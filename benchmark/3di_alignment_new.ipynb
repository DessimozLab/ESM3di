# %% [markdown]
# # 3Di Alignment Benchmark
#
# ## Description
#
# We compare the performance of ESM3Di against ProstT5 on the MetaVR sequence set.
#
# We have 3 different 3Di representations of the MetaVR sequence set:
# * **AF3**: 3Di generated by Foldseek based on the predicted AlphaFold3 structures of the MetaVR sequence set.
# * **ProstT5**: 3Di generated by ProstT5 based on the sequences of the MetaVR sequence set.
# * **ESM3Di**: 3Di generated by ESM3Di based on the sequences of the MetaVR sequence set.
#
# We compile each representation into a Foldseek database and run Foldseek's `structurealign` module on a 1-vs-1 basis (aligning identical entries).
#
# The results are represented as the **bitscore** of the alignment and **3Di sequence identity**.
#
# The **bitscore** is a measure of the overall similarity between two aligned 3Di sequences. It rewards long, well-matching alignments while penalizing mismatches and gaps, with higher bitscores indicating more similar 3Di representations.
#
# The **3Di sequence identity** is calculated as:
#
# $$
# \text{Identity} = \frac{\text{\# of residues with identical 3Di}}{\text{\# of residues}}
# $$

# %%
import sys

print(sys.executable)
# Out:
# /users/fweikert/ESM3di/.venv/bin/python3

# %%
import shutil
import os

# Optional: Add local foldseek directory to PATH if installed in project folder
os.environ["PATH"] += os.pathsep + "/users/fweikert/ESM3di/foldseek/bin"

if not shutil.which("foldseek"):
    raise FileNotFoundError(
        "Foldseek binary not found in PATH. "
        "Please download the standalone binary or load the appropriate cluster module."
    )
else:
    print(f"Foldseek is ready to use at: {shutil.which('foldseek')}")
# Out:
# Foldseek is ready to use at: /users/fweikert/ESM3di/foldseek/bin/foldseek

# %%
import subprocess
import torch

# 1. Check if PyTorch in Jupyter actually has CUDA compiled
print("--- PyTorch Diagnostics ---")
print("PyTorch Version:", torch.__version__)
print("CUDA Compiled into PyTorch:", torch.version.cuda)
print("CUDA Available to PyTorch:", torch.cuda.is_available())

# 2. Check if Foldseek binary supports GPU
print("\n--- Foldseek Diagnostics ---")
res = subprocess.run(["foldseek", "createdb" , "--help"], capture_output=True, text=True)
if "--gpu" in res.stdout or "--gpu-server" in res.stdout:
    print("Foldseek CLI supports GPU flag.")
else:
    print("WARNING: Foldseek binary appears to be CPU-only!")
# Out:
# --- PyTorch Diagnostics ---
# PyTorch Version: 2.8.0+cu128
# CUDA Compiled into PyTorch: 12.8
# CUDA Available to PyTorch: True
#
# --- Foldseek Diagnostics ---
# Foldseek CLI supports GPU flag.

# %%
import os
import subprocess
from pathlib import Path

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch

# --- Configuration ---
DATAPATH = Path("./data")
DATAPATH.mkdir(parents=True, exist_ok=True)

FS_DIR = DATAPATH / "foldseek"
META_DIR = DATAPATH / "metavr"
FS_DIR.mkdir(exist_ok=True)
META_DIR.mkdir(exist_ok=True)

# --- Utility Functions ---
def run_cmd(cmd, silent=False):
    # Pass os.environ.copy() to preserve GPU/CUDA settings
    process = subprocess.Popen(
        cmd,
        shell=True,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,  # Merge stderr into stdout so they stream in order
        text=True,
        bufsize=1,  # Line-buffered
        env=os.environ.copy()
    )

    output_lines = []

    # Read output line-by-line in real time
    for line in iter(process.stdout.readline, ''):
        output_lines.append(line)
        if not silent:
            print(line, end='', flush=True)  # Print immediately to terminal/Jupyter

    process.stdout.close()
    return_code = process.wait()

    if return_code != 0:
        error_msg = "".join(output_lines)
        raise RuntimeError(f"Command failed with exit code {return_code}:\n{cmd}\n\nOutput:\n{error_msg}")

def write_fasta(sequences: dict[str, str], filepath: Path):
    """Writes a dictionary of {id: sequence} to a FASTA file."""
    with open(filepath, "w") as f:
        for seq_id, seq in sequences.items():
            f.write(f">{seq_id}\n{seq}\n")

def parse_fasta(fasta_path: Path) -> dict[str, str]:
    """Reads a FASTA file into a {id: sequence} dictionary."""
    seqs, hdr = {}, None
    with open(fasta_path) as f:
        for line in f:
            line = line.strip()
            if line.startswith(">"):
                hdr = line[1:].split()[0]
                seqs[hdr] = ""
            elif hdr:
                seqs[hdr] += line
    return seqs

# %%
import tarfile
from curl_cffi import requests
from tqdm import tqdm

tar_path = META_DIR / "partial_download.tar.gz"
url = "https://www.meta-virome.org/Data/Downloads/IMGVR5_PC_3Dmodels.tar.gz"

max_bytes = 1024 * 1024 * 1024  # 1 GB cap
downloaded = 0

print("1. Downloading first 1 GB using browser TLS impersonation...")

response = requests.get(url, impersonate="chrome", stream=True)

if response.status_code != 200:
    print(f"Failed with status code: {response.status_code}")
else:
    # Stream download with progress bar
    with open(tar_path, "wb") as f, tqdm(
        total=max_bytes,
        unit="B",
        unit_scale=True,
        unit_divisor=1024,
        desc="Downloading 1GB sample",
    ) as pbar:
        for chunk in response.iter_content(chunk_size=1024 * 1024):
            if not chunk:
                continue

            # Ensure we stop precisely at the 1 GB cap
            bytes_to_write = min(len(chunk), max_bytes - downloaded)
            f.write(chunk[:bytes_to_write])
            downloaded += bytes_to_write
            pbar.update(bytes_to_write)

            if downloaded >= max_bytes:
                break

    print(f"\nDownloaded {downloaded / (1024 * 1024):.2f} MB to {tar_path}")

    print("2. Extracting structures...")

    # Stream mode ("r|gz") reads sequentially and avoids pre-scanning the full file
    try:
        with tarfile.open(tar_path, "r|gz") as tar:
            while True:
                try:
                    member = tar.next()
                    if member is None:
                        break
                    tar.extract(member, path=META_DIR)
                except (EOFError, tarfile.TarError, OSError):
                    # Gracefully stop extraction at the truncated cutoff point
                    print("\nReached the end of the truncated 1 GB stream.")
                    break
    except Exception as e:
        print(f"\nExtraction finished with notice: {e}")

    # Clean up archive file
    if tar_path.exists():
        tar_path.unlink()

    # Count extracted files
    extracted_files = sum(1 for _ in META_DIR.glob("**/*") if _.is_file())
    print(f"3. Done! Total extracted files: {extracted_files}")
# Out:
# 1. Downloading first 1 GB using browser TLS impersonation...
# Downloading 1GB sample: 100%|██████████| 1.00G/1.00G [00:16<00:00, 64.5MB/s]
# /usr/lib64/python3.9/tarfile.py:2288: RuntimeWarning: The default behavior of tarfile extraction has been changed to disallow common exploits (including CVE-2007-4559). By default, absolute/parent paths are disallowed and some mode bits are cleared. See https://access.redhat.com/articles/7004769 for more details.
#   warnings.warn(
# Downloaded 1024.00 MB to data/metavr/partial_download.tar.gz
# 2. Extracting structures...
#
# Reached the end of the truncated 1 GB stream.
# 3. Done! Total extracted files: 36344

# %%
import os
import random
import shutil


def sample_structures(source_dir, output_dir, n_samples=500, seed=42):
    """Samples `n_samples` PDB/CIF files from source_dir into output_dir."""
    random.seed(seed)  # Fixed seed ensures reproducible sampling
    os.makedirs(output_dir, exist_ok=True)

    # Find all 3D structure files
    valid_exts = (".pdb", ".cif", ".ent", ".pdb.gz", ".cif.gz")
    all_files = [
        f
        for f in os.listdir(source_dir)
        if f.lower().endswith(valid_exts)
        and os.path.isfile(os.path.join(source_dir, f))
    ]

    if not all_files:
        print(f"Error: No structure files found in '{source_dir}'")
        return

    sample_size = min(n_samples, len(all_files))
    sampled_files = random.sample(all_files, sample_size)

    print(f"Found {len(all_files)} structure files in '{source_dir}'.")
    print(f"Copying {sample_size} files to '{output_dir}'...")

    for file_name in sampled_files:
        src = os.path.join(source_dir, file_name)
        dst = os.path.join(output_dir, file_name)
        shutil.copy2(src, dst)

    print(f"Done! Sampled {sample_size} structures successfully.\n")

# %%
n = 10000
SAMPLE_DIR = META_DIR / f"metaVR_structures_{n}"

sample_structures(
    META_DIR / "metaVR_structures_all",
    SAMPLE_DIR,
    n_samples=n,
    seed=42,
)
# Out:
# Found 25338 structure files in 'data/metavr/metaVR_structures_all'.
# Copying 10000 files to 'data/metavr/metaVR_structures_10000'...
# Done! Sampled 10000 structures successfully.

# %% [markdown]
# ### Ground Truth 3Di from AlphaFold3

# %%
af3_db = FS_DIR / "metavr_af3"
fasta = META_DIR / "input_aa.fasta"

# 1. Create the Foldseek database directly from the directory of .cif files
print("Creating Foldseek DB from CIF folder...")
run_cmd(f"foldseek createdb '{SAMPLE_DIR}' '{af3_db}'")

# 2. Export the amino acid sequences from the DB to a standard FASTA file
print("Exporting AA sequences to FASTA...")
run_cmd(f"foldseek convert2fasta '{af3_db}' '{fasta}'")

# 3. Verify the sequence count
aa_seqs = parse_fasta(fasta)
print(f"Successfully extracted {len(aa_seqs)} sequences to {fasta}")
# Out:
# Creating Foldseek DB from CIF folder...
# data/foldseek/metavr_af3 exists and will be overwritten
# createdb data/metavr/metaVR_structures_10000 data/foldseek/metavr_af3
#
# MMseqs Version:             	7f4b94644d6b210af4530e04a9fdc9e4bb64ea66
# Use GPU                     	0
# Path to ProstT5
# Chain name mode             	0
# Model name mode             	0
# Createdb extraction mode    	0
# Interface distance threshold	10
# Write mapping file          	0
# Write Foldcomp              	0
# Mask b-factor threshold     	0
# Coord store mode            	2
# Write lookup file           	1
# Input format                	0
# Input compression format    	0
# File Inclusion Regex        	.*
# File Exclusion Regex        	^$
# Threads                     	48
# Verbosity                   	3
#
# Output file: data/foldseek/metavr_af3
# [=================================================================] 10.00K 13s 216ms
# Time for merging to metavr_af3_ss: 0h 0m 0s 47ms
# Time for merging to metavr_af3_h: 0h 0m 0s 12ms
# Time for merging to metavr_af3_ca: 0h 0m 0s 61ms
# Time for merging to metavr_af3: 0h 0m 0s 18ms
# Ignore 1 out of 9999.
# Too short: 0, incorrect: 1, not proteins: 0.
# Time for processing: 0h 0m 13s 547ms
# Exporting AA sequences to FASTA...
# data/metavr/input_aa.fasta exists and will be overwritten
# convert2fasta data/foldseek/metavr_af3 data/metavr/input_aa.fasta
#
# MMseqs Version:	7f4b94644d6b210af4530e04a9fdc9e4bb64ea66
# Use header DB	false
# Verbosity    	3
#
# Start writing file to data/metavr/input_aa.fasta
# Time for processing: 0h 0m 0s 8ms
# Successfully extracted 9999 sequences to data/metavr/input_aa.fasta

# %% [markdown]
# ### Predict 3Di with ProstT5 (General Purpose)

# %%
prost_db = FS_DIR / "metavr_prostt5"

prostt5_weights = DATAPATH / "prostt5_weights"
tmp = DATAPATH / "tmp"
prostt5_weights.mkdir(exist_ok=True)
tmp.mkdir(exist_ok=True)

# if empty directory, download weights
if not any(prostt5_weights.iterdir()):
    run_cmd(
        f"foldseek databases ProstT5 '{prostt5_weights}' '{tmp}'"
    )
else:
    print("Weights already loaded, creating foldseek database...")

# clean up temporary directory
if tmp.exists():
    shutil.rmtree(tmp)

# 4. Create the Foldseek database using the downloaded weights
run_cmd(
    f"foldseek createdb \
    '{fasta}' \
    '{prost_db}' \
    --gpu 1 \
    --prostt5-model '{prostt5_weights}'"
)
# Out:
# Weights already loaded, creating foldseek database...
# data/foldseek/metavr_prostt5 exists and will be overwritten
# data/foldseek/metavr_prostt5 exists and will be overwritten
# createdb data/metavr/input_aa.fasta data/foldseek/metavr_prostt5 --prostt5-model data/prostt5_weights
#
# MMseqs Version:             	7f4b94644d6b210af4530e04a9fdc9e4bb64ea66
# Use GPU                     	0
# Path to ProstT5             	data/prostt5_weights
# Chain name mode             	0
# Model name mode             	0
# Createdb extraction mode    	0
# Interface distance threshold	10
# Write mapping file          	0
# Write Foldcomp              	0
# Mask b-factor threshold     	0
# Coord store mode            	2
# Write lookup file           	1
# Input format                	0
# Input compression format    	0
# File Inclusion Regex        	.*
# File Exclusion Regex        	^$
# Threads                     	48
# Verbosity                   	3
#
# Converting sequences
# [
# Time for merging to metavr_prostt5_h: 0h 0m 0s 32ms
# Time for merging to metavr_prostt5: 0h 0m 0s 76ms
# Database type: Aminoacid
# CUDA0
# CPU
# [=================================================================] 10.00K 6m 24s 589ms
# Time for merging to metavr_prostt5_ss: 0h 0m 0s 45ms
# Time for merging to metavr_prostt5_ss_tmp: 0h 0m 0s 49ms
# Time for processing: 0h 6m 25s 297ms

# %% [markdown]
# ### Predict 3Di with ESM3Di (Fine tuned for viral structure)

# %%
esm_db = FS_DIR / "metavr_esm3di"

run_cmd(
    f"esm3di foldseek-db \
    --input-fasta '{fasta}' \
    --output-db '{esm_db}' \
    --batch-size 16"
    )
# Out:
# 15:52:18 [INFO] Loading model from: /users/fweikert/ESM3di/esm3di_inference/checkpoints/hf_compatible
# 15:52:20 [INFO] Using device: cuda (NVIDIA A100-PCIE-40GB)
# 15:52:20 [INFO] Reading sequence inputs from: /users/fweikert/ESM3di/esm3di_inference/benchmark/data/metavr/input_aa.fasta
#
# Generating 3Di tokens:   0%|          | 0/625 [00:00<?, ?batch/s]
# Generating 3Di tokens:   0%|          | 1/625 [00:01<14:38,  1.41s/batch]
# Generating 3Di tokens:   0%|          | 2/625 [00:01<08:09,  1.27batch/s]
# Generating 3Di tokens:   0%|          | 3/625 [00:02<06:11,  1.68batch/s]
# Generating 3Di tokens:   1%|          | 4/625 [00:02<05:41,  1.82batch/s]
# Generating 3Di tokens:   1%|          | 5/625 [00:02<04:39,  2.22batch/s]
# Generating 3Di tokens:   1%|          | 6/625 [00:03<05:38,  1.83batch/s]
# Generating 3Di tokens:   1%|          | 7/625 [00:05<09:43,  1.06batch/s]
# Generating 3Di tokens:   1%|▏         | 8/625 [00:05<08:26,  1.22batch/s]
# Generating 3Di tokens:   1%|▏         | 9/625 [00:06<06:49,  1.50batch/s]
# Generating 3Di tokens:   2%|▏         | 10/625 [00:06<05:32,  1.85batch/s]
# Generating 3Di tokens:   2%|▏         | 11/625 [00:07<06:29,  1.58batch/s]
# Generating 3Di tokens:   2%|▏         | 12/625 [00:07<05:38,  1.81batch/s]
# Generating 3Di tokens:   2%|▏         | 13/625 [00:08<05:15,  1.94batch/s]
# Generating 3Di tokens:   2%|▏         | 14/625 [00:08<04:54,  2.07batch/s]
# Generating 3Di tokens:   2%|▏         | 15/625 [00:09<05:52,  1.73batch/s]
# Generating 3Di tokens:   3%|▎         | 16/625 [00:09<05:03,  2.01batch/s]
# Generating 3Di tokens:   3%|▎         | 17/625 [00:10<05:21,  1.89batch/s]
# Generating 3Di tokens:   3%|▎         | 18/625 [00:10<04:41,  2.16batch/s]
# Generating 3Di tokens:   3%|▎         | 19/625 [00:11<04:43,  2.14batch/s]
# Generating 3Di tokens:   3%|▎         | 20/625 [00:11<04:53,  2.06batch/s]
# Generating 3Di tokens:   3%|▎         | 21/625 [00:12<05:16,  1.91batch/s]
# Generating 3Di tokens:   4%|▎         | 22/625 [00:12<05:42,  1.76batch/s]
# Generating 3Di tokens:   4%|▎         | 23/625 [00:13<07:12,  1.39batch/s]
# Generating 3Di tokens:   4%|▍         | 24/625 [00:14<06:02,  1.66batch/s]
# Generating 3Di tokens:   4%|▍         | 25/625 [00:14<05:35,  1.79batch/s]
# Generating 3Di tokens:   4%|▍         | 26/625 [00:15<06:03,  1.65batch/s]
# Generating 3Di tokens:   4%|▍         | 27/625 [00:15<05:08,  1.94batch/s]
# Generating 3Di tokens:   4%|▍         | 28/625 [00:16<04:43,  2.11batch/s]
# Generating 3Di tokens:   5%|▍         | 29/625 [00:16<04:46,  2.08batch/s]
# Generating 3Di tokens:   5%|▍         | 30/625 [00:16<04:08,  2.39batch/s]
# Generating 3Di tokens:   5%|▍         | 31/625 [00:17<05:20,  1.85batch/s]
# Generating 3Di tokens:   5%|▌         | 32/625 [00:18<05:05,  1.94batch/s]
# Generating 3Di tokens:   5%|▌         | 33/625 [00:18<05:10,  1.91batch/s]
# Generating 3Di tokens:   5%|▌         | 34/625 [00:19<05:37,  1.75batch/s]
# Generating 3Di tokens:   6%|▌         | 35/625 [00:20<07:50,  1.25batch/s]
# Generating 3Di tokens:   6%|▌         | 36/625 [00:20<06:15,  1.57batch/s]
# Generating 3Di tokens:   6%|▌         | 37/625 [00:21<04:58,  1.97batch/s]
# Generating 3Di tokens:   6%|▌         | 38/625 [00:22<07:26,  1.31batch/s]
# Generating 3Di tokens:   6%|▌         | 39/625 [00:23<08:35,  1.14batch/s]
# Generating 3Di tokens:   6%|▋         | 40/625 [00:24<07:15,  1.34batch/s]
# Generating 3Di tokens:   7%|▋         | 41/625 [00:24<06:13,  1.57batch/s]
# Generating 3Di tokens:   7%|▋         | 42/625 [00:24<05:13,  1.86batch/s]
# Generating 3Di tokens:   7%|▋         | 43/625 [00:25<05:25,  1.79batch/s]
# Generating 3Di tokens:   7%|▋         | 44/625 [00:25<04:30,  2.15batch/s]
# Generating 3Di tokens:   7%|▋         | 45/625 [00:26<04:16,  2.26batch/s]
# Generating 3Di tokens:   7%|▋         | 46/625 [00:26<04:07,  2.34batch/s]
# Generating 3Di tokens:   8%|▊         | 47/625 [00:26<03:20,  2.88batch/s]
# Generating 3Di tokens:   8%|▊         | 48/625 [00:27<03:28,  2.77batch/s]
# Generating 3Di tokens:   8%|▊         | 49/625 [00:28<05:36,  1.71batch/s]
# Generating 3Di tokens:   8%|▊         | 50/625 [00:28<05:41,  1.69batch/s]
# Generating 3Di tokens:   8%|▊         | 51/625 [00:29<05:23,  1.78batch/s]
# Generating 3Di tokens:   8%|▊         | 52/625 [00:29<04:28,  2.14batch/s]
# Generating 3Di tokens:   8%|▊         | 53/625 [00:30<05:23,  1.77batch/s]
# Generating 3Di tokens:   9%|▊         | 54/625 [00:30<04:34,  2.08batch/s]
# Generating 3Di tokens:   9%|▉         | 55/625 [00:31<04:57,  1.91batch/s]
# Generating 3Di tokens:   9%|▉         | 56/625 [00:31<05:03,  1.87batch/s]
# Generating 3Di tokens:   9%|▉         | 57/625 [00:31<04:15,  2.22batch/s]
# Generating 3Di tokens:   9%|▉         | 58/625 [00:32<04:00,  2.36batch/s]
# Generating 3Di tokens:   9%|▉         | 59/625 [00:32<03:44,  2.52batch/s]
# Generating 3Di tokens:  10%|▉         | 60/625 [00:33<03:35,  2.62batch/s]
# Generating 3Di tokens:  10%|▉         | 61/625 [00:37<16:22,  1.74s/batch]
# Generating 3Di tokens:  10%|▉         | 62/625 [00:38<14:09,  1.51s/batch]
# Generating 3Di tokens:  10%|█         | 63/625 [00:39<11:15,  1.20s/batch]
# Generating 3Di tokens:  10%|█         | 64/625 [00:39<08:44,  1.07batch/s]
# Generating 3Di tokens:  10%|█         | 65/625 [00:40<07:27,  1.25batch/s]
# Generating 3Di tokens:  11%|█         | 66/625 [00:40<05:51,  1.59batch/s]
# Generating 3Di tokens:  11%|█         | 67/625 [00:40<05:02,  1.84batch/s]
# Generating 3Di tokens:  11%|█         | 68/625 [00:42<07:57,  1.17batch/s]
# Generating 3Di tokens:  11%|█         | 69/625 [00:42<06:31,  1.42batch/s]
# Generating 3Di tokens:  11%|█         | 70/625 [00:43<07:27,  1.24batch/s]
# Generating 3Di tokens:  11%|█▏        | 71/625 [00:44<07:05,  1.30batch/s]
# Generating 3Di tokens:  12%|█▏        | 72/625 [00:45<06:57,  1.33batch/s]
# Generating 3Di tokens:  12%|█▏        | 73/625 [00:45<06:38,  1.38batch/s]
# Generating 3Di tokens:  12%|█▏        | 74/625 [00:46<05:11,  1.77batch/s]
# Generating 3Di tokens:  12%|█▏        | 75/625 [00:46<05:02,  1.82batch/s]
# Generating 3Di tokens:  12%|█▏        | 76/625 [00:46<04:22,  2.09batch/s]
# Generating 3Di tokens:  12%|█▏        | 77/625 [00:47<05:00,  1.82batch/s]
# Generating 3Di tokens:  12%|█▏        | 78/625 [00:48<05:35,  1.63batch/s]
# Generating 3Di tokens:  13%|█▎        | 79/625 [00:48<04:55,  1.85batch/s]
# Generating 3Di tokens:  13%|█▎        | 80/625 [00:49<06:24,  1.42batch/s]
# Generating 3Di tokens:  13%|█▎        | 81/625 [00:50<06:45,  1.34batch/s]
# Generating 3Di tokens:  13%|█▎        | 82/625 [00:51<05:55,  1.53batch/s]
# Generating 3Di tokens:  13%|█▎        | 83/625 [00:51<05:26,  1.66batch/s]
# Generating 3Di tokens:  13%|█▎        | 84/625 [00:52<06:29,  1.39batch/s]
# Generating 3Di tokens:  14%|█▎        | 85/625 [00:53<07:19,  1.23batch/s]
# Generating 3Di tokens:  14%|█▍        | 86/625 [00:54<06:39,  1.35batch/s]
# Generating 3Di tokens:  14%|█▍        | 87/625 [00:54<06:58,  1.29batch/s]
# Generating 3Di tokens:  14%|█▍        | 88/625 [00:55<05:38,  1.59batch/s]
# Generating 3Di tokens:  14%|█▍        | 89/625 [00:57<10:43,  1.20s/batch]
# Generating 3Di tokens:  14%|█▍        | 90/625 [00:58<09:17,  1.04s/batch]
# Generating 3Di tokens:  15%|█▍        | 91/625 [01:00<12:05,  1.36s/batch]
# Generating 3Di tokens:  15%|█▍        | 92/625 [01:00<09:30,  1.07s/batch]
# Generating 3Di tokens:  15%|█▍        | 93/625 [01:01<07:30,  1.18batch/s]
# Generating 3Di tokens:  15%|█▌        | 94/625 [01:01<06:14,  1.42batch/s]
# Generating 3Di tokens:  15%|█▌        | 95/625 [01:02<05:38,  1.56batch/s]
# Generating 3Di tokens:  15%|█▌        | 96/625 [01:02<05:59,  1.47batch/s]
# Generating 3Di tokens:  16%|█▌        | 97/625 [01:03<05:14,  1.68batch/s]
# Generating 3Di tokens:  16%|█▌        | 98/625 [01:03<04:49,  1.82batch/s]
# Generating 3Di tokens:  16%|█▌        | 99/625 [01:05<08:10,  1.07batch/s]
# Generating 3Di tokens:  16%|█▌        | 100/625 [01:05<06:13,  1.40batch/s]
# Generating 3Di tokens:  16%|█▌        | 101/625 [01:07<08:25,  1.04batch/s]
# Generating 3Di tokens:  16%|█▋        | 102/625 [01:07<06:53,  1.27batch/s]
# Generating 3Di tokens:  16%|█▋        | 103/625 [01:07<05:27,  1.59batch/s]
# Generating 3Di tokens:  17%|█▋        | 104/625 [01:08<04:53,  1.77batch/s]
# Generating 3Di tokens:  17%|█▋        | 105/625 [01:08<04:11,  2.07batch/s]
# Generating 3Di tokens:  17%|█▋        | 106/625 [01:09<04:59,  1.73batch/s]
# Generating 3Di tokens:  17%|█▋        | 107/625 [01:09<04:27,  1.94batch/s]
# Generating 3Di tokens:  17%|█▋        | 108/625 [01:10<04:38,  1.85batch/s]
# Generating 3Di tokens:  17%|█▋        | 109/625 [01:10<04:24,  1.95batch/s]
# Generating 3Di tokens:  18%|█▊        | 110/625 [01:11<04:18,  2.00batch/s]
# Generating 3Di tokens:  18%|█▊        | 111/625 [01:11<04:07,  2.08batch/s]
# Generating 3Di tokens:  18%|█▊        | 112/625 [01:12<04:10,  2.05batch/s]
# Generating 3Di tokens:  18%|█▊        | 113/625 [01:12<04:05,  2.08batch/s]
# Generating 3Di tokens:  18%|█▊        | 114/625 [01:13<04:35,  1.86batch/s]
# Generating 3Di tokens:  18%|█▊        | 115/625 [01:13<04:07,  2.06batch/s]
# Generating 3Di tokens:  19%|█▊        | 116/625 [01:14<03:33,  2.39batch/s]
# Generating 3Di tokens:  19%|█▊        | 117/625 [01:14<02:57,  2.86batch/s]
# Generating 3Di tokens:  19%|█▉        | 118/625 [01:14<03:35,  2.35batch/s]
# Generating 3Di tokens:  19%|█▉        | 119/625 [01:15<04:05,  2.06batch/s]
# Generating 3Di tokens:  19%|█▉        | 120/625 [01:16<04:38,  1.82batch/s]
# Generating 3Di tokens:  19%|█▉        | 121/625 [01:17<05:34,  1.50batch/s]
# Generating 3Di tokens:  20%|█▉        | 122/625 [01:17<05:12,  1.61batch/s]
# Generating 3Di tokens:  20%|█▉        | 123/625 [01:19<09:11,  1.10s/batch]
# Generating 3Di tokens:  20%|█▉        | 124/625 [01:20<06:56,  1.20batch/s]
# Generating 3Di tokens:  20%|██        | 125/625 [01:20<05:56,  1.40batch/s]
# Generating 3Di tokens:  20%|██        | 126/625 [01:20<05:21,  1.55batch/s]
# Generating 3Di tokens:  20%|██        | 127/625 [01:22<07:04,  1.17batch/s]
# Generating 3Di tokens:  20%|██        | 128/625 [01:22<06:03,  1.37batch/s]
# Generating 3Di tokens:  21%|██        | 129/625 [01:23<04:47,  1.72batch/s]
# Generating 3Di tokens:  21%|██        | 130/625 [01:23<04:13,  1.95batch/s]
# Generating 3Di tokens:  21%|██        | 131/625 [01:23<03:40,  2.24batch/s]
# Generating 3Di tokens:  21%|██        | 132/625 [01:24<04:08,  1.98batch/s]
# Generating 3Di tokens:  21%|██▏       | 133/625 [01:24<03:48,  2.15batch/s]
# Generating 3Di tokens:  21%|██▏       | 134/625 [01:26<06:34,  1.24batch/s]
# Generating 3Di tokens:  22%|██▏       | 135/625 [01:30<15:33,  1.91s/batch]
# Generating 3Di tokens:  22%|██▏       | 136/625 [01:31<11:49,  1.45s/batch]
# Generating 3Di tokens:  22%|██▏       | 137/625 [01:31<09:32,  1.17s/batch]
# Generating 3Di tokens:  22%|██▏       | 138/625 [01:32<09:19,  1.15s/batch]
# Generating 3Di tokens:  22%|██▏       | 139/625 [01:33<07:46,  1.04batch/s]
# Generating 3Di tokens:  22%|██▏       | 140/625 [01:33<06:03,  1.33batch/s]
# Generating 3Di tokens:  23%|██▎       | 141/625 [01:33<05:04,  1.59batch/s]
# Generating 3Di tokens:  23%|██▎       | 142/625 [01:34<05:14,  1.53batch/s]
# Generating 3Di tokens:  23%|██▎       | 143/625 [01:34<04:36,  1.74batch/s]
# Generating 3Di tokens:  23%|██▎       | 144/625 [01:35<04:05,  1.96batch/s]
# Generating 3Di tokens:  23%|██▎       | 145/625 [01:35<03:44,  2.14batch/s]
# Generating 3Di tokens:  23%|██▎       | 146/625 [01:36<03:22,  2.37batch/s]
# Generating 3Di tokens:  24%|██▎       | 147/625 [01:36<04:02,  1.97batch/s]
# Generating 3Di tokens:  24%|██▎       | 148/625 [01:37<03:59,  1.99batch/s]
# Generating 3Di tokens:  24%|██▍       | 149/625 [01:37<03:39,  2.17batch/s]
# Generating 3Di tokens:  24%|██▍       | 150/625 [01:37<03:29,  2.26batch/s]
# Generating 3Di tokens:  24%|██▍       | 151/625 [01:38<03:49,  2.07batch/s]
# Generating 3Di tokens:  24%|██▍       | 152/625 [01:38<03:24,  2.31batch/s]
# Generating 3Di tokens:  24%|██▍       | 153/625 [01:39<03:17,  2.39batch/s]
# Generating 3Di tokens:  25%|██▍       | 154/625 [01:39<03:09,  2.49batch/s]
# Generating 3Di tokens:  25%|██▍       | 155/625 [01:40<05:24,  1.45batch/s]
# Generating 3Di tokens:  25%|██▍       | 156/625 [01:41<04:42,  1.66batch/s]
# Generating 3Di tokens:  25%|██▌       | 157/625 [01:41<04:42,  1.66batch/s]
# Generating 3Di tokens:  25%|██▌       | 158/625 [01:42<04:05,  1.90batch/s]
# Generating 3Di tokens:  25%|██▌       | 159/625 [01:42<04:24,  1.76batch/s]
# Generating 3Di tokens:  26%|██▌       | 160/625 [01:43<04:16,  1.81batch/s]
# Generating 3Di tokens:  26%|██▌       | 161/625 [01:44<04:19,  1.78batch/s]
# Generating 3Di tokens:  26%|██▌       | 162/625 [01:45<05:28,  1.41batch/s]
# Generating 3Di tokens:  26%|██▌       | 163/625 [01:45<05:08,  1.50batch/s]
# Generating 3Di tokens:  26%|██▌       | 164/625 [01:45<04:06,  1.87batch/s]
# Generating 3Di tokens:  26%|██▋       | 165/625 [01:47<06:17,  1.22batch/s]
# Generating 3Di tokens:  27%|██▋       | 166/625 [01:48<06:59,  1.09batch/s]
# Generating 3Di tokens:  27%|██▋       | 167/625 [01:49<06:02,  1.26batch/s]
# Generating 3Di tokens:  27%|██▋       | 168/625 [01:49<04:52,  1.56batch/s]
# Generating 3Di tokens:  27%|██▋       | 169/625 [01:49<04:38,  1.64batch/s]
# Generating 3Di tokens:  27%|██▋       | 170/625 [01:50<04:20,  1.75batch/s]
# Generating 3Di tokens:  27%|██▋       | 171/625 [01:51<06:02,  1.25batch/s]
# Generating 3Di tokens:  28%|██▊       | 172/625 [01:52<05:46,  1.31batch/s]
# Generating 3Di tokens:  28%|██▊       | 173/625 [01:53<06:02,  1.25batch/s]
# Generating 3Di tokens:  28%|██▊       | 174/625 [01:53<04:48,  1.56batch/s]
# Generating 3Di tokens:  28%|██▊       | 175/625 [01:54<04:25,  1.70batch/s]
# Generating 3Di tokens:  28%|██▊       | 176/625 [01:54<03:41,  2.03batch/s]
# Generating 3Di tokens:  28%|██▊       | 177/625 [01:54<03:57,  1.89batch/s]
# Generating 3Di tokens:  28%|██▊       | 178/625 [01:55<03:11,  2.33batch/s]
# Generating 3Di tokens:  29%|██▊       | 179/625 [01:55<03:07,  2.37batch/s]
# Generating 3Di tokens:  29%|██▉       | 180/625 [01:57<06:02,  1.23batch/s]
# Generating 3Di tokens:  29%|██▉       | 181/625 [01:57<05:00,  1.48batch/s]
# Generating 3Di tokens:  29%|██▉       | 182/625 [01:58<04:49,  1.53batch/s]
# Generating 3Di tokens:  29%|██▉       | 183/625 [01:58<03:46,  1.95batch/s]
# Generating 3Di tokens:  29%|██▉       | 184/625 [01:58<03:09,  2.32batch/s]
# Generating 3Di tokens:  30%|██▉       | 185/625 [01:59<03:07,  2.35batch/s]
# Generating 3Di tokens:  30%|██▉       | 186/625 [02:01<06:51,  1.07batch/s]
# Generating 3Di tokens:  30%|██▉       | 187/625 [02:01<05:23,  1.35batch/s]
# Generating 3Di tokens:  30%|███       | 188/625 [02:02<05:38,  1.29batch/s]
# Generating 3Di tokens:  30%|███       | 189/625 [02:02<05:15,  1.38batch/s]
# Generating 3Di tokens:  30%|███       | 190/625 [02:03<05:46,  1.26batch/s]
# Generating 3Di tokens:  31%|███       | 191/625 [02:04<05:00,  1.44batch/s]
# Generating 3Di tokens:  31%|███       | 192/625 [02:04<04:55,  1.47batch/s]
# Generating 3Di tokens:  31%|███       | 193/625 [02:05<04:24,  1.63batch/s]
# Generating 3Di tokens:  31%|███       | 194/625 [02:05<03:57,  1.81batch/s]
# Generating 3Di tokens:  31%|███       | 195/625 [02:06<04:17,  1.67batch/s]
# Generating 3Di tokens:  31%|███▏      | 196/625 [02:08<06:41,  1.07batch/s]
# Generating 3Di tokens:  32%|███▏      | 197/625 [02:09<06:16,  1.14batch/s]
# Generating 3Di tokens:  32%|███▏      | 198/625 [02:09<05:11,  1.37batch/s]
# Generating 3Di tokens:  32%|███▏      | 199/625 [02:10<05:50,  1.22batch/s]
# Generating 3Di tokens:  32%|███▏      | 200/625 [02:11<05:51,  1.21batch/s]
# Generating 3Di tokens:  32%|███▏      | 201/625 [02:11<05:18,  1.33batch/s]
# Generating 3Di tokens:  32%|███▏      | 202/625 [02:12<04:39,  1.52batch/s]
# Generating 3Di tokens:  32%|███▏      | 203/625 [02:12<04:04,  1.73batch/s]
# Generating 3Di tokens:  33%|███▎      | 204/625 [02:12<03:29,  2.01batch/s]
# Generating 3Di tokens:  33%|███▎      | 205/625 [02:13<03:20,  2.09batch/s]
# Generating 3Di tokens:  33%|███▎      | 206/625 [02:13<03:04,  2.28batch/s]
# Generating 3Di tokens:  33%|███▎      | 207/625 [02:14<03:51,  1.80batch/s]
# Generating 3Di tokens:  33%|███▎      | 208/625 [02:15<04:01,  1.73batch/s]
# Generating 3Di tokens:  33%|███▎      | 209/625 [02:15<04:01,  1.72batch/s]
# Generating 3Di tokens:  34%|███▎      | 210/625 [02:16<04:04,  1.70batch/s]
# Generating 3Di tokens:  34%|███▍      | 211/625 [02:17<04:05,  1.68batch/s]
# Generating 3Di tokens:  34%|███▍      | 212/625 [02:17<03:56,  1.75batch/s]
# Generating 3Di tokens:  34%|███▍      | 213/625 [02:18<04:49,  1.42batch/s]
# Generating 3Di tokens:  34%|███▍      | 214/625 [02:19<05:43,  1.20batch/s]
# Generating 3Di tokens:  34%|███▍      | 215/625 [02:19<04:30,  1.52batch/s]
# Generating 3Di tokens:  35%|███▍      | 216/625 [02:20<04:16,  1.60batch/s]
# Generating 3Di tokens:  35%|███▍      | 217/625 [02:21<05:51,  1.16batch/s]
# Generating 3Di tokens:  35%|███▍      | 218/625 [02:22<05:08,  1.32batch/s]
# Generating 3Di tokens:  35%|███▌      | 219/625 [02:22<04:36,  1.47batch/s]
# Generating 3Di tokens:  35%|███▌      | 220/625 [02:23<04:23,  1.54batch/s]
# Generating 3Di tokens:  35%|███▌      | 221/625 [02:24<04:34,  1.47batch/s]
# Generating 3Di tokens:  36%|███▌      | 222/625 [02:24<03:53,  1.72batch/s]
# Generating 3Di tokens:  36%|███▌      | 223/625 [02:25<03:36,  1.85batch/s]
# Generating 3Di tokens:  36%|███▌      | 224/625 [02:25<03:40,  1.82batch/s]
# Generating 3Di tokens:  36%|███▌      | 225/625 [02:26<04:17,  1.55batch/s]
# Generating 3Di tokens:  36%|███▌      | 226/625 [02:26<03:52,  1.71batch/s]
# Generating 3Di tokens:  36%|███▋      | 227/625 [02:27<03:42,  1.79batch/s]
# Generating 3Di tokens:  36%|███▋      | 228/625 [02:28<04:24,  1.50batch/s]
# Generating 3Di tokens:  37%|███▋      | 229/625 [02:30<06:56,  1.05s/batch]
# Generating 3Di tokens:  37%|███▋      | 230/625 [02:30<06:12,  1.06batch/s]
# Generating 3Di tokens:  37%|███▋      | 231/625 [02:33<09:36,  1.46s/batch]
# Generating 3Di tokens:  37%|███▋      | 232/625 [02:34<07:50,  1.20s/batch]
# Generating 3Di tokens:  37%|███▋      | 233/625 [02:35<07:14,  1.11s/batch]
# Generating 3Di tokens:  37%|███▋      | 234/625 [02:35<05:34,  1.17batch/s]
# Generating 3Di tokens:  38%|███▊      | 235/625 [02:35<04:41,  1.38batch/s]
# Generating 3Di tokens:  38%|███▊      | 236/625 [02:36<03:59,  1.62batch/s]
# Generating 3Di tokens:  38%|███▊      | 237/625 [02:37<04:52,  1.33batch/s]
# Generating 3Di tokens:  38%|███▊      | 238/625 [02:38<05:11,  1.24batch/s]
# Generating 3Di tokens:  38%|███▊      | 239/625 [02:38<04:49,  1.33batch/s]
# Generating 3Di tokens:  38%|███▊      | 240/625 [02:39<04:21,  1.47batch/s]
# Generating 3Di tokens:  39%|███▊      | 241/625 [02:40<04:31,  1.42batch/s]
# Generating 3Di tokens:  39%|███▊      | 242/625 [02:41<05:44,  1.11batch/s]
# Generating 3Di tokens:  39%|███▉      | 243/625 [02:42<05:28,  1.16batch/s]
# Generating 3Di tokens:  39%|███▉      | 244/625 [02:42<04:43,  1.34batch/s]
# Generating 3Di tokens:  39%|███▉      | 245/625 [02:42<03:47,  1.67batch/s]
# Generating 3Di tokens:  39%|███▉      | 246/625 [02:43<03:23,  1.86batch/s]
# Generating 3Di tokens:  40%|███▉      | 247/625 [02:44<03:45,  1.68batch/s]
# Generating 3Di tokens:  40%|███▉      | 248/625 [02:44<03:34,  1.76batch/s]
# Generating 3Di tokens:  40%|███▉      | 249/625 [02:44<03:13,  1.94batch/s]
# Generating 3Di tokens:  40%|████      | 250/625 [02:45<02:50,  2.20batch/s]
# Generating 3Di tokens:  40%|████      | 251/625 [02:46<04:22,  1.42batch/s]
# Generating 3Di tokens:  40%|████      | 252/625 [02:47<04:01,  1.55batch/s]
# Generating 3Di tokens:  40%|████      | 253/625 [02:48<04:45,  1.30batch/s]
# Generating 3Di tokens:  41%|████      | 254/625 [02:48<04:14,  1.46batch/s]
# Generating 3Di tokens:  41%|████      | 255/625 [02:48<03:29,  1.76batch/s]
# Generating 3Di tokens:  41%|████      | 256/625 [02:49<03:55,  1.57batch/s]
# Generating 3Di tokens:  41%|████      | 257/625 [02:50<03:51,  1.59batch/s]
# Generating 3Di tokens:  41%|████▏     | 258/625 [02:50<03:20,  1.83batch/s]
# Generating 3Di tokens:  41%|████▏     | 259/625 [02:51<03:34,  1.70batch/s]
# Generating 3Di tokens:  42%|████▏     | 260/625 [02:52<04:24,  1.38batch/s]
# Generating 3Di tokens:  42%|████▏     | 261/625 [02:52<03:47,  1.60batch/s]
# Generating 3Di tokens:  42%|████▏     | 262/625 [02:53<03:36,  1.67batch/s]
# Generating 3Di tokens:  42%|████▏     | 263/625 [02:53<03:02,  1.98batch/s]
# Generating 3Di tokens:  42%|████▏     | 264/625 [02:54<03:11,  1.88batch/s]
# Generating 3Di tokens:  42%|████▏     | 265/625 [02:54<03:21,  1.79batch/s]
# Generating 3Di tokens:  43%|████▎     | 266/625 [02:55<03:51,  1.55batch/s]
# Generating 3Di tokens:  43%|████▎     | 267/625 [02:56<03:23,  1.76batch/s]
# Generating 3Di tokens:  43%|████▎     | 268/625 [02:57<04:26,  1.34batch/s]
# Generating 3Di tokens:  43%|████▎     | 269/625 [02:57<03:58,  1.49batch/s]
# Generating 3Di tokens:  43%|████▎     | 270/625 [02:58<03:51,  1.54batch/s]
# Generating 3Di tokens:  43%|████▎     | 271/625 [03:00<06:35,  1.12s/batch]
# Generating 3Di tokens:  44%|████▎     | 272/625 [03:01<06:45,  1.15s/batch]
# Generating 3Di tokens:  44%|████▎     | 273/625 [03:02<05:14,  1.12batch/s]
# Generating 3Di tokens:  44%|████▍     | 274/625 [03:02<04:43,  1.24batch/s]
# Generating 3Di tokens:  44%|████▍     | 275/625 [03:02<03:45,  1.55batch/s]
# Generating 3Di tokens:  44%|████▍     | 276/625 [03:04<05:59,  1.03s/batch]
# Generating 3Di tokens:  44%|████▍     | 277/625 [03:05<04:36,  1.26batch/s]
# Generating 3Di tokens:  44%|████▍     | 278/625 [03:05<03:58,  1.45batch/s]
# Generating 3Di tokens:  45%|████▍     | 279/625 [03:05<03:15,  1.77batch/s]
# Generating 3Di tokens:  45%|████▍     | 280/625 [03:06<02:40,  2.15batch/s]
# Generating 3Di tokens:  45%|████▍     | 281/625 [03:06<02:21,  2.42batch/s]
# Generating 3Di tokens:  45%|████▌     | 282/625 [03:07<02:57,  1.93batch/s]
# Generating 3Di tokens:  45%|████▌     | 283/625 [03:07<02:46,  2.06batch/s]
# Generating 3Di tokens:  45%|████▌     | 284/625 [03:07<02:37,  2.17batch/s]
# Generating 3Di tokens:  46%|████▌     | 285/625 [03:09<04:12,  1.35batch/s]
# Generating 3Di tokens:  46%|████▌     | 286/625 [03:09<03:38,  1.55batch/s]
# Generating 3Di tokens:  46%|████▌     | 287/625 [03:10<03:23,  1.66batch/s]
# Generating 3Di tokens:  46%|████▌     | 288/625 [03:10<02:44,  2.04batch/s]
# Generating 3Di tokens:  46%|████▌     | 289/625 [03:11<02:55,  1.92batch/s]
# Generating 3Di tokens:  46%|████▋     | 290/625 [03:12<03:47,  1.47batch/s]
# Generating 3Di tokens:  47%|████▋     | 291/625 [03:12<03:44,  1.49batch/s]
# Generating 3Di tokens:  47%|████▋     | 292/625 [03:13<03:18,  1.68batch/s]
# Generating 3Di tokens:  47%|████▋     | 293/625 [03:13<02:53,  1.91batch/s]
# Generating 3Di tokens:  47%|████▋     | 294/625 [03:13<02:25,  2.27batch/s]
# Generating 3Di tokens:  47%|████▋     | 295/625 [03:14<02:42,  2.03batch/s]
# Generating 3Di tokens:  47%|████▋     | 296/625 [03:14<02:36,  2.11batch/s]
# Generating 3Di tokens:  48%|████▊     | 297/625 [03:15<02:45,  1.98batch/s]
# Generating 3Di tokens:  48%|████▊     | 298/625 [03:15<02:25,  2.24batch/s]
# Generating 3Di tokens:  48%|████▊     | 299/625 [03:16<02:18,  2.35batch/s]
# Generating 3Di tokens:  48%|████▊     | 300/625 [03:16<02:35,  2.09batch/s]
# Generating 3Di tokens:  48%|████▊     | 301/625 [03:18<04:32,  1.19batch/s]
# Generating 3Di tokens:  48%|████▊     | 302/625 [03:18<03:33,  1.52batch/s]
# Generating 3Di tokens:  48%|████▊     | 303/625 [03:19<03:12,  1.67batch/s]
# Generating 3Di tokens:  49%|████▊     | 304/625 [03:19<03:32,  1.51batch/s]
# Generating 3Di tokens:  49%|████▉     | 305/625 [03:20<03:16,  1.63batch/s]
# Generating 3Di tokens:  49%|████▉     | 306/625 [03:20<03:15,  1.63batch/s]
# Generating 3Di tokens:  49%|████▉     | 307/625 [03:21<03:00,  1.76batch/s]
# Generating 3Di tokens:  49%|████▉     | 308/625 [03:21<02:44,  1.93batch/s]
# Generating 3Di tokens:  49%|████▉     | 309/625 [03:22<02:27,  2.15batch/s]
# Generating 3Di tokens:  50%|████▉     | 310/625 [03:22<02:41,  1.96batch/s]
# Generating 3Di tokens:  50%|████▉     | 311/625 [03:23<03:31,  1.48batch/s]
# Generating 3Di tokens:  50%|████▉     | 312/625 [03:24<03:04,  1.70batch/s]
# Generating 3Di tokens:  50%|█████     | 313/625 [03:24<02:32,  2.05batch/s]
# Generating 3Di tokens:  50%|█████     | 314/625 [03:24<02:30,  2.07batch/s]
# Generating 3Di tokens:  50%|█████     | 315/625 [03:25<02:25,  2.13batch/s]
# Generating 3Di tokens:  51%|█████     | 316/625 [03:25<02:15,  2.28batch/s]
# Generating 3Di tokens:  51%|█████     | 317/625 [03:25<01:51,  2.76batch/s]
# Generating 3Di tokens:  51%|█████     | 318/625 [03:26<01:56,  2.64batch/s]
# Generating 3Di tokens:  51%|█████     | 319/625 [03:26<01:39,  3.09batch/s]
# Generating 3Di tokens:  51%|█████     | 320/625 [03:27<02:29,  2.04batch/s]
# Generating 3Di tokens:  51%|█████▏    | 321/625 [03:28<02:37,  1.93batch/s]
# Generating 3Di tokens:  52%|█████▏    | 322/625 [03:28<03:15,  1.55batch/s]
# Generating 3Di tokens:  52%|█████▏    | 323/625 [03:29<03:00,  1.67batch/s]
# Generating 3Di tokens:  52%|█████▏    | 324/625 [03:30<03:07,  1.60batch/s]
# Generating 3Di tokens:  52%|█████▏    | 325/625 [03:31<03:37,  1.38batch/s]
# Generating 3Di tokens:  52%|█████▏    | 326/625 [03:32<04:04,  1.22batch/s]
# Generating 3Di tokens:  52%|█████▏    | 327/625 [03:32<03:32,  1.40batch/s]
# Generating 3Di tokens:  52%|█████▏    | 328/625 [03:33<03:15,  1.52batch/s]
# Generating 3Di tokens:  53%|█████▎    | 329/625 [03:33<03:00,  1.64batch/s]
# Generating 3Di tokens:  53%|█████▎    | 330/625 [03:34<03:46,  1.30batch/s]
# Generating 3Di tokens:  53%|█████▎    | 331/625 [03:35<02:57,  1.65batch/s]
# Generating 3Di tokens:  53%|█████▎    | 332/625 [03:35<03:05,  1.58batch/s]
# Generating 3Di tokens:  53%|█████▎    | 333/625 [03:36<02:56,  1.65batch/s]
# Generating 3Di tokens:  53%|█████▎    | 334/625 [03:37<03:22,  1.44batch/s]
# Generating 3Di tokens:  54%|█████▎    | 335/625 [03:37<03:06,  1.56batch/s]
# Generating 3Di tokens:  54%|█████▍    | 336/625 [03:38<02:45,  1.75batch/s]
# Generating 3Di tokens:  54%|█████▍    | 337/625 [03:38<02:11,  2.20batch/s]
# Generating 3Di tokens:  54%|█████▍    | 338/625 [03:38<01:55,  2.48batch/s]
# Generating 3Di tokens:  54%|█████▍    | 339/625 [03:39<02:06,  2.26batch/s]
# Generating 3Di tokens:  54%|█████▍    | 340/625 [03:39<01:50,  2.58batch/s]
# Generating 3Di tokens:  55%|█████▍    | 341/625 [03:39<01:35,  2.97batch/s]
# Generating 3Di tokens:  55%|█████▍    | 342/625 [03:40<01:51,  2.54batch/s]
# Generating 3Di tokens:  55%|█████▍    | 343/625 [03:41<02:45,  1.71batch/s]
# Generating 3Di tokens:  55%|█████▌    | 344/625 [03:41<02:13,  2.10batch/s]
# Generating 3Di tokens:  55%|█████▌    | 345/625 [03:41<02:24,  1.94batch/s]
# Generating 3Di tokens:  55%|█████▌    | 346/625 [03:42<01:58,  2.36batch/s]
# Generating 3Di tokens:  56%|█████▌    | 347/625 [03:42<02:11,  2.12batch/s]
# Generating 3Di tokens:  56%|█████▌    | 348/625 [03:43<02:08,  2.16batch/s]
# Generating 3Di tokens:  56%|█████▌    | 349/625 [03:43<01:59,  2.31batch/s]
# Generating 3Di tokens:  56%|█████▌    | 350/625 [03:43<01:46,  2.58batch/s]
# Generating 3Di tokens:  56%|█████▌    | 351/625 [03:44<02:17,  1.99batch/s]
# Generating 3Di tokens:  56%|█████▋    | 352/625 [03:45<02:11,  2.08batch/s]
# Generating 3Di tokens:  56%|█████▋    | 353/625 [03:45<01:56,  2.34batch/s]
# Generating 3Di tokens:  57%|█████▋    | 354/625 [03:45<01:40,  2.69batch/s]
# Generating 3Di tokens:  57%|█████▋    | 355/625 [03:46<01:54,  2.35batch/s]
# Generating 3Di tokens:  57%|█████▋    | 356/625 [03:46<01:58,  2.28batch/s]
# Generating 3Di tokens:  57%|█████▋    | 357/625 [03:48<03:25,  1.30batch/s]
# Generating 3Di tokens:  57%|█████▋    | 358/625 [03:48<02:42,  1.65batch/s]
# Generating 3Di tokens:  57%|█████▋    | 359/625 [03:48<02:12,  2.01batch/s]
# Generating 3Di tokens:  58%|█████▊    | 360/625 [03:49<02:19,  1.90batch/s]
# Generating 3Di tokens:  58%|█████▊    | 361/625 [03:49<02:10,  2.03batch/s]
# Generating 3Di tokens:  58%|█████▊    | 362/625 [03:49<01:55,  2.27batch/s]
# Generating 3Di tokens:  58%|█████▊    | 363/625 [03:50<01:59,  2.20batch/s]
# Generating 3Di tokens:  58%|█████▊    | 364/625 [03:51<02:19,  1.87batch/s]
# Generating 3Di tokens:  58%|█████▊    | 365/625 [03:51<02:34,  1.68batch/s]
# Generating 3Di tokens:  59%|█████▊    | 366/625 [03:52<02:13,  1.94batch/s]
# Generating 3Di tokens:  59%|█████▊    | 367/625 [03:52<02:05,  2.05batch/s]
# Generating 3Di tokens:  59%|█████▉    | 368/625 [03:53<02:17,  1.87batch/s]
# Generating 3Di tokens:  59%|█████▉    | 369/625 [03:53<02:19,  1.84batch/s]
# Generating 3Di tokens:  59%|█████▉    | 370/625 [03:54<02:17,  1.86batch/s]
# Generating 3Di tokens:  59%|█████▉    | 371/625 [03:55<02:40,  1.59batch/s]
# Generating 3Di tokens:  60%|█████▉    | 372/625 [03:55<02:14,  1.88batch/s]
# Generating 3Di tokens:  60%|█████▉    | 373/625 [03:56<02:40,  1.57batch/s]
# Generating 3Di tokens:  60%|█████▉    | 374/625 [03:57<02:45,  1.52batch/s]
# Generating 3Di tokens:  60%|██████    | 375/625 [03:57<02:19,  1.79batch/s]
# Generating 3Di tokens:  60%|██████    | 376/625 [03:57<01:53,  2.19batch/s]
# Generating 3Di tokens:  60%|██████    | 377/625 [03:57<01:40,  2.46batch/s]
# Generating 3Di tokens:  60%|██████    | 378/625 [03:58<02:13,  1.85batch/s]
# Generating 3Di tokens:  61%|██████    | 379/625 [03:59<01:59,  2.07batch/s]
# Generating 3Di tokens:  61%|██████    | 380/625 [03:59<02:02,  2.00batch/s]
# Generating 3Di tokens:  61%|██████    | 381/625 [03:59<01:44,  2.33batch/s]
# Generating 3Di tokens:  61%|██████    | 382/625 [04:00<01:48,  2.24batch/s]
# Generating 3Di tokens:  61%|██████▏   | 383/625 [04:02<03:22,  1.20batch/s]
# Generating 3Di tokens:  61%|██████▏   | 384/625 [04:02<02:39,  1.51batch/s]
# Generating 3Di tokens:  62%|██████▏   | 385/625 [04:03<02:34,  1.55batch/s]
# Generating 3Di tokens:  62%|██████▏   | 386/625 [04:03<02:24,  1.66batch/s]
# Generating 3Di tokens:  62%|██████▏   | 387/625 [04:04<02:55,  1.36batch/s]
# Generating 3Di tokens:  62%|██████▏   | 388/625 [04:05<02:38,  1.49batch/s]
# Generating 3Di tokens:  62%|██████▏   | 389/625 [04:05<02:13,  1.77batch/s]
# Generating 3Di tokens:  62%|██████▏   | 390/625 [04:05<01:46,  2.20batch/s]
# Generating 3Di tokens:  63%|██████▎   | 391/625 [04:06<01:43,  2.26batch/s]
# Generating 3Di tokens:  63%|██████▎   | 392/625 [04:06<01:36,  2.41batch/s]
# Generating 3Di tokens:  63%|██████▎   | 393/625 [04:07<01:54,  2.03batch/s]
# Generating 3Di tokens:  63%|██████▎   | 394/625 [04:07<01:44,  2.22batch/s]
# Generating 3Di tokens:  63%|██████▎   | 395/625 [04:07<01:45,  2.19batch/s]
# Generating 3Di tokens:  63%|██████▎   | 396/625 [04:08<01:39,  2.31batch/s]
# Generating 3Di tokens:  64%|██████▎   | 397/625 [04:08<01:36,  2.35batch/s]
# Generating 3Di tokens:  64%|██████▎   | 398/625 [04:09<01:38,  2.30batch/s]
# Generating 3Di tokens:  64%|██████▍   | 399/625 [04:09<01:22,  2.72batch/s]
# Generating 3Di tokens:  64%|██████▍   | 400/625 [04:10<01:49,  2.06batch/s]
# Generating 3Di tokens:  64%|██████▍   | 401/625 [04:10<02:06,  1.77batch/s]
# Generating 3Di tokens:  64%|██████▍   | 402/625 [04:11<01:47,  2.07batch/s]
# Generating 3Di tokens:  64%|██████▍   | 403/625 [04:11<01:46,  2.08batch/s]
# Generating 3Di tokens:  65%|██████▍   | 404/625 [04:12<02:42,  1.36batch/s]
# Generating 3Di tokens:  65%|██████▍   | 405/625 [04:13<02:30,  1.46batch/s]
# Generating 3Di tokens:  65%|██████▍   | 406/625 [04:13<02:01,  1.81batch/s]
# Generating 3Di tokens:  65%|██████▌   | 407/625 [04:14<02:01,  1.80batch/s]
# Generating 3Di tokens:  65%|██████▌   | 408/625 [04:14<01:40,  2.16batch/s]
# Generating 3Di tokens:  65%|██████▌   | 409/625 [04:15<02:08,  1.68batch/s]
# Generating 3Di tokens:  66%|██████▌   | 410/625 [04:16<02:20,  1.53batch/s]
# Generating 3Di tokens:  66%|██████▌   | 411/625 [04:16<02:02,  1.75batch/s]
# Generating 3Di tokens:  66%|██████▌   | 412/625 [04:17<01:47,  1.98batch/s]
# Generating 3Di tokens:  66%|██████▌   | 413/625 [04:17<01:53,  1.86batch/s]
# Generating 3Di tokens:  66%|██████▌   | 414/625 [04:19<02:47,  1.26batch/s]
# Generating 3Di tokens:  66%|██████▋   | 415/625 [04:19<02:58,  1.18batch/s]
# Generating 3Di tokens:  67%|██████▋   | 416/625 [04:20<02:42,  1.29batch/s]
# Generating 3Di tokens:  67%|██████▋   | 417/625 [04:21<02:19,  1.49batch/s]
# Generating 3Di tokens:  67%|██████▋   | 418/625 [04:21<02:09,  1.60batch/s]
# Generating 3Di tokens:  67%|██████▋   | 419/625 [04:22<02:12,  1.56batch/s]
# Generating 3Di tokens:  67%|██████▋   | 420/625 [04:22<02:14,  1.52batch/s]
# Generating 3Di tokens:  67%|██████▋   | 421/625 [04:23<02:06,  1.62batch/s]
# Generating 3Di tokens:  68%|██████▊   | 422/625 [04:24<02:09,  1.56batch/s]
# Generating 3Di tokens:  68%|██████▊   | 423/625 [04:26<04:08,  1.23s/batch]
# Generating 3Di tokens:  68%|██████▊   | 424/625 [04:27<03:10,  1.05batch/s]
# Generating 3Di tokens:  68%|██████▊   | 425/625 [04:27<02:47,  1.19batch/s]
# Generating 3Di tokens:  68%|██████▊   | 426/625 [04:27<02:09,  1.54batch/s]
# Generating 3Di tokens:  68%|██████▊   | 427/625 [04:28<01:47,  1.84batch/s]
# Generating 3Di tokens:  68%|██████▊   | 428/625 [04:28<01:48,  1.82batch/s]
# Generating 3Di tokens:  69%|██████▊   | 429/625 [04:28<01:32,  2.12batch/s]
# Generating 3Di tokens:  69%|██████▉   | 430/625 [04:29<01:41,  1.93batch/s]
# Generating 3Di tokens:  69%|██████▉   | 431/625 [04:29<01:26,  2.25batch/s]
# Generating 3Di tokens:  69%|██████▉   | 432/625 [04:31<02:07,  1.51batch/s]
# Generating 3Di tokens:  69%|██████▉   | 433/625 [04:31<02:03,  1.56batch/s]
# Generating 3Di tokens:  69%|██████▉   | 434/625 [04:32<01:48,  1.76batch/s]
# Generating 3Di tokens:  70%|██████▉   | 435/625 [04:32<01:52,  1.69batch/s]
# Generating 3Di tokens:  70%|██████▉   | 436/625 [04:33<02:04,  1.52batch/s]
# Generating 3Di tokens:  70%|██████▉   | 437/625 [04:34<02:05,  1.50batch/s]
# Generating 3Di tokens:  70%|███████   | 438/625 [04:34<01:46,  1.76batch/s]
# Generating 3Di tokens:  70%|███████   | 439/625 [04:35<01:42,  1.81batch/s]
# Generating 3Di tokens:  70%|███████   | 440/625 [04:35<01:33,  1.99batch/s]
# Generating 3Di tokens:  71%|███████   | 441/625 [04:35<01:21,  2.25batch/s]
# Generating 3Di tokens:  71%|███████   | 442/625 [04:36<01:14,  2.46batch/s]
# Generating 3Di tokens:  71%|███████   | 443/625 [04:36<01:27,  2.07batch/s]
# Generating 3Di tokens:  71%|███████   | 444/625 [04:37<01:18,  2.30batch/s]
# Generating 3Di tokens:  71%|███████   | 445/625 [04:37<01:15,  2.37batch/s]
# Generating 3Di tokens:  71%|███████▏  | 446/625 [04:38<02:12,  1.35batch/s]
# Generating 3Di tokens:  72%|███████▏  | 447/625 [04:41<03:28,  1.17s/batch]
# Generating 3Di tokens:  72%|███████▏  | 448/625 [04:41<03:11,  1.08s/batch]
# Generating 3Di tokens:  72%|███████▏  | 449/625 [04:42<02:27,  1.19batch/s]
# Generating 3Di tokens:  72%|███████▏  | 450/625 [04:42<02:10,  1.34batch/s]
# Generating 3Di tokens:  72%|███████▏  | 451/625 [04:43<02:19,  1.24batch/s]
# Generating 3Di tokens:  72%|███████▏  | 452/625 [04:44<01:59,  1.45batch/s]
# Generating 3Di tokens:  72%|███████▏  | 453/625 [04:44<01:49,  1.57batch/s]
# Generating 3Di tokens:  73%|███████▎  | 454/625 [04:45<01:57,  1.45batch/s]
# Generating 3Di tokens:  73%|███████▎  | 455/625 [04:45<01:35,  1.78batch/s]
# Generating 3Di tokens:  73%|███████▎  | 456/625 [04:46<01:24,  2.00batch/s]
# Generating 3Di tokens:  73%|███████▎  | 457/625 [04:46<01:09,  2.41batch/s]
# Generating 3Di tokens:  73%|███████▎  | 458/625 [04:46<01:08,  2.44batch/s]
# Generating 3Di tokens:  73%|███████▎  | 459/625 [04:47<01:10,  2.34batch/s]
# Generating 3Di tokens:  74%|███████▎  | 460/625 [04:47<01:04,  2.54batch/s]
# Generating 3Di tokens:  74%|███████▍  | 461/625 [04:48<01:13,  2.24batch/s]
# Generating 3Di tokens:  74%|███████▍  | 462/625 [04:49<01:41,  1.61batch/s]
# Generating 3Di tokens:  74%|███████▍  | 463/625 [04:49<01:34,  1.72batch/s]
# Generating 3Di tokens:  74%|███████▍  | 464/625 [04:50<01:48,  1.49batch/s]
# Generating 3Di tokens:  74%|███████▍  | 465/625 [04:50<01:38,  1.62batch/s]
# Generating 3Di tokens:  75%|███████▍  | 466/625 [04:51<01:48,  1.47batch/s]
# Generating 3Di tokens:  75%|███████▍  | 467/625 [04:53<02:23,  1.10batch/s]
# Generating 3Di tokens:  75%|███████▍  | 468/625 [04:53<01:58,  1.32batch/s]
# Generating 3Di tokens:  75%|███████▌  | 469/625 [04:54<01:46,  1.47batch/s]
# Generating 3Di tokens:  75%|███████▌  | 470/625 [04:54<01:28,  1.75batch/s]
# Generating 3Di tokens:  75%|███████▌  | 471/625 [04:54<01:14,  2.07batch/s]
# Generating 3Di tokens:  76%|███████▌  | 472/625 [04:55<01:21,  1.87batch/s]
# Generating 3Di tokens:  76%|███████▌  | 473/625 [04:55<01:10,  2.16batch/s]
# Generating 3Di tokens:  76%|███████▌  | 474/625 [04:55<00:58,  2.59batch/s]
# Generating 3Di tokens:  76%|███████▌  | 475/625 [04:56<00:53,  2.79batch/s]
# Generating 3Di tokens:  76%|███████▌  | 476/625 [04:56<00:59,  2.49batch/s]
# Generating 3Di tokens:  76%|███████▋  | 477/625 [04:56<00:53,  2.75batch/s]
# Generating 3Di tokens:  76%|███████▋  | 478/625 [04:57<00:53,  2.75batch/s]
# Generating 3Di tokens:  77%|███████▋  | 479/625 [04:58<01:49,  1.34batch/s]
# Generating 3Di tokens:  77%|███████▋  | 480/625 [04:59<01:39,  1.45batch/s]
# Generating 3Di tokens:  77%|███████▋  | 481/625 [04:59<01:18,  1.83batch/s]
# Generating 3Di tokens:  77%|███████▋  | 482/625 [05:00<01:38,  1.46batch/s]
# Generating 3Di tokens:  77%|███████▋  | 483/625 [05:01<01:25,  1.66batch/s]
# Generating 3Di tokens:  77%|███████▋  | 484/625 [05:01<01:30,  1.56batch/s]
# Generating 3Di tokens:  78%|███████▊  | 485/625 [05:02<01:23,  1.68batch/s]
# Generating 3Di tokens:  78%|███████▊  | 486/625 [05:02<01:25,  1.63batch/s]
# Generating 3Di tokens:  78%|███████▊  | 487/625 [05:03<01:14,  1.85batch/s]
# Generating 3Di tokens:  78%|███████▊  | 488/625 [05:03<01:13,  1.85batch/s]
# Generating 3Di tokens:  78%|███████▊  | 489/625 [05:04<01:04,  2.11batch/s]
# Generating 3Di tokens:  78%|███████▊  | 490/625 [05:04<01:14,  1.81batch/s]
# Generating 3Di tokens:  79%|███████▊  | 491/625 [05:05<00:59,  2.25batch/s]
# Generating 3Di tokens:  79%|███████▊  | 492/625 [05:05<00:51,  2.56batch/s]
# Generating 3Di tokens:  79%|███████▉  | 493/625 [05:05<00:43,  3.04batch/s]
# Generating 3Di tokens:  79%|███████▉  | 494/625 [05:06<01:09,  1.87batch/s]
# Generating 3Di tokens:  79%|███████▉  | 495/625 [05:07<01:06,  1.94batch/s]
# Generating 3Di tokens:  79%|███████▉  | 496/625 [05:07<01:00,  2.13batch/s]
# Generating 3Di tokens:  80%|███████▉  | 497/625 [05:08<01:12,  1.77batch/s]
# Generating 3Di tokens:  80%|███████▉  | 498/625 [05:08<01:04,  1.96batch/s]
# Generating 3Di tokens:  80%|███████▉  | 499/625 [05:08<00:59,  2.12batch/s]
# Generating 3Di tokens:  80%|████████  | 500/625 [05:09<00:55,  2.27batch/s]
# Generating 3Di tokens:  80%|████████  | 501/625 [05:10<01:11,  1.73batch/s]
# Generating 3Di tokens:  80%|████████  | 502/625 [05:10<01:03,  1.95batch/s]
# Generating 3Di tokens:  80%|████████  | 503/625 [05:11<01:05,  1.86batch/s]
# Generating 3Di tokens:  81%|████████  | 504/625 [05:11<01:13,  1.64batch/s]
# Generating 3Di tokens:  81%|████████  | 505/625 [05:13<01:31,  1.31batch/s]
# Generating 3Di tokens:  81%|████████  | 506/625 [05:14<01:41,  1.18batch/s]
# Generating 3Di tokens:  81%|████████  | 507/625 [05:14<01:33,  1.27batch/s]
# Generating 3Di tokens:  81%|████████▏ | 508/625 [05:16<02:03,  1.05s/batch]
# Generating 3Di tokens:  81%|████████▏ | 509/625 [05:16<01:36,  1.20batch/s]
# Generating 3Di tokens:  82%|████████▏ | 510/625 [05:17<01:20,  1.43batch/s]
# Generating 3Di tokens:  82%|████████▏ | 511/625 [05:17<01:02,  1.81batch/s]
# Generating 3Di tokens:  82%|████████▏ | 512/625 [05:17<01:01,  1.84batch/s]
# Generating 3Di tokens:  82%|████████▏ | 513/625 [05:18<00:50,  2.22batch/s]
# Generating 3Di tokens:  82%|████████▏ | 514/625 [05:19<01:11,  1.55batch/s]
# Generating 3Di tokens:  82%|████████▏ | 515/625 [05:19<00:57,  1.90batch/s]
# Generating 3Di tokens:  83%|████████▎ | 516/625 [05:19<00:49,  2.18batch/s]
# Generating 3Di tokens:  83%|████████▎ | 517/625 [05:20<00:57,  1.88batch/s]
# Generating 3Di tokens:  83%|████████▎ | 518/625 [05:20<00:51,  2.09batch/s]
# Generating 3Di tokens:  83%|████████▎ | 519/625 [05:21<00:45,  2.31batch/s]
# Generating 3Di tokens:  83%|████████▎ | 520/625 [05:21<00:49,  2.11batch/s]
# Generating 3Di tokens:  83%|████████▎ | 521/625 [05:22<00:44,  2.36batch/s]
# Generating 3Di tokens:  84%|████████▎ | 522/625 [05:22<00:42,  2.42batch/s]
# Generating 3Di tokens:  84%|████████▎ | 523/625 [05:22<00:40,  2.53batch/s]
# Generating 3Di tokens:  84%|████████▍ | 524/625 [05:23<00:37,  2.67batch/s]
# Generating 3Di tokens:  84%|████████▍ | 525/625 [05:23<00:39,  2.51batch/s]
# Generating 3Di tokens:  84%|████████▍ | 526/625 [05:23<00:33,  2.92batch/s]
# Generating 3Di tokens:  84%|████████▍ | 527/625 [05:24<00:34,  2.82batch/s]
# Generating 3Di tokens:  84%|████████▍ | 528/625 [05:24<00:39,  2.44batch/s]
# Generating 3Di tokens:  85%|████████▍ | 529/625 [05:24<00:35,  2.70batch/s]
# Generating 3Di tokens:  85%|████████▍ | 530/625 [05:25<00:31,  2.98batch/s]
# Generating 3Di tokens:  85%|████████▍ | 531/625 [05:25<00:30,  3.10batch/s]
# Generating 3Di tokens:  85%|████████▌ | 532/625 [05:25<00:33,  2.79batch/s]
# Generating 3Di tokens:  85%|████████▌ | 533/625 [05:27<00:52,  1.75batch/s]
# Generating 3Di tokens:  85%|████████▌ | 534/625 [05:27<00:48,  1.89batch/s]
# Generating 3Di tokens:  86%|████████▌ | 535/625 [05:28<00:49,  1.82batch/s]
# Generating 3Di tokens:  86%|████████▌ | 536/625 [05:28<00:41,  2.15batch/s]
# Generating 3Di tokens:  86%|████████▌ | 537/625 [05:28<00:42,  2.05batch/s]
# Generating 3Di tokens:  86%|████████▌ | 538/625 [05:29<00:37,  2.31batch/s]
# Generating 3Di tokens:  86%|████████▌ | 539/625 [05:29<00:32,  2.64batch/s]
# Generating 3Di tokens:  86%|████████▋ | 540/625 [05:29<00:27,  3.06batch/s]
# Generating 3Di tokens:  87%|████████▋ | 541/625 [05:30<00:29,  2.88batch/s]
# Generating 3Di tokens:  87%|████████▋ | 542/625 [05:31<00:46,  1.80batch/s]
# Generating 3Di tokens:  87%|████████▋ | 543/625 [05:31<00:39,  2.10batch/s]
# Generating 3Di tokens:  87%|████████▋ | 544/625 [05:32<00:49,  1.64batch/s]
# Generating 3Di tokens:  87%|████████▋ | 545/625 [05:32<00:42,  1.89batch/s]
# Generating 3Di tokens:  87%|████████▋ | 546/625 [05:33<00:42,  1.86batch/s]
# Generating 3Di tokens:  88%|████████▊ | 547/625 [05:33<00:35,  2.21batch/s]
# Generating 3Di tokens:  88%|████████▊ | 548/625 [05:33<00:32,  2.40batch/s]
# Generating 3Di tokens:  88%|████████▊ | 549/625 [05:34<00:33,  2.30batch/s]
# Generating 3Di tokens:  88%|████████▊ | 550/625 [05:35<00:42,  1.76batch/s]
# Generating 3Di tokens:  88%|████████▊ | 551/625 [05:35<00:40,  1.82batch/s]
# Generating 3Di tokens:  88%|████████▊ | 552/625 [05:35<00:34,  2.10batch/s]
# Generating 3Di tokens:  88%|████████▊ | 553/625 [05:36<00:35,  2.05batch/s]
# Generating 3Di tokens:  89%|████████▊ | 554/625 [05:37<00:41,  1.71batch/s]
# Generating 3Di tokens:  89%|████████▉ | 555/625 [05:37<00:38,  1.84batch/s]
# Generating 3Di tokens:  89%|████████▉ | 556/625 [05:38<00:37,  1.85batch/s]
# Generating 3Di tokens:  89%|████████▉ | 557/625 [05:38<00:29,  2.28batch/s]
# Generating 3Di tokens:  89%|████████▉ | 558/625 [05:38<00:29,  2.26batch/s]
# Generating 3Di tokens:  89%|████████▉ | 559/625 [05:40<00:57,  1.14batch/s]
# Generating 3Di tokens:  90%|████████▉ | 560/625 [05:41<01:00,  1.07batch/s]
# Generating 3Di tokens:  90%|████████▉ | 561/625 [05:42<00:47,  1.33batch/s]
# Generating 3Di tokens:  90%|████████▉ | 562/625 [05:44<01:12,  1.15s/batch]
# Generating 3Di tokens:  90%|█████████ | 563/625 [05:45<01:04,  1.04s/batch]
# Generating 3Di tokens:  90%|█████████ | 564/625 [05:45<00:50,  1.20batch/s]
# Generating 3Di tokens:  90%|█████████ | 565/625 [05:45<00:39,  1.50batch/s]
# Generating 3Di tokens:  91%|█████████ | 566/625 [05:46<00:33,  1.77batch/s]
# Generating 3Di tokens:  91%|█████████ | 567/625 [05:46<00:32,  1.78batch/s]
# Generating 3Di tokens:  91%|█████████ | 568/625 [05:46<00:27,  2.05batch/s]
# Generating 3Di tokens:  91%|█████████ | 569/625 [05:47<00:23,  2.37batch/s]
# Generating 3Di tokens:  91%|█████████ | 570/625 [05:47<00:19,  2.82batch/s]
# Generating 3Di tokens:  91%|█████████▏| 571/625 [05:48<00:39,  1.36batch/s]
# Generating 3Di tokens:  92%|█████████▏| 572/625 [05:49<00:30,  1.72batch/s]
# Generating 3Di tokens:  92%|█████████▏| 573/625 [05:49<00:26,  1.97batch/s]
# Generating 3Di tokens:  92%|█████████▏| 574/625 [05:49<00:22,  2.30batch/s]
# Generating 3Di tokens:  92%|█████████▏| 575/625 [05:49<00:17,  2.80batch/s]
# Generating 3Di tokens:  92%|█████████▏| 576/625 [05:50<00:20,  2.41batch/s]
# Generating 3Di tokens:  92%|█████████▏| 577/625 [05:50<00:16,  2.92batch/s]
# Generating 3Di tokens:  92%|█████████▏| 578/625 [05:50<00:14,  3.23batch/s]
# Generating 3Di tokens:  93%|█████████▎| 579/625 [05:51<00:15,  2.93batch/s]
# Generating 3Di tokens:  93%|█████████▎| 580/625 [05:52<00:29,  1.53batch/s]
# Generating 3Di tokens:  93%|█████████▎| 581/625 [05:53<00:26,  1.67batch/s]
# Generating 3Di tokens:  93%|█████████▎| 582/625 [05:53<00:25,  1.70batch/s]
# Generating 3Di tokens:  93%|█████████▎| 583/625 [05:54<00:21,  1.93batch/s]
# Generating 3Di tokens:  93%|█████████▎| 584/625 [05:54<00:19,  2.10batch/s]
# Generating 3Di tokens:  94%|█████████▎| 585/625 [05:55<00:29,  1.34batch/s]
# Generating 3Di tokens:  94%|█████████▍| 586/625 [05:56<00:24,  1.57batch/s]
# Generating 3Di tokens:  94%|█████████▍| 587/625 [05:56<00:19,  1.92batch/s]
# Generating 3Di tokens:  94%|█████████▍| 588/625 [05:57<00:21,  1.72batch/s]
# Generating 3Di tokens:  94%|█████████▍| 589/625 [05:57<00:20,  1.73batch/s]
# Generating 3Di tokens:  94%|█████████▍| 590/625 [05:57<00:16,  2.14batch/s]
# Generating 3Di tokens:  95%|█████████▍| 591/625 [05:58<00:14,  2.40batch/s]
# Generating 3Di tokens:  95%|█████████▍| 592/625 [06:00<00:30,  1.10batch/s]
# Generating 3Di tokens:  95%|█████████▍| 593/625 [06:01<00:35,  1.12s/batch]
# Generating 3Di tokens:  95%|█████████▌| 594/625 [06:02<00:31,  1.00s/batch]
# Generating 3Di tokens:  95%|█████████▌| 595/625 [06:02<00:23,  1.28batch/s]
# Generating 3Di tokens:  95%|█████████▌| 596/625 [06:03<00:20,  1.39batch/s]
# Generating 3Di tokens:  96%|█████████▌| 597/625 [06:06<00:42,  1.51s/batch]
# Generating 3Di tokens:  96%|█████████▌| 598/625 [06:07<00:30,  1.12s/batch]
# Generating 3Di tokens:  96%|█████████▌| 599/625 [06:07<00:22,  1.13batch/s]
# Generating 3Di tokens:  96%|█████████▌| 600/625 [06:07<00:19,  1.27batch/s]
# Generating 3Di tokens:  96%|█████████▌| 601/625 [06:08<00:14,  1.61batch/s]
# Generating 3Di tokens:  96%|█████████▋| 602/625 [06:08<00:13,  1.71batch/s]
# Generating 3Di tokens:  96%|█████████▋| 603/625 [06:09<00:15,  1.44batch/s]
# Generating 3Di tokens:  97%|█████████▋| 604/625 [06:10<00:15,  1.36batch/s]
# Generating 3Di tokens:  97%|█████████▋| 605/625 [06:10<00:12,  1.58batch/s]
# Generating 3Di tokens:  97%|█████████▋| 606/625 [06:11<00:10,  1.83batch/s]
# Generating 3Di tokens:  97%|█████████▋| 607/625 [06:11<00:10,  1.78batch/s]
# Generating 3Di tokens:  97%|█████████▋| 608/625 [06:12<00:11,  1.44batch/s]
# Generating 3Di tokens:  97%|█████████▋| 609/625 [06:13<00:09,  1.66batch/s]
# Generating 3Di tokens:  98%|█████████▊| 610/625 [06:13<00:08,  1.71batch/s]
# Generating 3Di tokens:  98%|█████████▊| 611/625 [06:14<00:08,  1.65batch/s]
# Generating 3Di tokens:  98%|█████████▊| 612/625 [06:14<00:06,  1.89batch/s]
# Generating 3Di tokens:  98%|█████████▊| 613/625 [06:17<00:16,  1.33s/batch]
# Generating 3Di tokens:  98%|█████████▊| 614/625 [06:18<00:11,  1.08s/batch]
# Generating 3Di tokens:  98%|█████████▊| 615/625 [06:18<00:09,  1.11batch/s]
# Generating 3Di tokens:  99%|█████████▊| 616/625 [06:19<00:06,  1.39batch/s]
# Generating 3Di tokens:  99%|█████████▊| 617/625 [06:20<00:06,  1.31batch/s]
# Generating 3Di tokens:  99%|█████████▉| 618/625 [06:20<00:04,  1.71batch/s]
# Generating 3Di tokens:  99%|█████████▉| 619/625 [06:20<00:03,  1.65batch/s]
# Generating 3Di tokens:  99%|█████████▉| 620/625 [06:21<00:02,  1.86batch/s]
# Generating 3Di tokens:  99%|█████████▉| 621/625 [06:21<00:02,  1.92batch/s]
# Generating 3Di tokens: 100%|█████████▉| 622/625 [06:22<00:01,  1.89batch/s]
# Generating 3Di tokens: 100%|█████████▉| 623/625 [06:22<00:00,  2.33batch/s]
# Generating 3Di tokens: 100%|█████████▉| 624/625 [06:22<00:00,  2.88batch/s]
# Generating 3Di tokens: 100%|██████████| 625/625 [06:23<00:00,  2.79batch/s]
#
# 15:58:43 [INFO] Saved predicted 3Di sequences to: /users/fweikert/ESM3di/esm3di_inference/benchmark/data/foldseek/metavr_esm3di_temp_3di.fasta
# 15:58:43 [INFO] Building Foldseek database at: /users/fweikert/ESM3di/esm3di_inference/benchmark/data/foldseek/metavr_esm3di
# 15:58:43 [INFO] Foldseek database generated successfully.

# %% [markdown]
# ### 3Di FASTA Extraction, Foldseek Alignment & Metric Evaluation
# Extract 3Di FASTA files from the Foldseek databases, align predictions against AF3 ground truth, and calculate both **bitscores** and **3Di sequence identity**.

# %%
# --- 1. Extract 3Di Sequences to FASTA Files ---
def convert_db_3di_to_fasta(db_prefix: Path, out_fasta: Path):
    """Extracts 3Di sequences from Foldseek _ss database into a standard FASTA file."""
    # Link header DB to secondary structure DB and dump FASTA
    run_cmd(f"foldseek base:lndb '{db_prefix}_h' '{db_prefix}_ss_h'", silent=True)
    run_cmd(f"foldseek convert2fasta '{db_prefix}_ss' '{out_fasta}'", silent=True)

print("Extracting 3Di FASTA sequences from Foldseek DBs...")
convert_db_3di_to_fasta(af3_db, META_DIR / "metavr_af3_3di.fa")
convert_db_3di_to_fasta(prost_db, META_DIR / "metavr_prostt5_3di.fa")
convert_db_3di_to_fasta(esm_db, META_DIR / "metavr_esm3di_3di.fa")
print("3Di FASTA files generated successfully!")


# --- 2. Prefilter & Foldseek Structure Alignment ---
def get_foldseek_header_map(db_prefix: Path) -> dict[str, int]:
    """Parses Foldseek's binary _h database using byte offsets from _h.index."""
    idx_path = db_prefix.with_name(f"{db_prefix.name}_h.index")
    hdr_path = db_prefix.with_name(f"{db_prefix.name}_h")

    header_to_id = {}
    with open(idx_path, "r", encoding="utf-8") as f_idx, open(hdr_path, "rb") as f_hdr:
        for line in f_idx:
            parts = line.strip().split("\t")
            if len(parts) < 3:
                continue
            key = int(parts[0])      # True internal Foldseek entry ID
            offset = int(parts[1])   # Byte offset in _h
            length = int(parts[2])   # Byte length in _h

            f_hdr.seek(offset)
            raw_bytes = f_hdr.read(length)
            # Clean null bytes and extract primary header identifier
            hdr_str = raw_bytes.decode("latin1").replace("\x00", "").strip().split()[0]
            header_to_id[hdr_str] = key

    return header_to_id


def create_1v1_prefilter(query_prefix: Path, target_prefix: Path, out_tsv: Path, out_db: Path):
    """Generates a 1-vs-1 mapping prefilter DB for Foldseek structurealign."""
    q_map = get_foldseek_header_map(query_prefix)
    t_map = get_foldseek_header_map(target_prefix)

    pairs = []
    for hdr, q_id in q_map.items():
        if hdr in t_map:
            pairs.append((q_id, t_map[hdr]))

    if not pairs:
        raise RuntimeError(f"No matching headers found between {query_prefix.name} and {target_prefix.name}")

    pd.DataFrame(pairs).to_csv(out_tsv, sep="\t", header=False, index=False)
    run_cmd(f"foldseek base:tsv2db '{out_tsv}' '{out_db}' --output-dbtype 7", silent=True)


def run_foldseek_alignment(query_db: Path, target_db: Path, pref_db: Path, out_prefix: Path) -> pd.DataFrame:
    """Runs structurealign and returns a formatted DataFrame containing bitscores."""
    aln_db = out_prefix.with_suffix(".aln")
    tsv_out = out_prefix.with_suffix(".tsv")
    fields = "query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits"

    run_cmd(f"foldseek structurealign -e INF '{query_db}' '{target_db}' '{pref_db}' '{aln_db}'", silent=True)
    run_cmd(f"foldseek convertalis '{query_db}' '{target_db}' '{aln_db}' '{tsv_out}' --format-output '{fields}'", silent=True)
    return pd.read_csv(tsv_out, sep="\t", names=fields.split(","))

print("\nAligning ProstT5 vs AF3...")
create_1v1_prefilter(prost_db, af3_db, META_DIR / "prost_pref.tsv", FS_DIR / "prost_pref")
df_prost = run_foldseek_alignment(prost_db, af3_db, FS_DIR / "prost_pref", FS_DIR / "prost_aln")

print("Aligning ESM3Di vs AF3...")
create_1v1_prefilter(esm_db, af3_db, META_DIR / "esm_pref.tsv", FS_DIR / "esm_pref")
df_esm = run_foldseek_alignment(esm_db, af3_db, FS_DIR / "esm_pref", FS_DIR / "esm_aln")


# --- 3. Compute 3Di Sequence Identities ---
af3_seqs = parse_fasta(META_DIR / "metavr_af3_3di.fa")
prost_seqs = parse_fasta(META_DIR / "metavr_prostt5_3di.fa")
esm_seqs = parse_fasta(META_DIR / "metavr_esm3di_3di.fa")

identities = []
for seq_id, af3_seq in af3_seqs.items():
    if seq_id in prost_seqs and seq_id in esm_seqs:
        p_seq, e_seq = prost_seqs[seq_id], esm_seqs[seq_id]
        if len(af3_seq) == len(p_seq) == len(e_seq):
            identities.append({
                "query": seq_id,
                "prostt5_identity": sum(a == b for a, b in zip(af3_seq, p_seq)) / len(af3_seq) * 100,
                "esm3di_identity": sum(a == b for a, b in zip(af3_seq, e_seq)) / len(af3_seq) * 100
            })

# --- 4. Merge Bitscores and Identities into Unified Benchmark DataFrame ---
df_benchmark = (
    df_prost[["query", "bits"]]
    .rename(columns={"bits": "prostt5_bitscore"})
    .merge(df_esm[["query", "bits"]].rename(columns={"bits": "esm3di_bitscore"}), on="query")
    .merge(pd.DataFrame(identities), on="query")
)

print(f"\nBenchmark dataset ready. Total sequences matched: {len(df_benchmark)}")
df_benchmark.head()
# Out:
# Extracting 3Di FASTA sequences from Foldseek DBs...
# 3Di FASTA files generated successfully!
#
# Aligning ProstT5 vs AF3...
# Aligning ESM3Di vs AF3...
#
# Benchmark dataset ready. Total sequences matched: 9999
#                 query  prostt5_bitscore  esm3di_bitscore  prostt5_identity  \
# 0  imgvr_pc_000161154               297              308         97.500000
# 1  imgvr_pc_000163847               575              643         54.368932
# 2  imgvr_pc_000166228               418              374         58.666667
# 3  imgvr_pc_000168374              1116             1130         52.249135
# 4  imgvr_pc_000179083              1099             1035         62.146893
#
#    esm3di_identity
# 0       100.000000
# 1        60.194175
# 2        52.000000
# 3        53.979239
# 4        57.062147

# %% [markdown]
# ### Benchmark Results: Bitscores & 3Di Sequence Identity
# Compare **ProstT5** and **ESM3Di** performance directly against AlphaFold3 ground truth representations.

# %%
def plot_benchmark_comparison(df, x_col, y_col, x_label, y_label, title, kind="scatter", gridsize=30, ax=None):
    if ax is None:
        fig, ax = plt.subplots(figsize=(6, 6))

    x, y = df[x_col].values, df[y_col].values
    if len(df) == 0:
        return ax

    n_total = len(df)
    n_above, n_below = np.sum(y > x), np.sum(y < x)
    pct_above, pct_below = (n_above / n_total) * 100, (n_below / n_total) * 100

    # Dynamic limits: Fixed cap at 100 for percentages, otherwise dynamic max
    max_val = max(x.max(), y.max())
    if "identity" in x_col.lower() and max_val <= 100:
        lim = 100.0
    else:
        lim = max_val * 1.05 if max_val > 0 else 1.0

    ax.set_xlim(0, lim)
    ax.set_ylim(0, lim)
    ax.set_aspect("equal", adjustable="box")

    # Render points using identical styling rules
    if kind == "hexbin" and len(df) > 10:
        hb = ax.hexbin(x, y, gridsize=gridsize, extent=(0, lim, 0, lim), cmap="viridis", mincnt=1)
        cb = plt.colorbar(hb, ax=ax, label="Count", fraction=0.046, pad=0.04)
        cb.ax.tick_params(labelsize=9)
    else:
        ax.scatter(x, y, alpha=0.6, edgecolors="none", color="#1f77b4", s=35)

    # Reference Identity line y = x
    ax.plot([0, lim], [0, lim], color="#d62728", linestyle="--", linewidth=1.5, label="y = x")

    # Annotations
    bbox_props = dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.85, edgecolor="none")
    ax.text(0.30, 0.75, f"ESM3Di Higher\n{n_above} ({pct_above:.1f}%)", transform=ax.transAxes, ha="center", va="center", fontsize=10, fontweight="bold", bbox=bbox_props)
    ax.text(0.75, 0.30, f"ProstT5 Higher\n{n_below} ({pct_below:.1f}%)", transform=ax.transAxes, ha="center", va="center", fontsize=10, fontweight="bold", bbox=bbox_props)

    # Styling
    ax.set_xlabel(x_label, fontsize=11)
    ax.set_ylabel(y_label, fontsize=11)
    ax.set_title(title, fontsize=12, fontweight="bold", pad=10)
    ax.grid(True, linestyle=":", alpha=0.5)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

    return ax


# Set a uniform style for both subplots ("scatter" or "hexbin")
PLOT_STYLE = "scatter"  # Switch to "hexbin" if scaling up to thousands of sequences

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot 1: Bitscores
plot_benchmark_comparison(
    df=df_benchmark,
    x_col="prostt5_bitscore",
    y_col="esm3di_bitscore",
    x_label="ProstT5 Bitscore",
    y_label="ESM3Di Bitscore",
    title="Foldseek Alignment Bitscores vs AF3",
    kind=PLOT_STYLE,
    ax=axes[0]
)

# Plot 2: 3Di Identity
plot_benchmark_comparison(
    df=df_benchmark,
    x_col="prostt5_identity",
    y_col="esm3di_identity",
    x_label="ProstT5 3Di Identity (%)",
    y_label="ESM3Di 3Di Identity (%)",
    title="3Di Sequence Identity vs AF3",
    kind=PLOT_STYLE,
    ax=axes[1]
)

plt.tight_layout()
plt.show()

# --- Print Summary Metrics ---
print("\n" + "=" * 45)
print("             BENCHMARK SUMMARY             ")
print("=" * 45)
summary_df = pd.DataFrame({
    "Metric": ["Mean Bitscore", "Median Bitscore", "Mean 3Di Identity (%)", "Median 3Di Identity (%)"],
    "ProstT5": [
        df_benchmark["prostt5_bitscore"].mean(),
        df_benchmark["prostt5_bitscore"].median(),
        df_benchmark["prostt5_identity"].mean(),
        df_benchmark["prostt5_identity"].median(),
    ],
    "ESM3Di": [
        df_benchmark["esm3di_bitscore"].mean(),
        df_benchmark["esm3di_bitscore"].median(),
        df_benchmark["esm3di_identity"].mean(),
        df_benchmark["esm3di_identity"].median(),
    ]
})
print(summary_df.to_string(index=False))
# Out:
# =============================================
#              BENCHMARK SUMMARY
# =============================================
#                  Metric     ProstT5      ESM3Di
#           Mean Bitscore 1100.760476 1113.849285
#         Median Bitscore  652.000000  668.000000
#   Mean 3Di Identity (%)   58.128090   60.501313
# Median 3Di Identity (%)   58.050847   60.273973
