# %% [markdown]
# # 3Di Alignment Benchmark
#
# ## Description
#
# We compare the performance of ESM3Di against ProstT5 on the MetaVR sequence set.
#
# We have 3 different 3Di representations of the MetaVR sequence set:
# * **AF3**: 3Di generated by Foldseek based on the predicted AlphaFold3 structures of the MetaVR sequence set.
# * **ProstT5**: 3Di generated by ProstT5 based on the sequences of the MetaVR sequence set.
# * **ESM3Di**: 3Di generated by ESM3Di based on the sequences of the MetaVR sequence set.
#
# We compile each representation into a Foldseek database and run Foldseek's `structurealign` module on a 1-vs-1 basis (aligning identical entries).
#
# The results are represented as the **bitscore** of the alignment and **3Di sequence identity**.
#
# The **bitscore** is a measure of the overall similarity between two aligned 3Di sequences. It rewards long, well-matching alignments while penalizing mismatches and gaps, with higher bitscores indicating more similar 3Di representations.
#
# The **3Di sequence identity** is calculated as:
#
# $$
# \text{Identity} = \frac{\text{\# of residues with identical 3Di}}{\text{\# of residues}}
# $$

# %%
import torch
import socket

print("Running on node:", socket.gethostname())
print("GPU available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Device name:", torch.cuda.get_device_name(0))
# Out:
# Running on node: dnagpu001
# GPU available: True
# Device name: NVIDIA A100-PCIE-40GB MIG 3g.20gb

# %%
import shutil
import os

# Optional: Add local foldseek directory to PATH if installed in project folder
os.environ["PATH"] += os.pathsep + "/users/fweikert/ESM3di/foldseek/bin"

if not shutil.which("foldseek"):
    raise FileNotFoundError(
        "Foldseek binary not found in PATH. "
        "Please download the standalone binary or load the appropriate cluster module."
    )
else:
    print(f"Foldseek is ready to use at: {shutil.which('foldseek')}")
# Out:
# Foldseek is ready to use at: /users/fweikert/miniforge3/bin/foldseek

# %%
import os
import subprocess
from pathlib import Path

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch

# --- Configuration ---
#DATAPATH = Path("./data") # !! SET THIS BACK !!
DATAPATH = Path("/scratch/fweikert/data")  # !! SET THIS BACK !!
DATAPATH.mkdir(parents=True, exist_ok=True)

FS_DIR = DATAPATH / "foldseek"
META_DIR = DATAPATH / "metavr"
FS_DIR.mkdir(exist_ok=True)
META_DIR.mkdir(exist_ok=True)

# --- Utility Functions ---
def run_cmd(cmd, silent=False):
    # Pass os.environ.copy() to preserve GPU/CUDA settings
    process = subprocess.Popen(
        cmd,
        shell=True,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,  # Merge stderr into stdout so they stream in order
        text=True,
        bufsize=1,  # Line-buffered
        env=os.environ.copy()
    )

    output_lines = []

    # Read output line-by-line in real time
    for line in iter(process.stdout.readline, ''):
        output_lines.append(line)
        if not silent:
            print(line, end='', flush=True)  # Print immediately to terminal/Jupyter

    process.stdout.close()
    return_code = process.wait()

    if return_code != 0:
        error_msg = "".join(output_lines)
        raise RuntimeError(f"Command failed with exit code {return_code}:\n{cmd}\n\nOutput:\n{error_msg}")

def write_fasta(sequences: dict[str, str], filepath: Path):
    """Writes a dictionary of {id: sequence} to a FASTA file."""
    with open(filepath, "w") as f:
        for seq_id, seq in sequences.items():
            f.write(f">{seq_id}\n{seq}\n")

def parse_fasta(fasta_path: Path) -> dict[str, str]:
    """Reads a FASTA file into a {id: sequence} dictionary."""
    seqs, hdr = {}, None
    with open(fasta_path) as f:
        for line in f:
            line = line.strip()
            if line.startswith(">"):
                hdr = line[1:].split()[0]
                seqs[hdr] = ""
            elif hdr:
                seqs[hdr] += line
    return seqs

# %%
import tarfile
from curl_cffi import requests
from tqdm import tqdm

tar_path = META_DIR / "partial_download.tar.gz"
url = "https://www.meta-virome.org/Data/Downloads/IMGVR5_PC_3Dmodels.tar.gz"

max_bytes = 1024 * 1024 * 1024  # 1 GB cap
downloaded = 0

print("1. Downloading first 1 GB using browser TLS impersonation...")

response = requests.get(url, impersonate="chrome", stream=True)

if response.status_code != 200:
    print(f"Failed with status code: {response.status_code}")
else:
    # Stream download with progress bar
    with open(tar_path, "wb") as f, tqdm(
        total=max_bytes,
        unit="B",
        unit_scale=True,
        unit_divisor=1024,
        desc="Downloading 1GB sample",
    ) as pbar:
        for chunk in response.iter_content(chunk_size=1024 * 1024):
            if not chunk:
                continue

            # Ensure we stop precisely at the 1 GB cap
            bytes_to_write = min(len(chunk), max_bytes - downloaded)
            f.write(chunk[:bytes_to_write])
            downloaded += bytes_to_write
            pbar.update(bytes_to_write)

            if downloaded >= max_bytes:
                break

    print(f"\nDownloaded {downloaded / (1024 * 1024):.2f} MB to {tar_path}")

    print("2. Extracting structures...")

    # Stream mode ("r|gz") reads sequentially and avoids pre-scanning the full file
    try:
        with tarfile.open(tar_path, "r|gz") as tar:
            while True:
                try:
                    member = tar.next()
                    if member is None:
                        break
                    tar.extract(member, path=META_DIR)
                except (EOFError, tarfile.TarError, OSError):
                    # Gracefully stop extraction at the truncated cutoff point
                    print("\nReached the end of the truncated 1 GB stream.")
                    break
    except Exception as e:
        print(f"\nExtraction finished with notice: {e}")

    # Clean up archive file
    if tar_path.exists():
        tar_path.unlink()

    # Count extracted files
    extracted_files = sum(1 for _ in META_DIR.glob("**/*") if _.is_file())
    print(f"3. Done! Total extracted files: {extracted_files}")
# Out:
# 1. Downloading first 1 GB using browser TLS impersonation...
# Downloading 1GB sample: 100%|██████████| 1.00G/1.00G [00:15<00:00, 71.3MB/s]
# Downloaded 1024.00 MB to /scratch/fweikert/data/metavr/partial_download.tar.gz
# 2. Extracting structures...
#
# Reached the end of the truncated 1 GB stream.
# 3. Done! Total extracted files: 25338

# %%
import os
import random
import shutil


def sample_structures(source_dir, output_dir, n_samples=500, seed=42):
    """Samples `n_samples` PDB/CIF files from source_dir into output_dir."""
    random.seed(seed)  # Fixed seed ensures reproducible sampling
    os.makedirs(output_dir, exist_ok=True)

    # Find all 3D structure files
    valid_exts = (".pdb", ".cif", ".ent", ".pdb.gz", ".cif.gz")
    all_files = [
        f
        for f in os.listdir(source_dir)
        if f.lower().endswith(valid_exts)
        and os.path.isfile(os.path.join(source_dir, f))
    ]

    if not all_files:
        print(f"Error: No structure files found in '{source_dir}'")
        return

    sample_size = min(n_samples, len(all_files))
    sampled_files = random.sample(all_files, sample_size)

    print(f"Found {len(all_files)} structure files in '{source_dir}'.")
    print(f"Copying {sample_size} files to '{output_dir}'...")

    for file_name in sampled_files:
        src = os.path.join(source_dir, file_name)
        dst = os.path.join(output_dir, file_name)
        shutil.copy2(src, dst)

    print(f"Done! Sampled {sample_size} structures successfully.\n")

# %%
n = 10000
SAMPLE_DIR = META_DIR / f"metaVR_structures_{n}"

sample_structures(
    META_DIR / "metaVR_structures_all",
    SAMPLE_DIR,
    n_samples=n,
    seed=42,
)
# Out:
# Found 25338 structure files in '/scratch/fweikert/data/metavr/metaVR_structures_all'.
# Copying 10000 files to '/scratch/fweikert/data/metavr/metaVR_structures_10000'...
# Done! Sampled 10000 structures successfully.

# %% [markdown]
# ### Ground Truth 3Di from AlphaFold3

# %%
af3_db = FS_DIR / "metavr_af3"
fasta = META_DIR / "input_aa.fasta"

# 1. Create the Foldseek database directly from the directory of .cif files
print("Creating Foldseek DB from CIF folder...")
run_cmd(f"foldseek createdb '{SAMPLE_DIR}' '{af3_db}'")

# 2. Export the amino acid sequences from the DB to a standard FASTA file
print("Exporting AA sequences to FASTA...")
run_cmd(f"foldseek convert2fasta '{af3_db}' '{fasta}'")

# 3. Verify the sequence count
aa_seqs = parse_fasta(fasta)
print(f"Successfully extracted {len(aa_seqs)} sequences to {fasta}")
# Out:
# Creating Foldseek DB from CIF folder...
# createdb /scratch/fweikert/data/metavr/metaVR_structures_10000 /scratch/fweikert/data/foldseek/metavr_af3
#
# MMseqs Version:             	10.941cd33
# Use GPU                     	0
# Path to ProstT5
# Chain name mode             	0
# Createdb extraction mode    	0
# Interface distance threshold	8
# Write mapping file          	0
# Mask b-factor threshold     	0
# Coord store mode            	2
# Write lookup file           	1
# Input format                	0
# File Inclusion Regex        	.*
# File Exclusion Regex        	^$
# Threads                     	48
# Verbosity                   	3
#
# Output file: /scratch/fweikert/data/foldseek/metavr_af3
# [=================================================================] 10.00K 37s 335ms
# Time for merging to metavr_af3_ss: 0h 0m 0s 38ms
# Time for merging to metavr_af3_h: 0h 0m 0s 38ms
# Time for merging to metavr_af3_ca: 0h 0m 0s 44ms
# Time for merging to metavr_af3: 0h 0m 0s 40ms
# Ignore 1 out of 9999.
# Too short: 0, incorrect: 1, not proteins: 0.
# Time for processing: 0h 0m 37s 683ms
# Exporting AA sequences to FASTA...
# convert2fasta /scratch/fweikert/data/foldseek/metavr_af3 /scratch/fweikert/data/metavr/input_aa.fasta
#
# MMseqs Version:	10.941cd33
# Use header DB	false
# Verbosity    	3
#
# Start writing file to /scratch/fweikert/data/metavr/input_aa.fasta
# Time for processing: 0h 0m 0s 22ms
# Successfully extracted 9999 sequences to /scratch/fweikert/data/metavr/input_aa.fasta

# %% [markdown]
# ### Predict 3Di with ProstT5 (General Purpose)

# %%
prost_db = FS_DIR / "metavr_prostt5"

prostt5_weights = DATAPATH / "prostt5_weights"
tmp = DATAPATH / "tmp"
prostt5_weights.mkdir(exist_ok=True)
tmp.mkdir(exist_ok=True)

# if empty directory, download weights
if not any(prostt5_weights.iterdir()):
    run_cmd(
        f"foldseek databases ProstT5 '{prostt5_weights}' '{tmp}'"
    )
else:
    print("Weights already loaded, creating foldseek database...")

# clean up temporary directory
if tmp.exists():
    shutil.rmtree(tmp)

# 4. Create the Foldseek database using the downloaded weights
run_cmd(
    f"foldseek createdb \
    '{fasta}' \
    '{prost_db}' \
    --gpu 1 \
    --prostt5-model '{prostt5_weights}'"
)
# Out:
# /scratch/fweikert/data/prostt5_weights exists and will be overwritten
# databases ProstT5 /scratch/fweikert/data/prostt5_weights /scratch/fweikert/data/tmp
#
# MMseqs Version:              	10.941cd33
# Tsv                          	false
# Force restart with latest tmp	false
# Remove temporary files       	false
# Compressed                   	0
# Threads                      	48
# Verbosity                    	3
#
#
# 09/14 17:18:45 [NOTICE] Downloading 1 item(s)
# [#1410f5 256KiB/2.0GiB(0%) CN:5 DL:802KiB ETA:45m7s]
# [#1410f5 58MiB/2.0GiB(2%) CN:5 DL:44MiB ETA:46s]
# [#1410f5 228MiB/2.0GiB(10%) CN:5 DL:98MiB ETA:19s]
# [#1410f5 387MiB/2.0GiB(18%) CN:5 DL:117MiB ETA:14s]
# [#1410f5 543MiB/2.0GiB(25%) CN:5 DL:126MiB ETA:12s]
# [#1410f5 695MiB/2.0GiB(32%) CN:5 DL:131MiB ETA:10s]
# [#1410f5 847MiB/2.0GiB(39%) CN:5 DL:135MiB ETA:9s]
# [#1410f5 0.9GiB/2.0GiB(47%) CN:5 DL:137MiB ETA:8s]
# [#1410f5 1.1GiB/2.0GiB(55%) CN:5 DL:143MiB ETA:6s]
# [#1410f5 1.2GiB/2.0GiB(62%) CN:5 DL:142MiB ETA:5s]
# [#1410f5 1.4GiB/2.0GiB(68%) CN:5 DL:154MiB ETA:4s]
# [#1410f5 1.5GiB/2.0GiB(75%) CN:5 DL:154MiB ETA:3s]
# [#1410f5 1.7GiB/2.0GiB(83%) CN:5 DL:154MiB ETA:2s]
# [#1410f5 1.8GiB/2.0GiB(90%) CN:5 DL:155MiB ETA:1s]
# [#1410f5 1.9GiB/2.0GiB(95%) CN:5 DL:150MiB]
# [#1410f5 2.0GiB/2.0GiB(99%) CN:1 DL:141MiB]
#
# 09/14 17:19:01 [NOTICE] Download complete: /scratch/fweikert/data/tmp/4165020037037928778/prostt5-f16-gguf.tar.gz
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 1410f5|OK  |   138MiB/s|/scratch/fweikert/data/tmp/4165020037037928778/prostt5-f16-gguf.tar.gz
#
# Status Legend:
# (OK):download completed.
# prostt5-f16.gguf
# createdb /scratch/fweikert/data/metavr/input_aa.fasta /scratch/fweikert/data/foldseek/metavr_prostt5 --gpu 1 --prostt5-model /scratch/fweikert/data/prostt5_weights
#
# MMseqs Version:             	10.941cd33
# Use GPU                     	1
# Path to ProstT5             	/scratch/fweikert/data/prostt5_weights
# Chain name mode             	0
# Createdb extraction mode    	0
# Interface distance threshold	8
# Write mapping file          	0
# Mask b-factor threshold     	0
# Coord store mode            	2
# Write lookup file           	1
# Input format                	0
# File Inclusion Regex        	.*
# File Exclusion Regex        	^$
# Threads                     	48
# Verbosity                   	3
#
# Converting sequences
# [
# Time for merging to metavr_prostt5_h: 0h 0m 0s 12ms
# Time for merging to metavr_prostt5: 0h 0m 0s 14ms
# Database type: Aminoacid
# CUDA0
# CPU
# [=================================================================] 10.00K 9m 21s 719ms
# Time for merging to metavr_prostt5_ss: 0h 0m 0s 12ms
# Time for merging to metavr_prostt5_ss_tmp: 0h 0m 0s 16ms
# Time for processing: 0h 9m 21s 965ms

# %% [markdown]
# ### Predict 3Di with ESM3Di (Fine tuned for viral structure)

# %%
esm_db = FS_DIR / "metavr_esm3di"

run_cmd(
    f"esm3di foldseek-db \
    --input-fasta '{fasta}' \
    --output-db '{esm_db}' \
    --batch-size 16"
    )
# Out:
# 17:43:26 [INFO] 'Downloading model cactuskid13/ESM3di_Small_MLM_3di' from Hugging Face Hub...
#
# Fetching 7 files:   0%|          | 0/7 [00:00<?, ?it/s]
# Fetching 7 files: 100%|██████████| 7/7 [00:00<00:00, 2153.29it/s]
# 17:43:28 [INFO] Using device: cuda (NVIDIA A100-PCIE-40GB MIG 3g.20gb)
# 17:43:28 [INFO] Reading sequence inputs from: /scratch/fweikert/data/metavr/input_aa.fasta
#
# Generating 3Di tokens:   0%|          | 0/625 [00:00<?, ?batch/s]
# Generating 3Di tokens:   0%|          | 1/625 [00:01<20:34,  1.98s/batch]
# Generating 3Di tokens:   0%|          | 2/625 [00:02<11:41,  1.13s/batch]
# Generating 3Di tokens:   0%|          | 3/625 [00:02<08:18,  1.25batch/s]
# Generating 3Di tokens:   1%|          | 4/625 [00:03<08:05,  1.28batch/s]
# Generating 3Di tokens:   1%|          | 5/625 [00:04<06:45,  1.53batch/s]
# Generating 3Di tokens:   1%|          | 6/625 [00:05<08:36,  1.20batch/s]
# Generating 3Di tokens:   1%|          | 7/625 [00:08<16:06,  1.56s/batch]
# Generating 3Di tokens:   1%|▏         | 8/625 [00:09<13:55,  1.35s/batch]
# Generating 3Di tokens:   1%|▏         | 9/625 [00:09<11:08,  1.09s/batch]
# Generating 3Di tokens:   2%|▏         | 10/625 [00:10<08:59,  1.14batch/s]
# Generating 3Di tokens:   2%|▏         | 11/625 [00:11<10:38,  1.04s/batch]
# Generating 3Di tokens:   2%|▏         | 12/625 [00:12<09:09,  1.11batch/s]
# Generating 3Di tokens:   2%|▏         | 13/625 [00:12<08:27,  1.21batch/s]
# Generating 3Di tokens:   2%|▏         | 14/625 [00:13<07:50,  1.30batch/s]
# Generating 3Di tokens:   2%|▏         | 15/625 [00:14<09:29,  1.07batch/s]
# Generating 3Di tokens:   3%|▎         | 16/625 [00:15<08:06,  1.25batch/s]
# Generating 3Di tokens:   3%|▎         | 17/625 [00:16<08:35,  1.18batch/s]
# Generating 3Di tokens:   3%|▎         | 18/625 [00:16<07:27,  1.36batch/s]
# Generating 3Di tokens:   3%|▎         | 19/625 [00:17<07:24,  1.36batch/s]
# Generating 3Di tokens:   3%|▎         | 20/625 [00:18<07:45,  1.30batch/s]
# Generating 3Di tokens:   3%|▎         | 21/625 [00:19<08:25,  1.20batch/s]
# Generating 3Di tokens:   4%|▎         | 22/625 [00:20<09:11,  1.09batch/s]
# Generating 3Di tokens:   4%|▎         | 23/625 [00:22<11:54,  1.19s/batch]
# Generating 3Di tokens:   4%|▍         | 24/625 [00:22<09:52,  1.01batch/s]
# Generating 3Di tokens:   4%|▍         | 25/625 [00:23<09:04,  1.10batch/s]
# Generating 3Di tokens:   4%|▍         | 26/625 [00:24<09:49,  1.02batch/s]
# Generating 3Di tokens:   4%|▍         | 27/625 [00:25<08:18,  1.20batch/s]
# Generating 3Di tokens:   4%|▍         | 28/625 [00:25<07:30,  1.33batch/s]
# Generating 3Di tokens:   5%|▍         | 29/625 [00:26<07:36,  1.31batch/s]
# Generating 3Di tokens:   5%|▍         | 30/625 [00:26<06:34,  1.51batch/s]
# Generating 3Di tokens:   5%|▍         | 31/625 [00:28<08:35,  1.15batch/s]
# Generating 3Di tokens:   5%|▌         | 32/625 [00:28<08:07,  1.22batch/s]
# Generating 3Di tokens:   5%|▌         | 33/625 [00:29<08:15,  1.20batch/s]
# Generating 3Di tokens:   5%|▌         | 34/625 [00:30<09:00,  1.09batch/s]
# Generating 3Di tokens:   6%|▌         | 35/625 [00:33<12:58,  1.32s/batch]
# Generating 3Di tokens:   6%|▌         | 36/625 [00:33<10:12,  1.04s/batch]
# Generating 3Di tokens:   6%|▌         | 37/625 [00:33<08:04,  1.21batch/s]
# Generating 3Di tokens:   6%|▌         | 38/625 [00:36<12:30,  1.28s/batch]
# Generating 3Di tokens:   6%|▌         | 39/625 [00:38<14:29,  1.48s/batch]
# Generating 3Di tokens:   6%|▋         | 40/625 [00:38<12:06,  1.24s/batch]
# Generating 3Di tokens:   7%|▋         | 41/625 [00:39<10:16,  1.06s/batch]
# Generating 3Di tokens:   7%|▋         | 42/625 [00:39<08:34,  1.13batch/s]
# Generating 3Di tokens:   7%|▋         | 43/625 [00:40<08:52,  1.09batch/s]
# Generating 3Di tokens:   7%|▋         | 44/625 [00:41<07:17,  1.33batch/s]
# Generating 3Di tokens:   7%|▋         | 45/625 [00:41<06:53,  1.40batch/s]
# Generating 3Di tokens:   7%|▋         | 46/625 [00:42<06:36,  1.46batch/s]
# Generating 3Di tokens:   8%|▊         | 47/625 [00:42<05:20,  1.80batch/s]
# Generating 3Di tokens:   8%|▊         | 48/625 [00:43<05:31,  1.74batch/s]
# Generating 3Di tokens:   8%|▊         | 49/625 [00:45<09:11,  1.04batch/s]
# Generating 3Di tokens:   8%|▊         | 50/625 [00:46<09:17,  1.03batch/s]
# Generating 3Di tokens:   8%|▊         | 51/625 [00:47<08:45,  1.09batch/s]
# Generating 3Di tokens:   8%|▊         | 52/625 [00:47<07:12,  1.33batch/s]
# Generating 3Di tokens:   8%|▊         | 53/625 [00:48<08:48,  1.08batch/s]
# Generating 3Di tokens:   9%|▊         | 54/625 [00:49<07:23,  1.29batch/s]
# Generating 3Di tokens:   9%|▉         | 55/625 [00:50<08:02,  1.18batch/s]
# Generating 3Di tokens:   9%|▉         | 56/625 [00:51<08:11,  1.16batch/s]
# Generating 3Di tokens:   9%|▉         | 57/625 [00:51<06:49,  1.39batch/s]
# Generating 3Di tokens:   9%|▉         | 58/625 [00:52<06:23,  1.48batch/s]
# Generating 3Di tokens:   9%|▉         | 59/625 [00:52<05:55,  1.59batch/s]
# Generating 3Di tokens:  10%|▉         | 60/625 [00:53<05:40,  1.66batch/s]
# Generating 3Di tokens:  10%|▉         | 61/625 [01:02<30:01,  3.19s/batch]
# Generating 3Di tokens:  10%|▉         | 62/625 [01:03<25:31,  2.72s/batch]
# Generating 3Di tokens:  10%|█         | 63/625 [01:04<20:00,  2.14s/batch]
# Generating 3Di tokens:  10%|█         | 64/625 [01:05<15:20,  1.64s/batch]
# Generating 3Di tokens:  10%|█         | 65/625 [01:05<12:52,  1.38s/batch]
# Generating 3Di tokens:  11%|█         | 66/625 [01:06<10:00,  1.07s/batch]
# Generating 3Di tokens:  11%|█         | 67/625 [01:06<08:27,  1.10batch/s]
# Generating 3Di tokens:  11%|█         | 68/625 [01:09<13:39,  1.47s/batch]
# Generating 3Di tokens:  11%|█         | 69/625 [01:10<11:03,  1.19s/batch]
# Generating 3Di tokens:  11%|█         | 70/625 [01:11<12:36,  1.36s/batch]
# Generating 3Di tokens:  11%|█▏        | 71/625 [01:13<11:54,  1.29s/batch]
# Generating 3Di tokens:  12%|█▏        | 72/625 [01:14<11:35,  1.26s/batch]
# Generating 3Di tokens:  12%|█▏        | 73/625 [01:15<11:02,  1.20s/batch]
# Generating 3Di tokens:  12%|█▏        | 74/625 [01:15<08:31,  1.08batch/s]
# Generating 3Di tokens:  12%|█▏        | 75/625 [01:16<08:16,  1.11batch/s]
# Generating 3Di tokens:  12%|█▏        | 76/625 [01:16<07:06,  1.29batch/s]
# Generating 3Di tokens:  12%|█▏        | 77/625 [01:18<08:10,  1.12batch/s]
# Generating 3Di tokens:  12%|█▏        | 78/625 [01:19<09:09,  1.00s/batch]
# Generating 3Di tokens:  13%|█▎        | 79/625 [01:19<07:58,  1.14batch/s]
# Generating 3Di tokens:  13%|█▎        | 80/625 [01:21<10:35,  1.17s/batch]
# Generating 3Di tokens:  13%|█▎        | 81/625 [01:23<11:10,  1.23s/batch]
# Generating 3Di tokens:  13%|█▎        | 82/625 [01:23<09:44,  1.08s/batch]
# Generating 3Di tokens:  13%|█▎        | 83/625 [01:24<08:53,  1.02batch/s]
# Generating 3Di tokens:  13%|█▎        | 84/625 [01:26<10:43,  1.19s/batch]
# Generating 3Di tokens:  14%|█▎        | 85/625 [01:28<12:13,  1.36s/batch]
# Generating 3Di tokens:  14%|█▍        | 86/625 [01:29<11:02,  1.23s/batch]
# Generating 3Di tokens:  14%|█▍        | 87/625 [01:30<11:36,  1.30s/batch]
# Generating 3Di tokens:  14%|█▍        | 88/625 [01:30<09:18,  1.04s/batch]
# Generating 3Di tokens:  14%|█▍        | 89/625 [01:35<18:38,  2.09s/batch]
# Generating 3Di tokens:  14%|█▍        | 90/625 [01:36<15:55,  1.79s/batch]
# Generating 3Di tokens:  15%|█▍        | 91/625 [01:40<21:05,  2.37s/batch]
# Generating 3Di tokens:  15%|█▍        | 92/625 [01:40<16:25,  1.85s/batch]
# Generating 3Di tokens:  15%|█▍        | 93/625 [01:41<12:48,  1.44s/batch]
# Generating 3Di tokens:  15%|█▌        | 94/625 [01:41<10:30,  1.19s/batch]
# Generating 3Di tokens:  15%|█▌        | 95/625 [01:42<09:21,  1.06s/batch]
# Generating 3Di tokens:  15%|█▌        | 96/625 [01:44<09:57,  1.13s/batch]
# Generating 3Di tokens:  16%|█▌        | 97/625 [01:44<08:39,  1.02batch/s]
# Generating 3Di tokens:  16%|█▌        | 98/625 [01:45<07:53,  1.11batch/s]
# Generating 3Di tokens:  16%|█▌        | 99/625 [01:48<13:58,  1.59s/batch]
# Generating 3Di tokens:  16%|█▌        | 100/625 [01:48<10:33,  1.21s/batch]
# Generating 3Di tokens:  16%|█▌        | 101/625 [01:51<14:26,  1.65s/batch]
# Generating 3Di tokens:  16%|█▋        | 102/625 [01:52<11:38,  1.33s/batch]
# Generating 3Di tokens:  16%|█▋        | 103/625 [01:52<09:07,  1.05s/batch]
# Generating 3Di tokens:  17%|█▋        | 104/625 [01:53<08:03,  1.08batch/s]
# Generating 3Di tokens:  17%|█▋        | 105/625 [01:53<06:47,  1.27batch/s]
# Generating 3Di tokens:  17%|█▋        | 106/625 [01:54<08:10,  1.06batch/s]
# Generating 3Di tokens:  17%|█▋        | 107/625 [01:55<07:12,  1.20batch/s]
# Generating 3Di tokens:  17%|█▋        | 108/625 [01:56<07:29,  1.15batch/s]
# Generating 3Di tokens:  17%|█▋        | 109/625 [01:57<07:04,  1.22batch/s]
# Generating 3Di tokens:  18%|█▊        | 110/625 [01:57<06:51,  1.25batch/s]
# Generating 3Di tokens:  18%|█▊        | 111/625 [01:58<06:33,  1.31batch/s]
# Generating 3Di tokens:  18%|█▊        | 112/625 [01:59<06:36,  1.29batch/s]
# Generating 3Di tokens:  18%|█▊        | 113/625 [02:00<06:27,  1.32batch/s]
# Generating 3Di tokens:  18%|█▊        | 114/625 [02:01<07:18,  1.16batch/s]
# Generating 3Di tokens:  18%|█▊        | 115/625 [02:01<06:31,  1.30batch/s]
# Generating 3Di tokens:  19%|█▊        | 116/625 [02:02<05:36,  1.51batch/s]
# Generating 3Di tokens:  19%|█▊        | 117/625 [02:02<04:39,  1.82batch/s]
# Generating 3Di tokens:  19%|█▉        | 118/625 [02:03<05:44,  1.47batch/s]
# Generating 3Di tokens:  19%|█▉        | 119/625 [02:04<06:36,  1.28batch/s]
# Generating 3Di tokens:  19%|█▉        | 120/625 [02:05<07:31,  1.12batch/s]
# Generating 3Di tokens:  19%|█▉        | 121/625 [02:07<09:05,  1.08s/batch]
# Generating 3Di tokens:  20%|█▉        | 122/625 [02:08<08:24,  1.00s/batch]
# Generating 3Di tokens:  20%|█▉        | 123/625 [02:11<15:47,  1.89s/batch]
# Generating 3Di tokens:  20%|█▉        | 124/625 [02:12<11:49,  1.42s/batch]
# Generating 3Di tokens:  20%|██        | 125/625 [02:12<09:58,  1.20s/batch]
# Generating 3Di tokens:  20%|██        | 126/625 [02:13<08:53,  1.07s/batch]
# Generating 3Di tokens:  20%|██        | 127/625 [02:16<11:53,  1.43s/batch]
# Generating 3Di tokens:  20%|██        | 128/625 [02:16<10:03,  1.21s/batch]
# Generating 3Di tokens:  21%|██        | 129/625 [02:17<07:53,  1.05batch/s]
# Generating 3Di tokens:  21%|██        | 130/625 [02:17<06:50,  1.20batch/s]
# Generating 3Di tokens:  21%|██        | 131/625 [02:18<05:53,  1.40batch/s]
# Generating 3Di tokens:  21%|██        | 132/625 [02:19<06:41,  1.23batch/s]
# Generating 3Di tokens:  21%|██▏       | 133/625 [02:19<06:05,  1.35batch/s]
# Generating 3Di tokens:  21%|██▏       | 134/625 [02:22<11:03,  1.35s/batch]
# Generating 3Di tokens:  22%|██▏       | 135/625 [02:30<28:06,  3.44s/batch]
# Generating 3Di tokens:  22%|██▏       | 136/625 [02:31<21:05,  2.59s/batch]
# Generating 3Di tokens:  22%|██▏       | 137/625 [02:32<16:47,  2.06s/batch]
# Generating 3Di tokens:  22%|██▏       | 138/625 [02:34<16:14,  2.00s/batch]
# Generating 3Di tokens:  22%|██▏       | 139/625 [02:34<13:23,  1.65s/batch]
# Generating 3Di tokens:  22%|██▏       | 140/625 [02:35<10:20,  1.28s/batch]
# Generating 3Di tokens:  23%|██▎       | 141/625 [02:35<08:30,  1.06s/batch]
# Generating 3Di tokens:  23%|██▎       | 142/625 [02:37<08:45,  1.09s/batch]
# Generating 3Di tokens:  23%|██▎       | 143/625 [02:37<07:35,  1.06batch/s]
# Generating 3Di tokens:  23%|██▎       | 144/625 [02:38<06:40,  1.20batch/s]
# Generating 3Di tokens:  23%|██▎       | 145/625 [02:38<06:02,  1.33batch/s]
# Generating 3Di tokens:  23%|██▎       | 146/625 [02:39<05:22,  1.48batch/s]
# Generating 3Di tokens:  24%|██▎       | 147/625 [02:40<06:32,  1.22batch/s]
# Generating 3Di tokens:  24%|██▎       | 148/625 [02:41<06:24,  1.24batch/s]
# Generating 3Di tokens:  24%|██▍       | 149/625 [02:41<05:51,  1.35batch/s]
# Generating 3Di tokens:  24%|██▍       | 150/625 [02:42<05:33,  1.43batch/s]
# Generating 3Di tokens:  24%|██▍       | 151/625 [02:43<06:05,  1.30batch/s]
# Generating 3Di tokens:  24%|██▍       | 152/625 [02:43<05:24,  1.46batch/s]
# Generating 3Di tokens:  24%|██▍       | 153/625 [02:44<05:11,  1.52batch/s]
# Generating 3Di tokens:  25%|██▍       | 154/625 [02:44<04:55,  1.59batch/s]
# Generating 3Di tokens:  25%|██▍       | 155/625 [02:47<08:56,  1.14s/batch]
# Generating 3Di tokens:  25%|██▍       | 156/625 [02:47<07:41,  1.02batch/s]
# Generating 3Di tokens:  25%|██▌       | 157/625 [02:48<07:40,  1.02batch/s]
# Generating 3Di tokens:  25%|██▌       | 158/625 [02:49<06:38,  1.17batch/s]
# Generating 3Di tokens:  25%|██▌       | 159/625 [02:50<07:07,  1.09batch/s]
# Generating 3Di tokens:  26%|██▌       | 160/625 [02:51<06:59,  1.11batch/s]
# Generating 3Di tokens:  26%|██▌       | 161/625 [02:52<07:01,  1.10batch/s]
# Generating 3Di tokens:  26%|██▌       | 162/625 [02:54<09:02,  1.17s/batch]
# Generating 3Di tokens:  26%|██▌       | 163/625 [02:55<08:28,  1.10s/batch]
# Generating 3Di tokens:  26%|██▌       | 164/625 [02:55<06:43,  1.14batch/s]
# Generating 3Di tokens:  26%|██▋       | 165/625 [02:57<10:34,  1.38s/batch]
# Generating 3Di tokens:  27%|██▋       | 166/625 [02:59<11:48,  1.54s/batch]
# Generating 3Di tokens:  27%|██▋       | 167/625 [03:00<10:05,  1.32s/batch]
# Generating 3Di tokens:  27%|██▋       | 168/625 [03:01<08:04,  1.06s/batch]
# Generating 3Di tokens:  27%|██▋       | 169/625 [03:01<07:36,  1.00s/batch]
# Generating 3Di tokens:  27%|██▋       | 170/625 [03:02<07:05,  1.07batch/s]
# Generating 3Di tokens:  27%|██▋       | 171/625 [03:05<10:05,  1.33s/batch]
# Generating 3Di tokens:  28%|██▊       | 172/625 [03:06<09:35,  1.27s/batch]
# Generating 3Di tokens:  28%|██▊       | 173/625 [03:07<10:02,  1.33s/batch]
# Generating 3Di tokens:  28%|██▊       | 174/625 [03:08<07:56,  1.06s/batch]
# Generating 3Di tokens:  28%|██▊       | 175/625 [03:08<07:15,  1.03batch/s]
# Generating 3Di tokens:  28%|██▊       | 176/625 [03:09<06:00,  1.25batch/s]
# Generating 3Di tokens:  28%|██▊       | 177/625 [03:10<06:23,  1.17batch/s]
# Generating 3Di tokens:  28%|██▊       | 178/625 [03:10<05:06,  1.46batch/s]
# Generating 3Di tokens:  29%|██▊       | 179/625 [03:11<04:59,  1.49batch/s]
# Generating 3Di tokens:  29%|██▉       | 180/625 [03:14<10:12,  1.38s/batch]
# Generating 3Di tokens:  29%|██▉       | 181/625 [03:14<08:22,  1.13s/batch]
# Generating 3Di tokens:  29%|██▉       | 182/625 [03:15<08:00,  1.08s/batch]
# Generating 3Di tokens:  29%|██▉       | 183/625 [03:15<06:12,  1.19batch/s]
# Generating 3Di tokens:  29%|██▉       | 184/625 [03:16<05:09,  1.43batch/s]
# Generating 3Di tokens:  30%|██▉       | 185/625 [03:16<05:03,  1.45batch/s]
# Generating 3Di tokens:  30%|██▉       | 186/625 [03:20<11:46,  1.61s/batch]
# Generating 3Di tokens:  30%|██▉       | 187/625 [03:21<09:09,  1.25s/batch]
# Generating 3Di tokens:  30%|███       | 188/625 [03:22<09:29,  1.30s/batch]
# Generating 3Di tokens:  30%|███       | 189/625 [03:23<08:44,  1.20s/batch]
# Generating 3Di tokens:  30%|███       | 190/625 [03:25<09:39,  1.33s/batch]
# Generating 3Di tokens:  31%|███       | 191/625 [03:25<08:15,  1.14s/batch]
# Generating 3Di tokens:  31%|███       | 192/625 [03:26<08:01,  1.11s/batch]
# Generating 3Di tokens:  31%|███       | 193/625 [03:27<07:08,  1.01batch/s]
# Generating 3Di tokens:  31%|███       | 194/625 [03:28<06:21,  1.13batch/s]
# Generating 3Di tokens:  31%|███       | 195/625 [03:29<06:55,  1.04batch/s]
# Generating 3Di tokens:  31%|███▏      | 196/625 [03:32<11:15,  1.58s/batch]
# Generating 3Di tokens:  32%|███▏      | 197/625 [03:33<10:30,  1.47s/batch]
# Generating 3Di tokens:  32%|███▏      | 198/625 [03:34<08:35,  1.21s/batch]
# Generating 3Di tokens:  32%|███▏      | 199/625 [03:35<09:40,  1.36s/batch]
# Generating 3Di tokens:  32%|███▏      | 200/625 [03:37<09:39,  1.36s/batch]
# Generating 3Di tokens:  32%|███▏      | 201/625 [03:38<08:42,  1.23s/batch]
# Generating 3Di tokens:  32%|███▏      | 202/625 [03:38<07:35,  1.08s/batch]
# Generating 3Di tokens:  32%|███▏      | 203/625 [03:39<06:35,  1.07batch/s]
# Generating 3Di tokens:  33%|███▎      | 204/625 [03:40<05:36,  1.25batch/s]
# Generating 3Di tokens:  33%|███▎      | 205/625 [03:40<05:19,  1.31batch/s]
# Generating 3Di tokens:  33%|███▎      | 206/625 [03:41<04:51,  1.44batch/s]
# Generating 3Di tokens:  33%|███▎      | 207/625 [03:42<06:11,  1.12batch/s]
# Generating 3Di tokens:  33%|███▎      | 208/625 [03:43<06:30,  1.07batch/s]
# Generating 3Di tokens:  33%|███▎      | 209/625 [03:44<06:29,  1.07batch/s]
# Generating 3Di tokens:  34%|███▎      | 210/625 [03:45<06:35,  1.05batch/s]
# Generating 3Di tokens:  34%|███▍      | 211/625 [03:46<06:37,  1.04batch/s]
# Generating 3Di tokens:  34%|███▍      | 212/625 [03:47<06:21,  1.08batch/s]
# Generating 3Di tokens:  34%|███▍      | 213/625 [03:49<07:54,  1.15s/batch]
# Generating 3Di tokens:  34%|███▍      | 214/625 [03:51<09:31,  1.39s/batch]
# Generating 3Di tokens:  34%|███▍      | 215/625 [03:51<07:24,  1.08s/batch]
# Generating 3Di tokens:  35%|███▍      | 216/625 [03:52<06:57,  1.02s/batch]
# Generating 3Di tokens:  35%|███▍      | 217/625 [03:54<09:49,  1.44s/batch]
# Generating 3Di tokens:  35%|███▍      | 218/625 [03:55<08:32,  1.26s/batch]
# Generating 3Di tokens:  35%|███▌      | 219/625 [03:56<07:36,  1.12s/batch]
# Generating 3Di tokens:  35%|███▌      | 220/625 [03:57<07:11,  1.07s/batch]
# Generating 3Di tokens:  35%|███▌      | 221/625 [03:58<07:30,  1.11s/batch]
# Generating 3Di tokens:  36%|███▌      | 222/625 [03:59<06:17,  1.07batch/s]
# Generating 3Di tokens:  36%|███▌      | 223/625 [03:59<05:46,  1.16batch/s]
# Generating 3Di tokens:  36%|███▌      | 224/625 [04:00<05:52,  1.14batch/s]
# Generating 3Di tokens:  36%|███▌      | 225/625 [04:02<06:55,  1.04s/batch]
# Generating 3Di tokens:  36%|███▌      | 226/625 [04:02<06:14,  1.06batch/s]
# Generating 3Di tokens:  36%|███▋      | 227/625 [04:03<05:57,  1.11batch/s]
# Generating 3Di tokens:  36%|███▋      | 228/625 [04:05<07:14,  1.09s/batch]
# Generating 3Di tokens:  37%|███▋      | 229/625 [04:08<11:52,  1.80s/batch]
# Generating 3Di tokens:  37%|███▋      | 230/625 [04:09<10:28,  1.59s/batch]
# Generating 3Di tokens:  37%|███▋      | 231/625 [04:14<16:35,  2.53s/batch]
# Generating 3Di tokens:  37%|███▋      | 232/625 [04:15<13:24,  2.05s/batch]
# Generating 3Di tokens:  37%|███▋      | 233/625 [04:16<12:17,  1.88s/batch]
# Generating 3Di tokens:  37%|███▋      | 234/625 [04:17<09:23,  1.44s/batch]
# Generating 3Di tokens:  38%|███▊      | 235/625 [04:17<07:49,  1.20s/batch]
# Generating 3Di tokens:  38%|███▊      | 236/625 [04:18<06:34,  1.01s/batch]
# Generating 3Di tokens:  38%|███▊      | 237/625 [04:20<08:03,  1.25s/batch]
# Generating 3Di tokens:  38%|███▊      | 238/625 [04:21<08:38,  1.34s/batch]
# Generating 3Di tokens:  38%|███▊      | 239/625 [04:22<07:57,  1.24s/batch]
# Generating 3Di tokens:  38%|███▊      | 240/625 [04:23<07:10,  1.12s/batch]
# Generating 3Di tokens:  39%|███▊      | 241/625 [04:24<07:23,  1.15s/batch]
# Generating 3Di tokens:  39%|███▊      | 242/625 [04:27<09:36,  1.50s/batch]
# Generating 3Di tokens:  39%|███▉      | 243/625 [04:28<09:06,  1.43s/batch]
# Generating 3Di tokens:  39%|███▉      | 244/625 [04:29<07:48,  1.23s/batch]
# Generating 3Di tokens:  39%|███▉      | 245/625 [04:29<06:14,  1.02batch/s]
# Generating 3Di tokens:  39%|███▉      | 246/625 [04:30<05:31,  1.14batch/s]
# Generating 3Di tokens:  40%|███▉      | 247/625 [04:31<06:08,  1.03batch/s]
# Generating 3Di tokens:  40%|███▉      | 248/625 [04:32<05:49,  1.08batch/s]
# Generating 3Di tokens:  40%|███▉      | 249/625 [04:32<05:13,  1.20batch/s]
# Generating 3Di tokens:  40%|████      | 250/625 [04:33<04:33,  1.37batch/s]
# Generating 3Di tokens:  40%|████      | 251/625 [04:35<07:14,  1.16s/batch]
# Generating 3Di tokens:  40%|████      | 252/625 [04:36<06:35,  1.06s/batch]
# Generating 3Di tokens:  40%|████      | 253/625 [04:38<07:51,  1.27s/batch]
# Generating 3Di tokens:  41%|████      | 254/625 [04:38<06:57,  1.12s/batch]
# Generating 3Di tokens:  41%|████      | 255/625 [04:39<05:38,  1.09batch/s]
# Generating 3Di tokens:  41%|████      | 256/625 [04:40<06:23,  1.04s/batch]
# Generating 3Di tokens:  41%|████      | 257/625 [04:41<06:13,  1.01s/batch]
# Generating 3Di tokens:  41%|████▏     | 258/625 [04:42<05:20,  1.14batch/s]
# Generating 3Di tokens:  41%|████▏     | 259/625 [04:43<05:49,  1.05batch/s]
# Generating 3Di tokens:  42%|████▏     | 260/625 [04:45<07:16,  1.20s/batch]
# Generating 3Di tokens:  42%|████▏     | 261/625 [04:45<06:11,  1.02s/batch]
# Generating 3Di tokens:  42%|████▏     | 262/625 [04:46<05:51,  1.03batch/s]
# Generating 3Di tokens:  42%|████▏     | 263/625 [04:46<04:53,  1.23batch/s]
# Generating 3Di tokens:  42%|████▏     | 264/625 [04:47<05:06,  1.18batch/s]
# Generating 3Di tokens:  42%|████▏     | 265/625 [04:48<05:22,  1.12batch/s]
# Generating 3Di tokens:  43%|████▎     | 266/625 [04:50<06:15,  1.05s/batch]
# Generating 3Di tokens:  43%|████▎     | 267/625 [04:50<05:28,  1.09batch/s]
# Generating 3Di tokens:  43%|████▎     | 268/625 [04:52<07:19,  1.23s/batch]
# Generating 3Di tokens:  43%|████▎     | 269/625 [04:53<06:30,  1.10s/batch]
# Generating 3Di tokens:  43%|████▎     | 270/625 [04:54<06:15,  1.06s/batch]
# Generating 3Di tokens:  43%|████▎     | 271/625 [04:58<11:19,  1.92s/batch]
# Generating 3Di tokens:  44%|████▎     | 272/625 [05:00<11:32,  1.96s/batch]
# Generating 3Di tokens:  44%|████▎     | 273/625 [05:01<08:51,  1.51s/batch]
# Generating 3Di tokens:  44%|████▍     | 274/625 [05:02<07:54,  1.35s/batch]
# Generating 3Di tokens:  44%|████▍     | 275/625 [05:02<06:14,  1.07s/batch]
# Generating 3Di tokens:  44%|████▍     | 276/625 [05:05<10:12,  1.76s/batch]
# Generating 3Di tokens:  44%|████▍     | 277/625 [05:06<07:47,  1.34s/batch]
# Generating 3Di tokens:  44%|████▍     | 278/625 [05:06<06:38,  1.15s/batch]
# Generating 3Di tokens:  45%|████▍     | 279/625 [05:07<05:23,  1.07batch/s]
# Generating 3Di tokens:  45%|████▍     | 280/625 [05:07<04:22,  1.32batch/s]
# Generating 3Di tokens:  45%|████▍     | 281/625 [05:08<03:49,  1.50batch/s]
# Generating 3Di tokens:  45%|████▌     | 282/625 [05:09<04:47,  1.19batch/s]
# Generating 3Di tokens:  45%|████▌     | 283/625 [05:10<04:27,  1.28batch/s]
# Generating 3Di tokens:  45%|████▌     | 284/625 [05:10<04:11,  1.36batch/s]
# Generating 3Di tokens:  46%|████▌     | 285/625 [05:13<07:04,  1.25s/batch]
# Generating 3Di tokens:  46%|████▌     | 286/625 [05:13<06:02,  1.07s/batch]
# Generating 3Di tokens:  46%|████▌     | 287/625 [05:14<05:33,  1.01batch/s]
# Generating 3Di tokens:  46%|████▌     | 288/625 [05:14<04:28,  1.25batch/s]
# Generating 3Di tokens:  46%|████▌     | 289/625 [05:15<04:45,  1.18batch/s]
# Generating 3Di tokens:  46%|████▋     | 290/625 [05:17<06:15,  1.12s/batch]
# Generating 3Di tokens:  47%|████▋     | 291/625 [05:18<06:09,  1.11s/batch]
# Generating 3Di tokens:  47%|████▋     | 292/625 [05:19<05:23,  1.03batch/s]
# Generating 3Di tokens:  47%|████▋     | 293/625 [05:19<04:40,  1.18batch/s]
# Generating 3Di tokens:  47%|████▋     | 294/625 [05:20<03:54,  1.41batch/s]
# Generating 3Di tokens:  47%|████▋     | 295/625 [05:21<04:21,  1.26batch/s]
# Generating 3Di tokens:  47%|████▋     | 296/625 [05:21<04:09,  1.32batch/s]
# Generating 3Di tokens:  48%|████▊     | 297/625 [05:22<04:25,  1.24batch/s]
# Generating 3Di tokens:  48%|████▊     | 298/625 [05:23<03:50,  1.42batch/s]
# Generating 3Di tokens:  48%|████▊     | 299/625 [05:23<03:40,  1.48batch/s]
# Generating 3Di tokens:  48%|████▊     | 300/625 [05:24<04:07,  1.31batch/s]
# Generating 3Di tokens:  48%|████▊     | 301/625 [05:27<07:35,  1.41s/batch]
# Generating 3Di tokens:  48%|████▊     | 302/625 [05:28<05:52,  1.09s/batch]
# Generating 3Di tokens:  48%|████▊     | 303/625 [05:28<05:14,  1.03batch/s]
# Generating 3Di tokens:  49%|████▊     | 304/625 [05:30<05:46,  1.08s/batch]
# Generating 3Di tokens:  49%|████▉     | 305/625 [05:31<05:18,  1.00batch/s]
# Generating 3Di tokens:  49%|████▉     | 306/625 [05:32<05:16,  1.01batch/s]
# Generating 3Di tokens:  49%|████▉     | 307/625 [05:32<04:49,  1.10batch/s]
# Generating 3Di tokens:  49%|████▉     | 308/625 [05:33<04:23,  1.20batch/s]
# Generating 3Di tokens:  49%|████▉     | 309/625 [05:33<03:54,  1.35batch/s]
# Generating 3Di tokens:  50%|████▉     | 310/625 [05:34<04:16,  1.23batch/s]
# Generating 3Di tokens:  50%|████▉     | 311/625 [05:36<05:45,  1.10s/batch]
# Generating 3Di tokens:  50%|████▉     | 312/625 [05:37<04:57,  1.05batch/s]
# Generating 3Di tokens:  50%|█████     | 313/625 [05:37<04:04,  1.27batch/s]
# Generating 3Di tokens:  50%|█████     | 314/625 [05:38<04:01,  1.29batch/s]
# Generating 3Di tokens:  50%|█████     | 315/625 [05:39<03:52,  1.33batch/s]
# Generating 3Di tokens:  51%|█████     | 316/625 [05:39<03:35,  1.44batch/s]
# Generating 3Di tokens:  51%|█████     | 317/625 [05:39<02:55,  1.75batch/s]
# Generating 3Di tokens:  51%|█████     | 318/625 [05:40<03:03,  1.67batch/s]
# Generating 3Di tokens:  51%|█████     | 319/625 [05:40<02:35,  1.96batch/s]
# Generating 3Di tokens:  51%|█████     | 320/625 [05:42<03:59,  1.27batch/s]
# Generating 3Di tokens:  51%|█████▏    | 321/625 [05:43<04:13,  1.20batch/s]
# Generating 3Di tokens:  52%|█████▏    | 322/625 [05:44<05:19,  1.06s/batch]
# Generating 3Di tokens:  52%|█████▏    | 323/625 [05:45<04:53,  1.03batch/s]
# Generating 3Di tokens:  52%|█████▏    | 324/625 [05:46<05:03,  1.01s/batch]
# Generating 3Di tokens:  52%|█████▏    | 325/625 [05:48<05:55,  1.19s/batch]
# Generating 3Di tokens:  52%|█████▏    | 326/625 [05:50<06:44,  1.35s/batch]
# Generating 3Di tokens:  52%|█████▏    | 327/625 [05:50<05:49,  1.17s/batch]
# Generating 3Di tokens:  52%|█████▏    | 328/625 [05:51<05:18,  1.07s/batch]
# Generating 3Di tokens:  53%|█████▎    | 329/625 [05:52<04:52,  1.01batch/s]
# Generating 3Di tokens:  53%|█████▎    | 330/625 [05:54<06:14,  1.27s/batch]
# Generating 3Di tokens:  53%|█████▎    | 331/625 [05:54<04:51,  1.01batch/s]
# Generating 3Di tokens:  53%|█████▎    | 332/625 [05:55<05:02,  1.03s/batch]
# Generating 3Di tokens:  53%|█████▎    | 333/625 [05:56<04:46,  1.02batch/s]
# Generating 3Di tokens:  53%|█████▎    | 334/625 [05:58<05:30,  1.13s/batch]
# Generating 3Di tokens:  54%|█████▎    | 335/625 [05:59<05:02,  1.04s/batch]
# Generating 3Di tokens:  54%|█████▍    | 336/625 [05:59<04:26,  1.08batch/s]
# Generating 3Di tokens:  54%|█████▍    | 337/625 [05:59<03:30,  1.37batch/s]
# Generating 3Di tokens:  54%|█████▍    | 338/625 [06:00<03:02,  1.57batch/s]
# Generating 3Di tokens:  54%|█████▍    | 339/625 [06:01<03:21,  1.42batch/s]
# Generating 3Di tokens:  54%|█████▍    | 340/625 [06:01<02:53,  1.64batch/s]
# Generating 3Di tokens:  55%|█████▍    | 341/625 [06:01<02:29,  1.90batch/s]
# Generating 3Di tokens:  55%|█████▍    | 342/625 [06:02<02:55,  1.61batch/s]
# Generating 3Di tokens:  55%|█████▍    | 343/625 [06:04<04:29,  1.05batch/s]
# Generating 3Di tokens:  55%|█████▌    | 344/625 [06:04<03:37,  1.29batch/s]
# Generating 3Di tokens:  55%|█████▌    | 345/625 [06:05<03:54,  1.20batch/s]
# Generating 3Di tokens:  55%|█████▌    | 346/625 [06:06<03:10,  1.47batch/s]
# Generating 3Di tokens:  56%|█████▌    | 347/625 [06:07<03:30,  1.32batch/s]
# Generating 3Di tokens:  56%|█████▌    | 348/625 [06:07<03:25,  1.35batch/s]
# Generating 3Di tokens:  56%|█████▌    | 349/625 [06:08<03:10,  1.45batch/s]
# Generating 3Di tokens:  56%|█████▌    | 350/625 [06:08<02:48,  1.63batch/s]
# Generating 3Di tokens:  56%|█████▌    | 351/625 [06:10<03:40,  1.24batch/s]
# Generating 3Di tokens:  56%|█████▋    | 352/625 [06:10<03:29,  1.30batch/s]
# Generating 3Di tokens:  56%|█████▋    | 353/625 [06:11<03:04,  1.47batch/s]
# Generating 3Di tokens:  57%|█████▋    | 354/625 [06:11<02:38,  1.71batch/s]
# Generating 3Di tokens:  57%|█████▋    | 355/625 [06:12<03:01,  1.49batch/s]
# Generating 3Di tokens:  57%|█████▋    | 356/625 [06:13<03:07,  1.44batch/s]
# Generating 3Di tokens:  57%|█████▋    | 357/625 [06:15<05:43,  1.28s/batch]
# Generating 3Di tokens:  57%|█████▋    | 358/625 [06:16<04:28,  1.01s/batch]
# Generating 3Di tokens:  57%|█████▋    | 359/625 [06:16<03:37,  1.22batch/s]
# Generating 3Di tokens:  58%|█████▊    | 360/625 [06:17<03:47,  1.17batch/s]
# Generating 3Di tokens:  58%|█████▊    | 361/625 [06:18<03:30,  1.25batch/s]
# Generating 3Di tokens:  58%|█████▊    | 362/625 [06:18<03:05,  1.42batch/s]
# Generating 3Di tokens:  58%|█████▊    | 363/625 [06:19<03:10,  1.38batch/s]
# Generating 3Di tokens:  58%|█████▊    | 364/625 [06:20<03:44,  1.16batch/s]
# Generating 3Di tokens:  58%|█████▊    | 365/625 [06:21<04:11,  1.03batch/s]
# Generating 3Di tokens:  59%|█████▊    | 366/625 [06:22<03:35,  1.20batch/s]
# Generating 3Di tokens:  59%|█████▊    | 367/625 [06:23<03:22,  1.28batch/s]
# Generating 3Di tokens:  59%|█████▉    | 368/625 [06:24<03:40,  1.17batch/s]
# Generating 3Di tokens:  59%|█████▉    | 369/625 [06:25<03:44,  1.14batch/s]
# Generating 3Di tokens:  59%|█████▉    | 370/625 [06:25<03:40,  1.15batch/s]
# Generating 3Di tokens:  59%|█████▉    | 371/625 [06:27<04:19,  1.02s/batch]
# Generating 3Di tokens:  60%|█████▉    | 372/625 [06:27<03:36,  1.17batch/s]
# Generating 3Di tokens:  60%|█████▉    | 373/625 [06:29<04:20,  1.03s/batch]
# Generating 3Di tokens:  60%|█████▉    | 374/625 [06:30<04:28,  1.07s/batch]
# Generating 3Di tokens:  60%|██████    | 375/625 [06:30<03:44,  1.12batch/s]
# Generating 3Di tokens:  60%|██████    | 376/625 [06:31<03:01,  1.37batch/s]
# Generating 3Di tokens:  60%|██████    | 377/625 [06:31<02:39,  1.55batch/s]
# Generating 3Di tokens:  60%|██████    | 378/625 [06:33<03:35,  1.15batch/s]
# Generating 3Di tokens:  61%|██████    | 379/625 [06:33<03:09,  1.30batch/s]
# Generating 3Di tokens:  61%|██████    | 380/625 [06:34<03:14,  1.26batch/s]
# Generating 3Di tokens:  61%|██████    | 381/625 [06:34<02:45,  1.47batch/s]
# Generating 3Di tokens:  61%|██████    | 382/625 [06:35<02:52,  1.41batch/s]
# Generating 3Di tokens:  61%|██████▏   | 383/625 [06:38<05:39,  1.40s/batch]
# Generating 3Di tokens:  61%|██████▏   | 384/625 [06:38<04:25,  1.10s/batch]
# Generating 3Di tokens:  62%|██████▏   | 385/625 [06:39<04:13,  1.06s/batch]
# Generating 3Di tokens:  62%|██████▏   | 386/625 [06:40<03:54,  1.02batch/s]
# Generating 3Di tokens:  62%|██████▏   | 387/625 [06:42<04:48,  1.21s/batch]
# Generating 3Di tokens:  62%|██████▏   | 388/625 [06:43<04:20,  1.10s/batch]
# Generating 3Di tokens:  62%|██████▏   | 389/625 [06:43<03:36,  1.09batch/s]
# Generating 3Di tokens:  62%|██████▏   | 390/625 [06:44<02:51,  1.37batch/s]
# Generating 3Di tokens:  63%|██████▎   | 391/625 [06:44<02:44,  1.42batch/s]
# Generating 3Di tokens:  63%|██████▎   | 392/625 [06:45<02:33,  1.52batch/s]
# Generating 3Di tokens:  63%|██████▎   | 393/625 [06:46<03:00,  1.28batch/s]
# Generating 3Di tokens:  63%|██████▎   | 394/625 [06:46<02:43,  1.41batch/s]
# Generating 3Di tokens:  63%|██████▎   | 395/625 [06:47<02:47,  1.38batch/s]
# Generating 3Di tokens:  63%|██████▎   | 396/625 [06:48<02:36,  1.46batch/s]
# Generating 3Di tokens:  64%|██████▎   | 397/625 [06:48<02:32,  1.49batch/s]
# Generating 3Di tokens:  64%|██████▎   | 398/625 [06:49<02:35,  1.46batch/s]
# Generating 3Di tokens:  64%|██████▍   | 399/625 [06:49<02:09,  1.74batch/s]
# Generating 3Di tokens:  64%|██████▍   | 400/625 [06:51<02:55,  1.28batch/s]
# Generating 3Di tokens:  64%|██████▍   | 401/625 [06:52<03:25,  1.09batch/s]
# Generating 3Di tokens:  64%|██████▍   | 402/625 [06:52<02:54,  1.28batch/s]
# Generating 3Di tokens:  64%|██████▍   | 403/625 [06:53<02:51,  1.30batch/s]
# Generating 3Di tokens:  65%|██████▍   | 404/625 [06:55<04:27,  1.21s/batch]
# Generating 3Di tokens:  65%|██████▍   | 405/625 [06:56<04:06,  1.12s/batch]
# Generating 3Di tokens:  65%|██████▍   | 406/625 [06:57<03:15,  1.12batch/s]
# Generating 3Di tokens:  65%|██████▌   | 407/625 [06:58<03:15,  1.11batch/s]
# Generating 3Di tokens:  65%|██████▌   | 408/625 [06:58<02:41,  1.35batch/s]
# Generating 3Di tokens:  65%|██████▌   | 409/625 [06:59<03:29,  1.03batch/s]
# Generating 3Di tokens:  66%|██████▌   | 410/625 [07:01<03:49,  1.07s/batch]
# Generating 3Di tokens:  66%|██████▌   | 411/625 [07:01<03:18,  1.08batch/s]
# Generating 3Di tokens:  66%|██████▌   | 412/625 [07:02<02:52,  1.23batch/s]
# Generating 3Di tokens:  66%|██████▌   | 413/625 [07:03<03:01,  1.17batch/s]
# Generating 3Di tokens:  66%|██████▌   | 414/625 [07:05<04:35,  1.31s/batch]
# Generating 3Di tokens:  66%|██████▋   | 415/625 [07:07<04:55,  1.41s/batch]
# Generating 3Di tokens:  67%|██████▋   | 416/625 [07:08<04:28,  1.28s/batch]
# Generating 3Di tokens:  67%|██████▋   | 417/625 [07:09<03:49,  1.10s/batch]
# Generating 3Di tokens:  67%|██████▋   | 418/625 [07:09<03:30,  1.02s/batch]
# Generating 3Di tokens:  67%|██████▋   | 419/625 [07:10<03:34,  1.04s/batch]
# Generating 3Di tokens:  67%|██████▋   | 420/625 [07:12<03:39,  1.07s/batch]
# Generating 3Di tokens:  67%|██████▋   | 421/625 [07:12<03:25,  1.01s/batch]
# Generating 3Di tokens:  68%|██████▊   | 422/625 [07:14<03:31,  1.04s/batch]
# Generating 3Di tokens:  68%|██████▊   | 423/625 [07:18<07:08,  2.12s/batch]
# Generating 3Di tokens:  68%|██████▊   | 424/625 [07:19<05:25,  1.62s/batch]
# Generating 3Di tokens:  68%|██████▊   | 425/625 [07:20<04:42,  1.41s/batch]
# Generating 3Di tokens:  68%|██████▊   | 426/625 [07:20<03:35,  1.08s/batch]
# Generating 3Di tokens:  68%|██████▊   | 427/625 [07:20<02:57,  1.12batch/s]
# Generating 3Di tokens:  68%|██████▊   | 428/625 [07:21<02:57,  1.11batch/s]
# Generating 3Di tokens:  69%|██████▊   | 429/625 [07:22<02:28,  1.32batch/s]
# Generating 3Di tokens:  69%|██████▉   | 430/625 [07:23<02:42,  1.20batch/s]
# Generating 3Di tokens:  69%|██████▉   | 431/625 [07:23<02:17,  1.41batch/s]
# Generating 3Di tokens:  69%|██████▉   | 432/625 [07:25<03:29,  1.08s/batch]
# Generating 3Di tokens:  69%|██████▉   | 433/625 [07:26<03:21,  1.05s/batch]
# Generating 3Di tokens:  69%|██████▉   | 434/625 [07:27<02:55,  1.09batch/s]
# Generating 3Di tokens:  70%|██████▉   | 435/625 [07:28<03:00,  1.05batch/s]
# Generating 3Di tokens:  70%|██████▉   | 436/625 [07:29<03:21,  1.06s/batch]
# Generating 3Di tokens:  70%|██████▉   | 437/625 [07:30<03:23,  1.08s/batch]
# Generating 3Di tokens:  70%|███████   | 438/625 [07:31<02:50,  1.10batch/s]
# Generating 3Di tokens:  70%|███████   | 439/625 [07:32<02:45,  1.12batch/s]
# Generating 3Di tokens:  70%|███████   | 440/625 [07:32<02:29,  1.24batch/s]
# Generating 3Di tokens:  71%|███████   | 441/625 [07:33<02:09,  1.42batch/s]
# Generating 3Di tokens:  71%|███████   | 442/625 [07:33<01:57,  1.55batch/s]
# Generating 3Di tokens:  71%|███████   | 443/625 [07:34<02:20,  1.29batch/s]
# Generating 3Di tokens:  71%|███████   | 444/625 [07:35<02:05,  1.44batch/s]
# Generating 3Di tokens:  71%|███████   | 445/625 [07:35<02:00,  1.50batch/s]
# Generating 3Di tokens:  71%|███████▏  | 446/625 [07:38<03:41,  1.24s/batch]
# Generating 3Di tokens:  72%|███████▏  | 447/625 [07:42<06:00,  2.02s/batch]
# Generating 3Di tokens:  72%|███████▏  | 448/625 [07:43<05:27,  1.85s/batch]
# Generating 3Di tokens:  72%|███████▏  | 449/625 [07:44<04:10,  1.42s/batch]
# Generating 3Di tokens:  72%|███████▏  | 450/625 [07:44<03:39,  1.25s/batch]
# Generating 3Di tokens:  72%|███████▏  | 451/625 [07:46<03:54,  1.35s/batch]
# Generating 3Di tokens:  72%|███████▏  | 452/625 [07:47<03:16,  1.14s/batch]
# Generating 3Di tokens:  72%|███████▏  | 453/625 [07:47<02:59,  1.05s/batch]
# Generating 3Di tokens:  73%|███████▎  | 454/625 [07:49<03:12,  1.13s/batch]
# Generating 3Di tokens:  73%|███████▎  | 455/625 [07:49<02:35,  1.10batch/s]
# Generating 3Di tokens:  73%|███████▎  | 456/625 [07:50<02:16,  1.24batch/s]
# Generating 3Di tokens:  73%|███████▎  | 457/625 [07:50<01:51,  1.51batch/s]
# Generating 3Di tokens:  73%|███████▎  | 458/625 [07:51<01:48,  1.54batch/s]
# Generating 3Di tokens:  73%|███████▎  | 459/625 [07:51<01:52,  1.47batch/s]
# Generating 3Di tokens:  74%|███████▎  | 460/625 [07:52<01:42,  1.62batch/s]
# Generating 3Di tokens:  74%|███████▍  | 461/625 [07:53<01:56,  1.41batch/s]
# Generating 3Di tokens:  74%|███████▍  | 462/625 [07:55<02:46,  1.02s/batch]
# Generating 3Di tokens:  74%|███████▍  | 463/625 [07:55<02:33,  1.06batch/s]
# Generating 3Di tokens:  74%|███████▍  | 464/625 [07:57<02:57,  1.10s/batch]
# Generating 3Di tokens:  74%|███████▍  | 465/625 [07:58<02:40,  1.00s/batch]
# Generating 3Di tokens:  75%|███████▍  | 466/625 [07:59<02:56,  1.11s/batch]
# Generating 3Di tokens:  75%|███████▍  | 467/625 [08:01<03:58,  1.51s/batch]
# Generating 3Di tokens:  75%|███████▍  | 468/625 [08:02<03:15,  1.24s/batch]
# Generating 3Di tokens:  75%|███████▌  | 469/625 [08:03<02:52,  1.11s/batch]
# Generating 3Di tokens:  75%|███████▌  | 470/625 [08:03<02:23,  1.08batch/s]
# Generating 3Di tokens:  75%|███████▌  | 471/625 [08:04<01:58,  1.29batch/s]
# Generating 3Di tokens:  76%|███████▌  | 472/625 [08:05<02:10,  1.17batch/s]
# Generating 3Di tokens:  76%|███████▌  | 473/625 [08:05<01:51,  1.36batch/s]
# Generating 3Di tokens:  76%|███████▌  | 474/625 [08:06<01:32,  1.64batch/s]
# Generating 3Di tokens:  76%|███████▌  | 475/625 [08:06<01:24,  1.78batch/s]
# Generating 3Di tokens:  76%|███████▌  | 476/625 [08:07<01:34,  1.58batch/s]
# Generating 3Di tokens:  76%|███████▋  | 477/625 [08:07<01:24,  1.74batch/s]
# Generating 3Di tokens:  76%|███████▋  | 478/625 [08:08<01:24,  1.74batch/s]
# Generating 3Di tokens:  77%|███████▋  | 479/625 [08:11<03:00,  1.24s/batch]
# Generating 3Di tokens:  77%|███████▋  | 480/625 [08:11<02:44,  1.13s/batch]
# Generating 3Di tokens:  77%|███████▋  | 481/625 [08:12<02:08,  1.12batch/s]
# Generating 3Di tokens:  77%|███████▋  | 482/625 [08:14<02:41,  1.13s/batch]
# Generating 3Di tokens:  77%|███████▋  | 483/625 [08:14<02:19,  1.02batch/s]
# Generating 3Di tokens:  77%|███████▋  | 484/625 [08:15<02:25,  1.03s/batch]
# Generating 3Di tokens:  78%|███████▊  | 485/625 [08:16<02:14,  1.04batch/s]
# Generating 3Di tokens:  78%|███████▊  | 486/625 [08:17<02:17,  1.01batch/s]
# Generating 3Di tokens:  78%|███████▊  | 487/625 [08:18<02:00,  1.15batch/s]
# Generating 3Di tokens:  78%|███████▊  | 488/625 [08:19<01:58,  1.16batch/s]
# Generating 3Di tokens:  78%|███████▊  | 489/625 [08:19<01:42,  1.33batch/s]
# Generating 3Di tokens:  78%|███████▊  | 490/625 [08:20<02:00,  1.12batch/s]
# Generating 3Di tokens:  79%|███████▊  | 491/625 [08:21<01:35,  1.40batch/s]
# Generating 3Di tokens:  79%|███████▊  | 492/625 [08:21<01:22,  1.61batch/s]
# Generating 3Di tokens:  79%|███████▉  | 493/625 [08:21<01:08,  1.92batch/s]
# Generating 3Di tokens:  79%|███████▉  | 494/625 [08:23<01:55,  1.13batch/s]
# Generating 3Di tokens:  79%|███████▉  | 495/625 [08:24<01:48,  1.20batch/s]
# Generating 3Di tokens:  79%|███████▉  | 496/625 [08:24<01:37,  1.32batch/s]
# Generating 3Di tokens:  80%|███████▉  | 497/625 [08:26<01:57,  1.09batch/s]
# Generating 3Di tokens:  80%|███████▉  | 498/625 [08:26<01:44,  1.22batch/s]
# Generating 3Di tokens:  80%|███████▉  | 499/625 [08:27<01:35,  1.32batch/s]
# Generating 3Di tokens:  80%|████████  | 500/625 [08:27<01:27,  1.43batch/s]
# Generating 3Di tokens:  80%|████████  | 501/625 [08:29<01:55,  1.07batch/s]
# Generating 3Di tokens:  80%|████████  | 502/625 [08:29<01:41,  1.21batch/s]
# Generating 3Di tokens:  80%|████████  | 503/625 [08:30<01:44,  1.16batch/s]
# Generating 3Di tokens:  81%|████████  | 504/625 [08:32<01:59,  1.01batch/s]
# Generating 3Di tokens:  81%|████████  | 505/625 [08:34<02:32,  1.27s/batch]
# Generating 3Di tokens:  81%|████████  | 506/625 [08:35<02:48,  1.42s/batch]
# Generating 3Di tokens:  81%|████████  | 507/625 [08:36<02:34,  1.31s/batch]
# Generating 3Di tokens:  81%|████████▏ | 508/625 [08:39<03:28,  1.78s/batch]
# Generating 3Di tokens:  81%|████████▏ | 509/625 [08:40<02:42,  1.40s/batch]
# Generating 3Di tokens:  82%|████████▏ | 510/625 [08:40<02:13,  1.16s/batch]
# Generating 3Di tokens:  82%|████████▏ | 511/625 [08:41<01:43,  1.11batch/s]
# Generating 3Di tokens:  82%|████████▏ | 512/625 [08:42<01:40,  1.13batch/s]
# Generating 3Di tokens:  82%|████████▏ | 513/625 [08:42<01:21,  1.38batch/s]
# Generating 3Di tokens:  82%|████████▏ | 514/625 [08:44<01:57,  1.06s/batch]
# Generating 3Di tokens:  82%|████████▏ | 515/625 [08:44<01:34,  1.16batch/s]
# Generating 3Di tokens:  83%|████████▎ | 516/625 [08:45<01:20,  1.35batch/s]
# Generating 3Di tokens:  83%|████████▎ | 517/625 [08:46<01:32,  1.16batch/s]
# Generating 3Di tokens:  83%|████████▎ | 518/625 [08:46<01:21,  1.31batch/s]
# Generating 3Di tokens:  83%|████████▎ | 519/625 [08:47<01:12,  1.46batch/s]
# Generating 3Di tokens:  83%|████████▎ | 520/625 [08:48<01:19,  1.32batch/s]
# Generating 3Di tokens:  83%|████████▎ | 521/625 [08:48<01:09,  1.49batch/s]
# Generating 3Di tokens:  84%|████████▎ | 522/625 [08:49<01:06,  1.54batch/s]
# Generating 3Di tokens:  84%|████████▎ | 523/625 [08:49<01:03,  1.61batch/s]
# Generating 3Di tokens:  84%|████████▍ | 524/625 [08:50<00:59,  1.70batch/s]
# Generating 3Di tokens:  84%|████████▍ | 525/625 [08:51<01:02,  1.60batch/s]
# Generating 3Di tokens:  84%|████████▍ | 526/625 [08:51<00:52,  1.88batch/s]
# Generating 3Di tokens:  84%|████████▍ | 527/625 [08:51<00:54,  1.81batch/s]
# Generating 3Di tokens:  84%|████████▍ | 528/625 [08:52<01:02,  1.54batch/s]
# Generating 3Di tokens:  85%|████████▍ | 529/625 [08:53<00:56,  1.71batch/s]
# Generating 3Di tokens:  85%|████████▍ | 530/625 [08:53<00:50,  1.90batch/s]
# Generating 3Di tokens:  85%|████████▍ | 531/625 [08:54<00:47,  1.98batch/s]
# Generating 3Di tokens:  85%|████████▌ | 532/625 [08:54<00:52,  1.77batch/s]
# Generating 3Di tokens:  85%|████████▌ | 533/625 [08:56<01:26,  1.07batch/s]
# Generating 3Di tokens:  85%|████████▌ | 534/625 [08:57<01:18,  1.16batch/s]
# Generating 3Di tokens:  86%|████████▌ | 535/625 [08:58<01:19,  1.13batch/s]
# Generating 3Di tokens:  86%|████████▌ | 536/625 [08:58<01:06,  1.34batch/s]
# Generating 3Di tokens:  86%|████████▌ | 537/625 [08:59<01:08,  1.28batch/s]
# Generating 3Di tokens:  86%|████████▌ | 538/625 [08:59<00:59,  1.46batch/s]
# Generating 3Di tokens:  86%|████████▌ | 539/625 [09:00<00:51,  1.67batch/s]
# Generating 3Di tokens:  86%|████████▋ | 540/625 [09:00<00:43,  1.94batch/s]
# Generating 3Di tokens:  87%|████████▋ | 541/625 [09:01<00:45,  1.83batch/s]
# Generating 3Di tokens:  87%|████████▋ | 542/625 [09:03<01:15,  1.10batch/s]
# Generating 3Di tokens:  87%|████████▋ | 543/625 [09:03<01:03,  1.30batch/s]
# Generating 3Di tokens:  87%|████████▋ | 544/625 [09:05<01:21,  1.00s/batch]
# Generating 3Di tokens:  87%|████████▋ | 545/625 [09:05<01:08,  1.16batch/s]
# Generating 3Di tokens:  87%|████████▋ | 546/625 [09:06<01:09,  1.14batch/s]
# Generating 3Di tokens:  88%|████████▊ | 547/625 [09:06<00:56,  1.37batch/s]
# Generating 3Di tokens:  88%|████████▊ | 548/625 [09:07<00:51,  1.50batch/s]
# Generating 3Di tokens:  88%|████████▊ | 549/625 [09:08<00:52,  1.44batch/s]
# Generating 3Di tokens:  88%|████████▊ | 550/625 [09:09<01:09,  1.08batch/s]
# Generating 3Di tokens:  88%|████████▊ | 551/625 [09:10<01:05,  1.13batch/s]
# Generating 3Di tokens:  88%|████████▊ | 552/625 [09:10<00:55,  1.31batch/s]
# Generating 3Di tokens:  88%|████████▊ | 553/625 [09:11<00:56,  1.27batch/s]
# Generating 3Di tokens:  89%|████████▊ | 554/625 [09:13<01:07,  1.05batch/s]
# Generating 3Di tokens:  89%|████████▉ | 555/625 [09:13<01:01,  1.14batch/s]
# Generating 3Di tokens:  89%|████████▉ | 556/625 [09:14<01:00,  1.14batch/s]
# Generating 3Di tokens:  89%|████████▉ | 557/625 [09:14<00:47,  1.42batch/s]
# Generating 3Di tokens:  89%|████████▉ | 558/625 [09:15<00:47,  1.41batch/s]
# Generating 3Di tokens:  89%|████████▉ | 559/625 [09:18<01:37,  1.48s/batch]
# Generating 3Di tokens:  90%|████████▉ | 560/625 [09:20<01:42,  1.57s/batch]
# Generating 3Di tokens:  90%|████████▉ | 561/625 [09:21<01:19,  1.25s/batch]
# Generating 3Di tokens:  90%|████████▉ | 562/625 [09:24<02:03,  1.96s/batch]
# Generating 3Di tokens:  90%|█████████ | 563/625 [09:26<01:49,  1.76s/batch]
# Generating 3Di tokens:  90%|█████████ | 564/625 [09:26<01:25,  1.40s/batch]
# Generating 3Di tokens:  90%|█████████ | 565/625 [09:27<01:06,  1.11s/batch]
# Generating 3Di tokens:  91%|█████████ | 566/625 [09:27<00:54,  1.08batch/s]
# Generating 3Di tokens:  91%|█████████ | 567/625 [09:28<00:53,  1.09batch/s]
# Generating 3Di tokens:  91%|█████████ | 568/625 [09:29<00:44,  1.27batch/s]
# Generating 3Di tokens:  91%|█████████ | 569/625 [09:29<00:37,  1.48batch/s]
# Generating 3Di tokens:  91%|█████████ | 570/625 [09:29<00:31,  1.77batch/s]
# Generating 3Di tokens:  91%|█████████▏| 571/625 [09:32<01:06,  1.23s/batch]
# Generating 3Di tokens:  92%|█████████▏| 572/625 [09:32<00:51,  1.04batch/s]
# Generating 3Di tokens:  92%|█████████▏| 573/625 [09:33<00:43,  1.20batch/s]
# Generating 3Di tokens:  92%|█████████▏| 574/625 [09:33<00:36,  1.42batch/s]
# Generating 3Di tokens:  92%|█████████▏| 575/625 [09:34<00:28,  1.74batch/s]
# Generating 3Di tokens:  92%|█████████▏| 576/625 [09:34<00:32,  1.50batch/s]
# Generating 3Di tokens:  92%|█████████▏| 577/625 [09:35<00:26,  1.83batch/s]
# Generating 3Di tokens:  92%|█████████▏| 578/625 [09:35<00:22,  2.05batch/s]
# Generating 3Di tokens:  93%|█████████▎| 579/625 [09:36<00:24,  1.86batch/s]
# Generating 3Di tokens:  93%|█████████▎| 580/625 [09:38<00:48,  1.08s/batch]
# Generating 3Di tokens:  93%|█████████▎| 581/625 [09:39<00:43,  1.01batch/s]
# Generating 3Di tokens:  93%|█████████▎| 582/625 [09:40<00:41,  1.05batch/s]
# Generating 3Di tokens:  93%|█████████▎| 583/625 [09:40<00:35,  1.20batch/s]
# Generating 3Di tokens:  93%|█████████▎| 584/625 [09:41<00:31,  1.31batch/s]
# Generating 3Di tokens:  94%|█████████▎| 585/625 [09:43<00:49,  1.24s/batch]
# Generating 3Di tokens:  94%|█████████▍| 586/625 [09:44<00:40,  1.04s/batch]
# Generating 3Di tokens:  94%|█████████▍| 587/625 [09:44<00:32,  1.18batch/s]
# Generating 3Di tokens:  94%|█████████▍| 588/625 [09:45<00:34,  1.06batch/s]
# Generating 3Di tokens:  94%|█████████▍| 589/625 [09:46<00:33,  1.07batch/s]
# Generating 3Di tokens:  94%|█████████▍| 590/625 [09:47<00:26,  1.34batch/s]
# Generating 3Di tokens:  95%|█████████▍| 591/625 [09:47<00:22,  1.51batch/s]
# Generating 3Di tokens:  95%|█████████▍| 592/625 [09:51<00:51,  1.55s/batch]
# Generating 3Di tokens:  95%|█████████▍| 593/625 [09:53<01:00,  1.90s/batch]
# Generating 3Di tokens:  95%|█████████▌| 594/625 [09:55<00:52,  1.70s/batch]
# Generating 3Di tokens:  95%|█████████▌| 595/625 [09:55<00:39,  1.31s/batch]
# Generating 3Di tokens:  95%|█████████▌| 596/625 [09:56<00:34,  1.19s/batch]
# Generating 3Di tokens:  96%|█████████▌| 597/625 [10:02<01:14,  2.67s/batch]
# Generating 3Di tokens:  96%|█████████▌| 598/625 [10:02<00:52,  1.95s/batch]
# Generating 3Di tokens:  96%|█████████▌| 599/625 [10:03<00:39,  1.53s/batch]
# Generating 3Di tokens:  96%|█████████▌| 600/625 [10:04<00:33,  1.34s/batch]
# Generating 3Di tokens:  96%|█████████▌| 601/625 [10:04<00:25,  1.05s/batch]
# Generating 3Di tokens:  96%|█████████▋| 602/625 [10:05<00:22,  1.03batch/s]
# Generating 3Di tokens:  96%|█████████▋| 603/625 [10:07<00:25,  1.16s/batch]
# Generating 3Di tokens:  97%|█████████▋| 604/625 [10:08<00:25,  1.22s/batch]
# Generating 3Di tokens:  97%|█████████▋| 605/625 [10:09<00:20,  1.04s/batch]
# Generating 3Di tokens:  97%|█████████▋| 606/625 [10:09<00:16,  1.12batch/s]
# Generating 3Di tokens:  97%|█████████▋| 607/625 [10:10<00:16,  1.09batch/s]
# Generating 3Di tokens:  97%|█████████▋| 608/625 [10:12<00:19,  1.15s/batch]
# Generating 3Di tokens:  97%|█████████▋| 609/625 [10:12<00:15,  1.02batch/s]
# Generating 3Di tokens:  98%|█████████▊| 610/625 [10:13<00:14,  1.05batch/s]
# Generating 3Di tokens:  98%|█████████▊| 611/625 [10:14<00:13,  1.02batch/s]
# Generating 3Di tokens:  98%|█████████▊| 612/625 [10:15<00:11,  1.17batch/s]
# Generating 3Di tokens:  98%|█████████▊| 613/625 [10:21<00:28,  2.34s/batch]
# Generating 3Di tokens:  98%|█████████▊| 614/625 [10:21<00:20,  1.87s/batch]
# Generating 3Di tokens:  98%|█████████▊| 615/625 [10:22<00:15,  1.54s/batch]
# Generating 3Di tokens:  99%|█████████▊| 616/625 [10:23<00:10,  1.22s/batch]
# Generating 3Di tokens:  99%|█████████▊| 617/625 [10:24<00:10,  1.27s/batch]
# Generating 3Di tokens:  99%|█████████▉| 618/625 [10:24<00:06,  1.03batch/s]
# Generating 3Di tokens:  99%|█████████▉| 619/625 [10:25<00:05,  1.00batch/s]
# Generating 3Di tokens:  99%|█████████▉| 620/625 [10:26<00:04,  1.14batch/s]
# Generating 3Di tokens:  99%|█████████▉| 621/625 [10:27<00:03,  1.18batch/s]
# Generating 3Di tokens: 100%|█████████▉| 622/625 [10:28<00:02,  1.16batch/s]
# Generating 3Di tokens: 100%|█████████▉| 623/625 [10:28<00:01,  1.45batch/s]
# Generating 3Di tokens: 100%|█████████▉| 624/625 [10:28<00:00,  1.81batch/s]
# Generating 3Di tokens: 100%|██████████| 625/625 [10:29<00:00,  1.77batch/s]
#
# 17:53:58 [INFO] Saved predicted 3Di sequences to: /scratch/fweikert/data/foldseek/metavr_esm3di_temp_3di.fasta
# 17:53:58 [INFO] Building Foldseek database at: /scratch/fweikert/data/foldseek/metavr_esm3di
# 17:53:58 [INFO] Foldseek database generated successfully.

# %% [markdown]
# ### 3Di FASTA Extraction, Foldseek Alignment & Metric Evaluation
# Extract 3Di FASTA files from the Foldseek databases, align predictions against AF3 ground truth, and calculate both **bitscores** and **3Di sequence identity**.

# %%
# --- 1. Extract 3Di Sequences to FASTA Files ---
def convert_db_3di_to_fasta(db_prefix: Path, out_fasta: Path):
    """Extracts 3Di sequences from Foldseek _ss database into a standard FASTA file."""
    # Link header DB to secondary structure DB and dump FASTA
    run_cmd(f"foldseek base:lndb '{db_prefix}_h' '{db_prefix}_ss_h'", silent=True)
    run_cmd(f"foldseek convert2fasta '{db_prefix}_ss' '{out_fasta}'", silent=True)

print("Extracting 3Di FASTA sequences from Foldseek DBs...")
convert_db_3di_to_fasta(af3_db, META_DIR / "metavr_af3_3di.fa")
convert_db_3di_to_fasta(prost_db, META_DIR / "metavr_prostt5_3di.fa")
convert_db_3di_to_fasta(esm_db, META_DIR / "metavr_esm3di_3di.fa")
print("3Di FASTA files generated successfully!")


# --- 2. Prefilter & Foldseek Structure Alignment ---
def get_foldseek_header_map(db_prefix: Path) -> dict[str, int]:
    """Parses Foldseek's binary _h database using byte offsets from _h.index."""
    idx_path = db_prefix.with_name(f"{db_prefix.name}_h.index")
    hdr_path = db_prefix.with_name(f"{db_prefix.name}_h")

    header_to_id = {}
    with open(idx_path, "r", encoding="utf-8") as f_idx, open(hdr_path, "rb") as f_hdr:
        for line in f_idx:
            parts = line.strip().split("\t")
            if len(parts) < 3:
                continue
            key = int(parts[0])      # True internal Foldseek entry ID
            offset = int(parts[1])   # Byte offset in _h
            length = int(parts[2])   # Byte length in _h

            f_hdr.seek(offset)
            raw_bytes = f_hdr.read(length)
            # Clean null bytes and extract primary header identifier
            hdr_str = raw_bytes.decode("latin1").replace("\x00", "").strip().split()[0]
            header_to_id[hdr_str] = key

    return header_to_id


def create_1v1_prefilter(query_prefix: Path, target_prefix: Path, out_tsv: Path, out_db: Path):
    """Generates a 1-vs-1 mapping prefilter DB for Foldseek structurealign."""
    q_map = get_foldseek_header_map(query_prefix)
    t_map = get_foldseek_header_map(target_prefix)

    pairs = []
    for hdr, q_id in q_map.items():
        if hdr in t_map:
            pairs.append((q_id, t_map[hdr]))

    if not pairs:
        raise RuntimeError(f"No matching headers found between {query_prefix.name} and {target_prefix.name}")

    pd.DataFrame(pairs).to_csv(out_tsv, sep="\t", header=False, index=False)
    run_cmd(f"foldseek base:tsv2db '{out_tsv}' '{out_db}' --output-dbtype 7", silent=True)


def run_foldseek_alignment(query_db: Path, target_db: Path, pref_db: Path, out_prefix: Path) -> pd.DataFrame:
    """Runs structurealign and returns a formatted DataFrame containing bitscores."""
    aln_db = out_prefix.with_suffix(".aln")
    tsv_out = out_prefix.with_suffix(".tsv")
    fields = "query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits"

    run_cmd(f"foldseek structurealign -e INF '{query_db}' '{target_db}' '{pref_db}' '{aln_db}'", silent=True)
    run_cmd(f"foldseek convertalis '{query_db}' '{target_db}' '{aln_db}' '{tsv_out}' --format-output '{fields}'", silent=True)
    return pd.read_csv(tsv_out, sep="\t", names=fields.split(","))

print("\nAligning ProstT5 vs AF3...")
create_1v1_prefilter(prost_db, af3_db, META_DIR / "prost_pref.tsv", FS_DIR / "prost_pref")
df_prost = run_foldseek_alignment(prost_db, af3_db, FS_DIR / "prost_pref", FS_DIR / "prost_aln")

print("Aligning ESM3Di vs AF3...")
create_1v1_prefilter(esm_db, af3_db, META_DIR / "esm_pref.tsv", FS_DIR / "esm_pref")
df_esm = run_foldseek_alignment(esm_db, af3_db, FS_DIR / "esm_pref", FS_DIR / "esm_aln")


# --- 3. Compute 3Di Sequence Identities ---
af3_seqs = parse_fasta(META_DIR / "metavr_af3_3di.fa")
prost_seqs = parse_fasta(META_DIR / "metavr_prostt5_3di.fa")
esm_seqs = parse_fasta(META_DIR / "metavr_esm3di_3di.fa")

identities = []
for seq_id, af3_seq in af3_seqs.items():
    if seq_id in prost_seqs and seq_id in esm_seqs:
        p_seq, e_seq = prost_seqs[seq_id], esm_seqs[seq_id]
        if len(af3_seq) == len(p_seq) == len(e_seq):
            identities.append({
                "query": seq_id,
                "prostt5_identity": sum(a == b for a, b in zip(af3_seq, p_seq)) / len(af3_seq) * 100,
                "esm3di_identity": sum(a == b for a, b in zip(af3_seq, e_seq)) / len(af3_seq) * 100
            })

# --- 4. Merge Bitscores and Identities into Unified Benchmark DataFrame ---
df_benchmark = (
    df_prost[["query", "bits"]]
    .rename(columns={"bits": "prostt5_bitscore"})
    .merge(df_esm[["query", "bits"]].rename(columns={"bits": "esm3di_bitscore"}), on="query")
    .merge(pd.DataFrame(identities), on="query")
)

print(f"\nBenchmark dataset ready. Total sequences matched: {len(df_benchmark)}")
df_benchmark.head()
# Out:
# Extracting 3Di FASTA sequences from Foldseek DBs...
# 3Di FASTA files generated successfully!
#
# Aligning ProstT5 vs AF3...
# Aligning ESM3Di vs AF3...
#
# Benchmark dataset ready. Total sequences matched: 9999
#                 query  prostt5_bitscore  esm3di_bitscore  prostt5_identity  \
# 0  imgvr_pc_000313352              2458             2354         38.078292
# 1  imgvr_pc_000315488              1683             1750         65.443425
# 2  imgvr_pc_000317353               737              824         45.864662
# 3  imgvr_pc_000320088              1741             1776         60.837438
# 4  imgvr_pc_000322346               163              157         70.454545
#
#    esm3di_identity
# 0        36.298932
# 1        70.336391
# 2        51.127820
# 3        63.793103
# 4        61.363636

# %% [markdown]
# ### Benchmark Results: Bitscores & 3Di Sequence Identity
# Compare **ProstT5** and **ESM3Di** performance directly against AlphaFold3 ground truth representations.

# %%
def plot_benchmark_comparison(df, x_col, y_col, x_label, y_label, title, kind="scatter", gridsize=30, ax=None):
    if ax is None:
        fig, ax = plt.subplots(figsize=(6, 6))

    x, y = df[x_col].values, df[y_col].values
    if len(df) == 0:
        return ax

    n_total = len(df)
    n_above, n_below = np.sum(y > x), np.sum(y < x)
    pct_above, pct_below = (n_above / n_total) * 100, (n_below / n_total) * 100

    # Dynamic limits: Fixed cap at 100 for percentages, otherwise dynamic max
    max_val = max(x.max(), y.max())
    if "identity" in x_col.lower() and max_val <= 100:
        lim = 100.0
    else:
        lim = max_val * 1.05 if max_val > 0 else 1.0

    ax.set_xlim(0, lim)
    ax.set_ylim(0, lim)
    ax.set_aspect("equal", adjustable="box")

    # Render points using identical styling rules
    if kind == "hexbin" and len(df) > 10:
        hb = ax.hexbin(x, y, gridsize=gridsize, extent=(0, lim, 0, lim), cmap="viridis", mincnt=1)
        cb = plt.colorbar(hb, ax=ax, label="Count", fraction=0.046, pad=0.04)
        cb.ax.tick_params(labelsize=9)
    else:
        ax.scatter(x, y, alpha=0.6, edgecolors="none", color="#1f77b4", s=35)

    # Reference Identity line y = x
    ax.plot([0, lim], [0, lim], color="#d62728", linestyle="--", linewidth=1.5, label="y = x")

    # Annotations
    bbox_props = dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.85, edgecolor="none")
    ax.text(0.30, 0.75, f"ESM3Di Higher\n{n_above} ({pct_above:.1f}%)", transform=ax.transAxes, ha="center", va="center", fontsize=10, fontweight="bold", bbox=bbox_props)
    ax.text(0.75, 0.30, f"ProstT5 Higher\n{n_below} ({pct_below:.1f}%)", transform=ax.transAxes, ha="center", va="center", fontsize=10, fontweight="bold", bbox=bbox_props)

    # Styling
    ax.set_xlabel(x_label, fontsize=11)
    ax.set_ylabel(y_label, fontsize=11)
    ax.set_title(title, fontsize=12, fontweight="bold", pad=10)
    ax.grid(True, linestyle=":", alpha=0.5)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

    return ax


# Set a uniform style for both subplots ("scatter" or "hexbin")
PLOT_STYLE = "scatter"  # Switch to "hexbin" if scaling up to thousands of sequences

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot 1: Bitscores
plot_benchmark_comparison(
    df=df_benchmark,
    x_col="prostt5_bitscore",
    y_col="esm3di_bitscore",
    x_label="ProstT5 Bitscore",
    y_label="ESM3Di Bitscore",
    title="Foldseek Alignment Bitscores vs AF3",
    kind=PLOT_STYLE,
    ax=axes[0]
)

# Plot 2: 3Di Identity
plot_benchmark_comparison(
    df=df_benchmark,
    x_col="prostt5_identity",
    y_col="esm3di_identity",
    x_label="ProstT5 3Di Identity (%)",
    y_label="ESM3Di 3Di Identity (%)",
    title="3Di Sequence Identity vs AF3",
    kind=PLOT_STYLE,
    ax=axes[1]
)

plt.tight_layout()
plt.show()

# --- Print Summary Metrics ---
print("\n" + "=" * 45)
print("             BENCHMARK SUMMARY             ")
print("=" * 45)
summary_df = pd.DataFrame({
    "Metric": ["Mean Bitscore", "Median Bitscore", "Mean 3Di Identity (%)", "Median 3Di Identity (%)"],
    "ProstT5": [
        df_benchmark["prostt5_bitscore"].mean(),
        df_benchmark["prostt5_bitscore"].median(),
        df_benchmark["prostt5_identity"].mean(),
        df_benchmark["prostt5_identity"].median(),
    ],
    "ESM3Di": [
        df_benchmark["esm3di_bitscore"].mean(),
        df_benchmark["esm3di_bitscore"].median(),
        df_benchmark["esm3di_identity"].mean(),
        df_benchmark["esm3di_identity"].median(),
    ]
})
print(summary_df.to_string(index=False))
# Out:
# =============================================
#              BENCHMARK SUMMARY
# =============================================
#                  Metric     ProstT5      ESM3Di
#           Mean Bitscore 1100.800980 1113.858886
#         Median Bitscore  653.000000  668.000000
#   Mean 3Di Identity (%)   58.129093   60.502751
# Median 3Di Identity (%)   58.032787   60.273973
