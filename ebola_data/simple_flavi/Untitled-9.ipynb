# %%
import glob
infolder ='/mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco'
structs = glob.glob(f"{infolder}/*.pdb")

# %%
# %%bash
# foldseek createdb /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/ /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_db
# Out:
# createdb /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/ /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_db
#
# MMseqs Version:             	10.941cd33
# Use GPU                     	0
# Path to ProstT5
# Chain name mode             	0
# Createdb extraction mode    	0
# Interface distance threshold	8
# Write mapping file          	0
# Mask b-factor threshold     	0
# Coord store mode            	2
# Write lookup file           	1
# Input format                	0
# File Inclusion Regex        	.*
# File Exclusion Regex        	^$
# Threads                     	32
# Verbosity                   	3
#
# Output file: /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_db
# [=================================================================] 627 3s 394ms
# Time for merging to refolded_fullglyco_db_ss: 0h 0m 0s 5ms
# Time for merging to refolded_fullglyco_db_h: 0h 0m 0s 3ms
# Time for merging to refolded_fullglyco_db_ca: 0h 0m 0s 5ms
# Time for merging to refolded_fullglyco_db: 0h 0m 0s 3ms
# Ignore 0 out of 626.
# Too short: 0, incorrect: 0, not proteins: 0.
# Time for processing: 0h 0m 3s 487ms

# %%
# %%bash
# DB_PREFIX="/mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_db"
# OUTPUT_PREFIX="/mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco"
#
# python -m esm3di.foldseek_db_to_fasta \
# 	--db-prefix "$DB_PREFIX" \
# 	--output-prefix "$OUTPUT_PREFIX"
# Out:
# Writing AA sequences: 100%|██████████| 626/626 [00:00<00:00, 696824.39seq/s]
# Writing 3Di sequences: 100%|██████████| 626/626 [00:00<00:00, 930416.12seq/s]
# Wrote AA FASTA: /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_aa.fasta
# Wrote 3Di FASTA: /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_3di.fasta

# %%
# %%bash
# set -euo pipefail
#
# MODEL_CKPT="/home/dmoi/projects/ESM3di/checkpoints/esm3di_from_mlm/epoch_5.pt"
# AA_FASTA="/mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_aa.fasta"
# OUTPUT_DB="/mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db"
#
# python -m esm3di.fastas2foldseekdb \
# 	--aa-fasta "$AA_FASTA" \
# 	--model-ckpt "$MODEL_CKPT" \
# 	--output-db "$OUTPUT_DB" \
# 	--num-gpus 2 \
# 	--revision 46c5f7d \
# 	--keep-fastas
# Out:
# Checking for FoldSeek installation...
# ✓ FoldSeek found
#
# Running ESM inference on /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_aa.fasta...
# Using model: /home/dmoi/projects/ESM3di/checkpoints/esm3di_from_mlm/epoch_5.pt
# Device: cuda
# Loading model configuration from checkpoint...
# Using model revision: 46c5f7d
# Using 2 GPU(s) for inference on 626 sequences
# Multi-GPU inference:   0%|          | 0/2 [00:06<?, ?GPU/s]
# WARNING: Multi-GPU inference failed: GPU 1 worker failed: object of type 'NoneType' has no len()
# Falling back to single-GPU inference...
# Using single GPU: cuda
# Initializing ESM3DiModel with Synthyra/ESMplusplus_small...
#
# Loading model: Synthyra/ESMplusplus_small
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Attention backend: config='sdpa' -> resolved='sdpa'
# Loading weights: 100%|██████████| 308/308 [00:00<00:00, 2513.30it/s]
# [transformers] ESMplusplusForTokenClassification LOAD REPORT from: Synthyra/ESMplusplus_small
# Key                         | Status  |
# ----------------------------+---------+-
# classifier.{0, 2, 3}.bias   | MISSING |
# classifier.{0, 2, 3}.weight | MISSING |
#
# Notes:
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# ✓ Base model loaded (TokenClassification)
#
# Auto-discovering LoRA target modules...
# Discovering LoRA target modules...
# Discovered target modules: ['classifier.0', 'classifier.3', 'embed', 'sequence_head.0', 'sequence_head.3', 'transformer.blocks.0.attn.layernorm_qkv.1', 'transformer.blocks.0.attn.out_proj', 'transformer.blocks.0.ffn.1', 'transformer.blocks.0.ffn.3', 'transformer.blocks.1.attn.layernorm_qkv.1', 'transformer.blocks.1.attn.out_proj', 'transformer.blocks.1.ffn.1', 'transformer.blocks.1.ffn.3', 'transformer.blocks.10.attn.layernorm_qkv.1', 'transformer.blocks.10.attn.out_proj', 'transformer.blocks.10.ffn.1', 'transformer.blocks.10.ffn.3', 'transformer.blocks.11.attn.layernorm_qkv.1', 'transformer.blocks.11.attn.out_proj', 'transformer.blocks.11.ffn.1', 'transformer.blocks.11.ffn.3', 'transformer.blocks.12.attn.layernorm_qkv.1', 'transformer.blocks.12.attn.out_proj', 'transformer.blocks.12.ffn.1', 'transformer.blocks.12.ffn.3', 'transformer.blocks.13.attn.layernorm_qkv.1', 'transformer.blocks.13.attn.out_proj', 'transformer.blocks.13.ffn.1', 'transformer.blocks.13.ffn.3', 'transformer.blocks.14.attn.layernorm_qkv.1', 'transformer.blocks.14.attn.out_proj', 'transformer.blocks.14.ffn.1', 'transformer.blocks.14.ffn.3', 'transformer.blocks.15.attn.layernorm_qkv.1', 'transformer.blocks.15.attn.out_proj', 'transformer.blocks.15.ffn.1', 'transformer.blocks.15.ffn.3', 'transformer.blocks.16.attn.layernorm_qkv.1', 'transformer.blocks.16.attn.out_proj', 'transformer.blocks.16.ffn.1', 'transformer.blocks.16.ffn.3', 'transformer.blocks.17.attn.layernorm_qkv.1', 'transformer.blocks.17.attn.out_proj', 'transformer.blocks.17.ffn.1', 'transformer.blocks.17.ffn.3', 'transformer.blocks.18.attn.layernorm_qkv.1', 'transformer.blocks.18.attn.out_proj', 'transformer.blocks.18.ffn.1', 'transformer.blocks.18.ffn.3', 'transformer.blocks.19.attn.layernorm_qkv.1', 'transformer.blocks.19.attn.out_proj', 'transformer.blocks.19.ffn.1', 'transformer.blocks.19.ffn.3', 'transformer.blocks.2.attn.layernorm_qkv.1', 'transformer.blocks.2.attn.out_proj', 'transformer.blocks.2.ffn.1', 'transformer.blocks.2.ffn.3', 'transformer.blocks.20.attn.layernorm_qkv.1', 'transformer.blocks.20.attn.out_proj', 'transformer.blocks.20.ffn.1', 'transformer.blocks.20.ffn.3', 'transformer.blocks.21.attn.layernorm_qkv.1', 'transformer.blocks.21.attn.out_proj', 'transformer.blocks.21.ffn.1', 'transformer.blocks.21.ffn.3', 'transformer.blocks.22.attn.layernorm_qkv.1', 'transformer.blocks.22.attn.out_proj', 'transformer.blocks.22.ffn.1', 'transformer.blocks.22.ffn.3', 'transformer.blocks.23.attn.layernorm_qkv.1', 'transformer.blocks.23.attn.out_proj', 'transformer.blocks.23.ffn.1', 'transformer.blocks.23.ffn.3', 'transformer.blocks.24.attn.layernorm_qkv.1', 'transformer.blocks.24.attn.out_proj', 'transformer.blocks.24.ffn.1', 'transformer.blocks.24.ffn.3', 'transformer.blocks.25.attn.layernorm_qkv.1', 'transformer.blocks.25.attn.out_proj', 'transformer.blocks.25.ffn.1', 'transformer.blocks.25.ffn.3', 'transformer.blocks.26.attn.layernorm_qkv.1', 'transformer.blocks.26.attn.out_proj', 'transformer.blocks.26.ffn.1', 'transformer.blocks.26.ffn.3', 'transformer.blocks.27.attn.layernorm_qkv.1', 'transformer.blocks.27.attn.out_proj', 'transformer.blocks.27.ffn.1', 'transformer.blocks.27.ffn.3', 'transformer.blocks.28.attn.layernorm_qkv.1', 'transformer.blocks.28.attn.out_proj', 'transformer.blocks.28.ffn.1', 'transformer.blocks.28.ffn.3', 'transformer.blocks.29.attn.layernorm_qkv.1', 'transformer.blocks.29.attn.out_proj', 'transformer.blocks.29.ffn.1', 'transformer.blocks.29.ffn.3', 'transformer.blocks.3.attn.layernorm_qkv.1', 'transformer.blocks.3.attn.out_proj', 'transformer.blocks.3.ffn.1', 'transformer.blocks.3.ffn.3', 'transformer.blocks.4.attn.layernorm_qkv.1', 'transformer.blocks.4.attn.out_proj', 'transformer.blocks.4.ffn.1', 'transformer.blocks.4.ffn.3', 'transformer.blocks.5.attn.layernorm_qkv.1', 'transformer.blocks.5.attn.out_proj', 'transformer.blocks.5.ffn.1', 'transformer.blocks.5.ffn.3', 'transformer.blocks.6.attn.layernorm_qkv.1', 'transformer.blocks.6.attn.out_proj', 'transformer ...
# ✓ CNN classification head added (2 layers)
# ✓ LoRA setup complete
#
# Predicting 3Di sequences...
# Using device: cuda
# Loading model from: /home/dmoi/projects/ESM3di/checkpoints/esm3di_from_mlm/epoch_5.pt
# ✓ Checkpoint loaded
# <class 'dict'>
# <class 'esm3di.ESM3di_model.ESMWithCNNHead'>
# ✓ Loaded model from epoch 5
# Reading input FASTA: /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_aa.fasta
# Found 626 sequences
# [transformers] `use_return_dict` is deprecated! Use `return_dict` instead!
# Processed 40/626 sequences
# Processed 80/626 sequences
# Processed 120/626 sequences
# Processed 160/626 sequences
# Processed 200/626 sequences
# Processed 240/626 sequences
# Processed 280/626 sequences
# Processed 320/626 sequences
# Processed 360/626 sequences
# Processed 400/626 sequences
# Processed 440/626 sequences
# Processed 480/626 sequences
# Processed 520/626 sequences
# Processed 560/626 sequences
# Processed 600/626 sequences
# Processed 626/626 sequences
# Writing predictions to: /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db_3di.fasta
# ✓ Prediction complete! 626 sequences written to /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db_3di.fasta
# ✓ FASTA files ready
#
# Creating FoldSeek database: /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db
# Finished writing Foldseek database to /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db
# Total sequences: 626
# Pep file: /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db, size: 197760 bytes
# TDI file: /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db_ss, size: 197760 bytes
# Header file: /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db_h, size: 36948 bytes
# Pep index file: /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db.index, size: 8963 bytes
# TDI index file: /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db_ss.index, size: 8963 bytes
# Header index file: /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db_h.index, size: 7841 bytes
#
# ✓ Successfully created FoldSeek database: /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db
#   - Main database: /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db
#   - 3Di database: /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db_ss
#
# Created 11 database files:
#   - refolded_fullglyco_esm3di_db
#   - refolded_fullglyco_esm3di_db.dbtype
#   - refolded_fullglyco_esm3di_db.index
#   - refolded_fullglyco_esm3di_db.lookup
#   - refolded_fullglyco_esm3di_db_3di.fasta
#   - refolded_fullglyco_esm3di_db_h
#   - refolded_fullglyco_esm3di_db_h.dbtype
#   - refolded_fullglyco_esm3di_db_h.index
#   - refolded_fullglyco_esm3di_db_ss
#   - refolded_fullglyco_esm3di_db_ss.dbtype
#   ... and 1 more
#
# ✓ Pipeline complete!

# %%
import subprocess


def runFoldseek_allvall( dbpath , outfolder , foldseekpath = 'foldseek' , maxseqs = 3000):
	'''
	run foldseek search and createtsv
	
	parameters
	----------
	dbpath : str
		path to foldseek database
	outfolder : str 
		path to output folder
	maxseqs : int   
		maximum number of sequences to compare to

	'''
	if not os.path.exists(outfolder):
		os.makedirs(outfolder)
	dbfolder = os.path.dirname(dbpath)

	cmd = foldseekpath + " easy-search " + dbpath + " "+ dbpath +" "+ outfolder+"/allvall.csv " +  dbfolder+"/tmp --format-output 'query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits' --exhaustive-search --alignment-type 2" 
	subprocess.run(cmd, shell=True, check=True)
	
	return outfolder + '/allvall.csv'

# %%
def runQuicktree(   clusterfile , quicktreepath= 'quicktree' ):
	'''
	run quicktree

	parameters
	----------
	clusterfile : str
		path to all vs all distance matrix in fastme format
	quicktreepath : str 
		path to quicktree binary

	'''
	args = quicktreepath + ' -i m ' + clusterfile +' > ' + clusterfile + '.struct_tree.nwk'
	print(args)
	p =subprocess.run( args , shell= True)
	return clusterfile + '.struct_tree.nwk'


def runFastme(   clusterfile , fastmepath= 'fastme' ):
	'''
	run fastme

	parameters
	----------
	clusterfile : str
		path to all vs all distance matrix in fastme format
	fastmepath : str 
		path to fastme binary

	'''
	
	args = fastmepath + ' -i ' + clusterfile +' -o ' + clusterfile + '.struct_tree.nwk'
	print(args)
	p =subprocess.run(args , shell= True)
	return clusterfile + '.struct_tree.nwk'

def run_madroot( treefile, madrootpath = '/home/dmoi/projects/ESM3di/madroot/mad' ):
	'''
	run madroot

	parameters
	----------
	treefile : str
		path to tree file in newick format
	madrootpath : str 
		path to madroot binary

	'''
	args = madrootpath + ' ' + treefile 
	print(args)
	p =subprocess.run(args , shell= True)
	return treefile + '.rooted'

# %%
#finish up 
import sys
import os
import pandas as pd
import numpy as np
import tqdm
from matplotlib import pyplot as plt

run_trees= False


foldtree_dir = '/home/dmoi/projects/fold_tree'
fastmepath = 'fastme'
delta = 1e-5

sys.path.append(foldtree_dir)
import foldtree.foldseek2tree as ft1

def runFoldseek2Tree( alnres , delta = 1e-5):
	res = pd.read_table(alnres , header = None )
	res[0] = res[0].map(lambda x :x.replace('.pdb', ''))
	res[1] = res[1].map(lambda x :x.replace('.pdb', ''))
	res.columns = 'query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits'.split(',')
	#drop rows where query and target are the same
	res = res[res['query'] != res['target']]
	
	res.fident.hist(bins = 100)
	plt.show()
	ids = list( set(list(res['query'].unique()) + list(res['target'].unique())))
	pos = { protid : i for i,protid in enumerate(ids)}
	kernels = ['fident']
	matrices = { k:np.zeros((len(pos), len(pos))) for k in kernels }
	print(res)

	#calc kernel for tm, aln score, lddt
	for idx,row in tqdm.tqdm(res.iterrows(), total=res.shape[0]):
		for k in matrices:
			matrices[k][pos[row['query']] , pos[row['target']]] += row[k]
			matrices[k][pos[row['target']] , pos[row['query']]] += row[k]

	trees = {}
	for i,k in enumerate(matrices):
		matrices[k] /= 2
		matrices[k] = 1-matrices[k]
		matrices[k][np.diag_indices_from(matrices[k])] = 0
		#floor at 0.0001 to avoid issues with fastme
		matrices[k][matrices[k] < delta] = delta
		

		if k == 'fident':
			distmat = ft1.Tajima_dist( matrices[k] , bfactor = .93 , iter = 100 )
		else:
			distmat = ft1.Tajima_dist( matrices[k] )
		print(distmat,  np.amax(distmat), np.amin(distmat) )

		#save the distance matrix and run fastme to the same folder as the input csv file
		np.save( alnres.replace('allvall.csv', k + '_distmat.npy') , distmat)
		distmat_txt = ft1.distmat_to_txt( ids , distmat , alnres.replace('allvall.csv', k + '_distmat.txt') )
		#print a few lines of the distance matrix
		with open(distmat_txt) as f:
			for i in range(5):
				print(f.readline())
		treefile = runQuicktree( clusterfile=distmat_txt )
		out_tree = ft1.postprocess(treefile, treefile+'.pp.nwk' , delta = delta)
		trees[k] = out_tree
	return trees

# %%
#run allvsall foldseek for structures
runFoldseek_allvall( dbpath = "/mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_db" , outfolder = "/mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results" , foldseekpath = 'foldseek' , maxseqs = 3000)
# Out:
# /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results/allvall.csv exists and will be overwritten
# easy-search /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_db /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_db /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results/allvall.csv /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp --format-output query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits --exhaustive-search --alignment-type 2
#
# MMseqs Version:                    	10.941cd33
# Seq. id. threshold                 	0
# Coverage threshold                 	0
# Coverage mode                      	0
# Max reject                         	2147483647
# Max accept                         	2147483647
# Add backtrace                      	false
# TMscore threshold                  	0
# TMscore threshold mode             	0
# TMalign hit order                  	0
# TMalign fast                       	1
# Preload mode                       	0
# Threads                            	32
# Verbosity                          	3
# LDDT threshold                     	0
# Sort by structure bit score        	1
# Alignment type                     	2
# Exact TMscore                      	0
# Substitution matrix                	aa:3di.out,nucl:3di.out
# Alignment mode                     	3
# Alignment mode                     	0
# E-value threshold                  	10
# Min alignment length               	0
# Seq. id. mode                      	0
# Alternative alignments             	0
# Max sequence length                	65535
# Compositional bias                 	1
# Compositional bias                 	1
# Gap open cost                      	aa:10,nucl:10
# Gap extension cost                 	aa:1,nucl:1
# Compressed                         	0
# Seed substitution matrix           	aa:3di.out,nucl:3di.out
# Sensitivity                        	9.5
# k-mer length                       	6
# Target search mode                 	0
# k-score                            	seq:2147483647,prof:2147483647
# Max results per query              	1000
# Split database                     	0
# Split mode                         	2
# Split memory limit                 	0
# Diagonal scoring                   	true
# Exact k-mer matching               	0
# Mask residues                      	0
# Mask residues probability          	0.999995
# Mask lower case residues           	1
# Mask lower letter repeating N times	6
# Minimum diagonal score             	30
# Selected taxa
# Spaced k-mers                      	1
# Spaced k-mer pattern
# Local temporary path
# Use GPU                            	0
# Use GPU server                     	0
# Wait for GPU server                	600
# Prefilter mode                     	0
# Exhaustive search mode             	true
# Search iterations                  	1
# Remove temporary files             	true
# MPI runner
# Force restart with latest tmp      	false
# Cluster search                     	0
# Path to ProstT5
# Chain name mode                    	0
# Createdb extraction mode           	0
# Interface distance threshold       	8
# Write mapping file                 	0
# Mask b-factor threshold            	0
# Coord store mode                   	2
# Write lookup file                  	1
# Input format                       	0
# File Inclusion Regex               	.*
# File Exclusion Regex               	^$
# Alignment format                   	0
# Format alignment output            	query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits
# Database output                    	false
# Report mode                        	2
# Greedy best hits                   	false
#
# Create directory /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/2703916181952498453/search_tmp
# search /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_db /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_db /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/2703916181952498453/result /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/2703916181952498453/search_tmp --alignment-type 2 --alignment-mode 3 -s 9.5 -k 6 --exhaustive-search 1 --remove-tmp-files 1
#
# structurealign /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_db /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_db /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/2703916181952498453/search_tmp/17140974526226198938/pref /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/2703916181952498453/search_tmp/17140974526226198938/strualn --tmscore-threshold 0 --tmscore-threshold-mode 0 --lddt-threshold 0 --sort-by-structure-bits 1 --alignment-type 2 --exact-tmscore 0 --sub-mat 'aa:3di.out,nucl:3di.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 10 --min-seq-id 0 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 0.5 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:10,nucl:10 --gap-extend aa:1,nucl:1 --zdrop 40 --threads 32 --compressed 0 -v 3
#
# [=================================================================] 626 12s 402ms
# Time for merging to strualn: 0h 0m 0s 2ms
# Time for processing: 0h 0m 12s 915ms
# mvdb /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/2703916181952498453/search_tmp/17140974526226198938/strualn /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/2703916181952498453/search_tmp/17140974526226198938/aln -v 3
#
# Time for processing: 0h 0m 0s 1ms
# mvdb /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/2703916181952498453/search_tmp/17140974526226198938/aln /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/2703916181952498453/result -v 3
#
# Time for processing: 0h 0m 0s 1ms
# Removing temporary files
# rmdb /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/2703916181952498453/search_tmp/17140974526226198938/pref -v 3
#
# Time for processing: 0h 0m 0s 0ms
# /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results/allvall.csv exists and will be overwritten
# convertalis /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_db /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_db /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/2703916181952498453/result /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results/allvall.csv --sub-mat 'aa:3di.out,nucl:3di.out' --format-mode 0 --format-output query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits --translation-table 1 --gap-open aa:10,nucl:10 --gap-extend aa:1,nucl:1 --db-output 0 --db-load-mode 0 --search-type 0 --threads 32 --compressed 0 -v 3 --exact-tmscore 0
#
# [=================================================================] 626 0s 54ms
# Time for merging to allvall.csv: 0h 0m 0s 50ms
# Time for processing: 0h 0m 0s 188ms
# rmdb /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/2703916181952498453/result -v 3
#
# Time for processing: 0h 0m 0s 3ms
# '/mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results/allvall.csv'

# %%
#run all vs all for esm3di 
runFoldseek_allvall( dbpath = "/mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db" , outfolder = "/mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results_esm3di" , foldseekpath = 'foldseek' , maxseqs = 3000)
# Out:
# /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results_esm3di/allvall.csv exists and will be overwritten
# easy-search /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results_esm3di/allvall.csv /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp --format-output query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits --exhaustive-search --alignment-type 2
#
# MMseqs Version:                    	10.941cd33
# Seq. id. threshold                 	0
# Coverage threshold                 	0
# Coverage mode                      	0
# Max reject                         	2147483647
# Max accept                         	2147483647
# Add backtrace                      	false
# TMscore threshold                  	0
# TMscore threshold mode             	0
# TMalign hit order                  	0
# TMalign fast                       	1
# Preload mode                       	0
# Threads                            	32
# Verbosity                          	3
# LDDT threshold                     	0
# Sort by structure bit score        	1
# Alignment type                     	2
# Exact TMscore                      	0
# Substitution matrix                	aa:3di.out,nucl:3di.out
# Alignment mode                     	3
# Alignment mode                     	0
# E-value threshold                  	10
# Min alignment length               	0
# Seq. id. mode                      	0
# Alternative alignments             	0
# Max sequence length                	65535
# Compositional bias                 	1
# Compositional bias                 	1
# Gap open cost                      	aa:10,nucl:10
# Gap extension cost                 	aa:1,nucl:1
# Compressed                         	0
# Seed substitution matrix           	aa:3di.out,nucl:3di.out
# Sensitivity                        	9.5
# k-mer length                       	6
# Target search mode                 	0
# k-score                            	seq:2147483647,prof:2147483647
# Max results per query              	1000
# Split database                     	0
# Split mode                         	2
# Split memory limit                 	0
# Diagonal scoring                   	true
# Exact k-mer matching               	0
# Mask residues                      	0
# Mask residues probability          	0.999995
# Mask lower case residues           	1
# Mask lower letter repeating N times	6
# Minimum diagonal score             	30
# Selected taxa
# Spaced k-mers                      	1
# Spaced k-mer pattern
# Local temporary path
# Use GPU                            	0
# Use GPU server                     	0
# Wait for GPU server                	600
# Prefilter mode                     	0
# Exhaustive search mode             	true
# Search iterations                  	1
# Remove temporary files             	true
# MPI runner
# Force restart with latest tmp      	false
# Cluster search                     	0
# Path to ProstT5
# Chain name mode                    	0
# Createdb extraction mode           	0
# Interface distance threshold       	8
# Write mapping file                 	0
# Mask b-factor threshold            	0
# Coord store mode                   	2
# Write lookup file                  	1
# Input format                       	0
# File Inclusion Regex               	.*
# File Exclusion Regex               	^$
# Alignment format                   	0
# Format alignment output            	query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits
# Database output                    	false
# Report mode                        	2
# Greedy best hits                   	false
#
# Create directory /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/12596106981107127237/search_tmp
# search /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/12596106981107127237/result /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/12596106981107127237/search_tmp --alignment-type 2 --alignment-mode 3 -s 9.5 -k 6 --exhaustive-search 1 --remove-tmp-files 1
#
# structurealign /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/12596106981107127237/search_tmp/7230980655674423492/pref /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/12596106981107127237/search_tmp/7230980655674423492/strualn --tmscore-threshold 0 --tmscore-threshold-mode 0 --lddt-threshold 0 --sort-by-structure-bits 1 --alignment-type 2 --exact-tmscore 0 --sub-mat 'aa:3di.out,nucl:3di.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 10 --min-seq-id 0 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 0.5 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:10,nucl:10 --gap-extend aa:1,nucl:1 --zdrop 40 --threads 32 --compressed 0 -v 3
#
# Cannot find refolded_fullglyco_esm3di_db C-alpha or refolded_fullglyco_esm3di_db C-alpha database
# Disabling --sort-by-structure-bits
# This impacts the final score and ranking of hits, but not E-values themselves. Ranking alterations primarily occur for E-values < 10^-1.
# [=================================================================] 626 3s 160ms
# Time for merging to strualn: 0h 0m 0s 2ms
# Time for processing: 0h 0m 3s 425ms
# mvdb /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/12596106981107127237/search_tmp/7230980655674423492/strualn /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/12596106981107127237/search_tmp/7230980655674423492/aln -v 3
#
# Time for processing: 0h 0m 0s 1ms
# mvdb /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/12596106981107127237/search_tmp/7230980655674423492/aln /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/12596106981107127237/result -v 3
#
# Time for processing: 0h 0m 0s 3ms
# Removing temporary files
# rmdb /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/12596106981107127237/search_tmp/7230980655674423492/pref -v 3
#
# Time for processing: 0h 0m 0s 0ms
# /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results_esm3di/allvall.csv exists and will be overwritten
# convertalis /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/refolded_fullglyco_esm3di_db /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/12596106981107127237/result /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results_esm3di/allvall.csv --sub-mat 'aa:3di.out,nucl:3di.out' --format-mode 0 --format-output query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits --translation-table 1 --gap-open aa:10,nucl:10 --gap-extend aa:1,nucl:1 --db-output 0 --db-load-mode 0 --search-type 0 --threads 32 --compressed 0 -v 3 --exact-tmscore 0
#
# [=================================================================] 626 0s 69ms
# Time for merging to allvall.csv: 0h 0m 0s 68ms
# Time for processing: 0h 0m 0s 263ms
# rmdb /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/tmp/12596106981107127237/result -v 3
#
# Time for processing: 0h 0m 0s 3ms
# '/mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results_esm3di/allvall.csv'

# %%
#create a foldtree for esm3di
trees_esm3di = runFoldseek2Tree( alnres = "/mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results_esm3di/allvall.csv" , delta = 1e-5)

#create a foldtree for structures
trees_structures = runFoldseek2Tree( alnres = "/mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results/allvall.csv" , delta = 1e-5)
# Out:
#                                                     query  \
# 1       PLPV_Pestivirus_strain_Aydin04-TR_E2_691-1062_...
# 2       PLPV_Pestivirus_strain_Aydin04-TR_E2_691-1062_...
# 3       PLPV_Pestivirus_strain_Aydin04-TR_E2_691-1062_...
# 4       PLPV_Pestivirus_strain_Aydin04-TR_E2_691-1062_...
# 5       PLPV_Pestivirus_strain_Aydin04-TR_E2_691-1062_...
# ...                                                   ...
# 295856  PLPV_Pangolin_pestivirus_strain_PPeVBIME3P019T...
# 295857  PLPV_Pangolin_pestivirus_strain_PPeVBIME3P019T...
# 295858  PLPV_Pangolin_pestivirus_strain_PPeVBIME3P019T...
# 295859  PLPV_Pangolin_pestivirus_strain_PPeVBIME3P019T...
# 295860  PLPV_Pangolin_pestivirus_strain_PPeVBIME3P019T...
#
#                                                    target  fident  alnlen  \
# 1       PLPV_Pestivirus_Burdur05-TR_E2_691-1062_AlphaFold   0.865     372
# 2       PLPV_Tunisian_small_ruminant_pestivirus_strain...   0.693     371
# 3       PLPV_Pestivirus_sp._isolate_ovineIt338710-3201...   0.658     372
# 4       PLPV_Pestivirus_reindeer-1_V60-Krefeld_E2_691-...   0.698     371
# 5       PLPV_Bovine_viral_diarrhea_virus_3_Th04_KhonKa...   0.549     370
# ...                                                   ...     ...     ...
# 295856  HPHV_Rodent_hepacivirus_TA085TZA2013_E2_410-68...   0.171     175
# 295857  HPHV_Rodent_hepacivirus_TA142TZA2013_E2_360-69...   0.156     161
# 295858  FJIS_Tafomo_virus_strain_TVB22-CI-2004_E_332-6...   0.200      30
# 295859       FJTB_Gadgets_Gully_virus_E_280-676_AlphaFold   0.164      73
# 295860  PLLG_Shayang_fly_virus_4_strain_SYCY_E_761-124...   0.147      83
#
#         mismatch  gapopen  qstart  qend  tstart  tend        evalue  bits
# 1             50        0       1   372       1   372  5.708000e-43  1890
# 2            114        0       1   371       1   371  2.247000e-37  1649
# 3            127        0       1   372       1   372  8.950000e-35  1537
# 4            112        0       1   371       1   371  1.605000e-33  1483
# 5            166        0       3   372       2   369  8.353000e-31  1366
# ...          ...      ...     ...   ...     ...   ...           ...   ...
# 295856       138        0       7   173      97   271  9.859000e+00    21
# 295857       111        0       5   137       2   162  9.859000e+00    21
# 295858        22        0      57    85     307   336  9.859000e+00    21
# 295859        59        0      50   122     189   259  9.859000e+00    21
# 295860        68        0      40   120     210   292  9.859000e+00    21
#
# [295235 rows x 12 columns]
# 100%|██████████| 295235/295235 [00:15<00:00, 18606.37it/s]
# [[  0.           2.44629204   2.94704868 ...   2.09745768   2.65524008
#   215.89018894]
#  [  2.44629204   0.           2.2305359  ...   2.2471916    2.97083811
#     1.81924528]
#  [  2.94704868   2.2305359    0.         ...   2.36656421   2.43938161
.8466 2.6212 2.3230 2.6296 2.4325 7.9651 2.3730 1.6968 2.6046 2.5184 2.9589 3.0076 2.4325 215.8902 2.6816 3.2151 4.7661 2.4816 3.2784 3.3631 2.5335 8.7634 215.8902 2.4603 3.0856 2.7087 4.3403 2.8900 2.7461 6.4153 2.9470 4.3403 2.3353 2.6466 2.5644 2.9238 2.8154 3.0459 2.9589 2.6552 215.8902 3.1555 2.6552 215.8902 1.9359 3.0330 0.1963 2.7087 2.9124 0.1890 0.2406 2.6212 2.9470 6.7176 7.5469 2.8361 2.9124 2.9708 2.9354 6.8249 2.8681 0.1804 2.2756 2.3794 2.7179 11.9077 2.5723 0.0274 3.0076 2.5723 2.5803 2.9011 215.8902 3.1555 2.8466 0.0326 2.8466 3.1849 6.7176 2.7654 3.9466 3.3989 1.3095 2.9354 0.0295 3.1999 2.5335 3.0722 3.1999 2.7272 2.4122 2.8466 2.6046 2.5109 2.6996 8.2682 3.1701 2.8681 2.7851 2.7366 2.5803 215.8902 215.8902 2.6466 3.0589 0.2602 215.8902 2.9708 2.7179 3.1412 2.3859 2.7951 4.9166 215.8902 1.7983 2.8154 2.6639 3.1701 5.0798 2.2528 2.7461 3.2622 2.7752 2.3414 215.8902 2.8052 0.1829 2.8573 4.2669 2.5644 7.2904 8.5927 2.6129  ...
#
# quicktree -i m /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results_esm3di/fident_distmat.txt > /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results_esm3di/fident_distmat.txt.struct_tree.nwk
# ⚠️ toytree | writer:write | Deprecated args to write(): ['tree_format']. See docs.
# <toytree.ToyTree at 0x7f25cb52e6e0>
#                                                     query  \
# 1       PLLG_Sanxia_water_strider_virus_6_strain_SYSZZ...
# 2       PLLG_Sanxia_water_strider_virus_6_strain_SYSZZ...
# 3       PLLG_Sanxia_water_strider_virus_6_strain_SYSZZ...
# 4       PLLG_Sanxia_water_strider_virus_6_strain_SYSZZ...
# 5       PLLG_Sanxia_water_strider_virus_6_strain_SYSZZ...
# ...                                                   ...
# 225829  FJJI_Jingmen_tick_virus_isolate_TTP-Pool-3b_se...
# 225830  FJJI_Jingmen_tick_virus_isolate_TTP-Pool-3b_se...
# 225831  FJJI_Jingmen_tick_virus_isolate_TTP-Pool-3b_se...
# 225832  FJJI_Jingmen_tick_virus_isolate_TTP-Pool-3b_se...
# 225833  FJJI_Jingmen_tick_virus_isolate_TTP-Pool-3b_se...
#
#                                                    target  fident  alnlen  \
# 1       PLLG_Shuangao_lacewing_virus_2_strain_SCL_E_77...   0.208     259
# 2       PLLG_Shayang_fly_virus_4_strain_SYCY_E_761-124...   0.187     257
# 3       PLLG_Locusta_migratoria_associated_flavi-like_...   0.167     297
# 4       PLLG_Brachymeria_lasus_associated_flavi-like_v...   0.169     296
# 5       PLLG_Fushun_laodelphax_striatellus_flavivirus_...   0.162     254
# ...                                                   ...     ...     ...
# 225829  PLPV_Pangolin_pestivirus_strain_PPeVBIME7P022T...   0.121     109
# 225830  PLPV_Pangolin_pestivirus_1_isolate_ZJ-F1_E2_70...   0.095      97
# 225831  FJUN_flavi_salt_marsh_ORF170_SRR11829261_E_276...   0.058      86
mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results/fident_distmat.txt > /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results/fident_distmat.txt.struct_tree.nwk
# ⚠️ toytree | writer:write | Deprecated args to write(): ['tree_format']. See docs.
# <toytree.ToyTree at 0x7f25cc08ace0>

# %%
#root both trees using madroot

trees_rooted = [run_madroot(tree) for tree in trees]
# Out:
# /home/dmoi/projects/ESM3di/madroot/mad /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results_esm3di/fident_distmat.txt.struct_tree.nwk.pp.nwk
#
# MAD phylogenetic rooting
#
# Analyzing file '/mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results_esm3di/fident_distmat.txt.struct_tree.nwk.pp.nwk'...
# >> Warning: Trees with repeating branch lengths are suspicious (8 repeating values).
# >> Warning: Squeezing tip polytomies (626 OTUs, 8 redundant tips, 618 effective OTUs).
# >> [MAD=0.513_AI=0.998_CCV=43.9%_N=1/1]
#
# Minimal ancestor deviation, MAD = 0.513
#            Ambiguity index,  AI = 0.998
#                   Clock CV, CCV = 43.9%
# Rooted tree written to '/mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results_esm3di/fident_distmat.txt.struct_tree.nwk.pp.nwk.rooted'
#
#
#     - Please cite DOI:10.1038/s41559-017-0193
#
# /home/dmoi/projects/ESM3di/madroot/mad /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results/fident_distmat.txt.struct_tree.nwk.pp.nwk
#
# MAD phylogenetic rooting
#
# Analyzing file '/mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results/fident_distmat.txt.struct_tree.nwk.pp.nwk'...
# >> Warning: Trees with repeating branch lengths are suspicious (4 repeating values).
# >> Warning: Squeezing tip polytomies (626 OTUs, 9 redundant tips, 617 effective OTUs).
# >> [MAD=0.635_AI=1.000_CCV=44.4%_N=1/1]
#
# Minimal ancestor deviation, MAD = 0.635
#            Ambiguity index,  AI = 1.000
#                   Clock CV, CCV = 44.4%
# Rooted tree written to '/mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results/fident_distmat.txt.struct_tree.nwk.pp.nwk.rooted'
#
#
#     - Please cite DOI:10.1038/s41559-017-0193

# %%
#load all trees and plot them using toytree
import toytree
import glob
import os
import colour
	

for tree in trees_rooted:
	print(f"Plotting tree: {tree}")
	tre = toytree.tree(tree)
	tip_ids = tre.get_tip_labels()
	#split each tip name on '_': first token groups/colors the tip, next 3 tokens form its display label
	tip_tokens = [tid.split('_') for tid in tip_ids]
	tip_groups = [tokens[0] if tokens else 'unknown' for tokens in tip_tokens]
	tip_labels_text = ['_'.join(tokens[1:4]) for tokens in tip_tokens]

	red = colour.Color("red")
	blue = colour.Color("blue")
	unique_groups = sorted(set(tip_groups))
	colors = list(red.range_to(blue, len(unique_groups))) if len(unique_groups) > 1 else [red]
	colors = [color.hex_l for color in colors]
	group_colors = {group: color for group, color in zip(unique_groups, colors)}
	print(f"Group colors: {group_colors}")

	tip_colors = [group_colors[group] for group in tip_groups]
	#tip nodes come first (idx 0..ntips-1); color those by group, keep internal nodes black
	n_internal = tre.nnodes - tre.ntips
	node_colors = tip_colors + ['black'] * n_internal
	#derive a readable title from the tree filename (family name)
	tree_title = os.path.basename(tree).replace('.pp.nwk', '').replace('_', ' ')
	#display the tree with the tip text showing the first-3-token label, colored by the first-token group
	canvas, axes, mark = tre.draw(tip_labels=tip_labels_text, tip_labels_colors=tip_colors, node_sizes=5, node_colors=node_colors, edge_colors='black', width=900, height=2500, show_node_labels=False, label=tree_title)
	#legend mapping each group to its color, using toyplot's legend API
	legend_entries = [(str(group), "rect", {"fill": color}) for group, color in group_colors.items()]
	if legend_entries:
		canvas.legend(legend_entries, corner=("right", 20, 150, max(20, min(600, 20 * len(legend_entries)))))
# Out:
# ⚠️ toytree | draw_toytree:get_tree_style_updated_by_draw_args | Unrecognized arguments skipped: ['show_node_labels'].
# Check the docs, argument names may have changed.
# Plotting tree: /mnt/data2/Mifsud_et_al_Repository/glycoprotein_structural_alignments_and_trees/refolded_fullglyco/foldseek_results_esm3di/fident_distmat.txt.struct_tree.nwk.pp.nwk.rooted
# Group colors: {'FJAF': '#ff0000', 'FJFL': '#ff4e00', 'FJIS': '#ff9d00', 'FJJI': '#ffeb00', 'FJMB': '#c4ff00', 'FJNV': '#76ff00', 'FJTB': '#27ff00', 'FJUN': '#00ff27', 'HPHV': '#00ff76', 'HPPV': '#00ffc4', 'HPUN': '#00ebff', 'PLLG': '#009dff', 'PLPV': '#004eff', 'PLUN': '#0000ff'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 36
#      34 legend_entries = [(str(group), "rect", {"fill": color}) for group, color in group_colors.items()]
#      35 if legend_entries:
# ---> 36 	canvas.legend(legend_entries, corner=("right", 20, 150, max(20, min(600, 20 * len(legend_entries)))))
#
# File ~/miniforge3/envs/fastas2foldseekdb/lib/python3.10/site-packages/toyplot/canvas.py:395, in Canvas.legend(self, entries, bounds, corner, grid, label, margin, rect)
#     392 table.cells.column[0].align = "right"
#     393 table.cells.column[1].align = "left"
# --> 395 for index, (label, spec) in enumerate(entries): # pylint: disable=redefined-argument-from-local
#     396     if isinstance(spec, toyplot.mark.Mark):
#     397         markers = spec.markers
#
# ValueError: too many values to unpack (expected 2)
# <div class="toyplot" id="t960d8e92397045729013fcdc33741cd7" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="900.0px" height="2500.0px" viewBox="0 0 900.0 2500.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t951ff2ca191647b5bda20bf08cee9950"><g class="toyplot-coordinates-Cartesian" id="t63ea0cda4f594f49ad8f4f682194c683"><clipPath id="tef1de0ed566a45a2ad5aa065c2500e48"><rect x="35.0" y="35.0" width="830.0" height="2430.0"></rect></clipPath><g clip-path="url(#tef1de0ed566a45a2ad5aa065c2500e48)"><g class="toytree-mark-Toytree" id="tea89d0042cd249e682475b70bda0a1b5"><g class="toytree-Edges" style="stroke:rgb(0.0%,0.0%,0.0%);stroke-opacity:1.0;stroke-linecap:round;stroke-width:2.0;fill:none"><path d="M